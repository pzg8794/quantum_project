# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 3,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 3
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# =============================================================================
# STEP 1: Deep Clean
# =============================================================================
import gc
import torch


def deep_cleanup():
    """Clean up all model instances and free memory"""
    model_vars = ['oracle', 'gneuralucb', 'expneuralucb', 
                  'cpursuitneuralucb', 'icpursuitneuralucb', 
                  'evaluator', 'results']
    
    for var in model_vars:
        if var in globals():
            try:
                if hasattr(globals()[var], 'cleanup'):
                    globals()[var].cleanup(verbose=False)
                del globals()[var]
            except:
                pass
    
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    
    gc.collect()
    torch.set_default_dtype(torch.float32)
    print("✓ Deep cleanup complete!")


deep_cleanup()


# =============================================================================
# STEP 2: Re-import Everything Fresh (NEW STRUCTURE)
# =============================================================================
import sys
import os
import importlib

# Add parent directory to path for daqr package
if os.path.abspath('..') not in sys.path:
    sys.path.insert(0, os.path.abspath('..'))

# Import and reload modules
from daqr.config import experiment_config
from daqr.core import qubit_allocator
from daqr.evaluation import visualizer
from daqr.core import network_environment
from daqr.evaluation import multi_run_evaluator
from daqr.algorithms import neural_bandits, predictive_bandits

importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(multi_run_evaluator)
importlib.reload(predictive_bandits)
importlib.reload(qubit_allocator)
importlib.reload(neural_bandits)
importlib.reload(visualizer)

# Import specific classes
from daqr.core.qubit_allocator import *
from daqr.config.experiment_config import *
from daqr.core.network_environment import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully!")
# Out:
# ✓ Deep cleanup complete!
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully!

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
from daqr.core.qubit_allocator import *

# Create allocator with correct parameters
# allocator = ThompsonSamplingAllocator(
#     total_qubits=35,           # Total qubits available (8+10+8+9=35)
#     num_routes=4,              # Number of routes
#     min_qubits_per_route=2     # Minimum qubits per route
# )
# AFTER (UCB - Dynamic):

# allocator = DynamicQubitAllocator(              # ← Change class name
#     total_qubits=35,           
#     num_routes=4,              
#     min_qubits_per_route=2,
#     exploration_bonus=2.0      # ← NEW parameter (optional, default is 2.0)
# )



# Fully random (exploration only)
allocator = RandomQubitAllocator(epsilon=1.0, seed=42)

# # 50-50 mix of random and baseline
# random_50 = RandomQubitAllocator(epsilon=0.5, seed=42)

# # Mostly baseline with occasional exploration (epsilon-greedy style)
# random_10 = RandomQubitAllocator(epsilon=0.1, seed=42)

# # Decaying randomness (start exploratory, become deterministic)
# decaying = RandomQubitAllocator(
#     epsilon=1.0,           # Start fully random
#     epsilon_decay=0.99,    # Decay 1% per timestep
#     min_epsilon=0.05,      # Eventually stabilize at 5% exploration
#     seed=42
# )

# # Fully deterministic (acts like fixed allocator)
# deterministic = RandomQubitAllocator(epsilon=0.0, seed=42)


# allocator = None

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, 
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=True, overwrite=True) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k

# Pass to evaluator - done!
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True)
    evaluator.calculate_scenario_performance(scenario=FRAMEWORK_CONFIG['main_env'])
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
# 🔄 Dynamic Allocation (Initial): (9, 4, 20, 2)
# 	⚠️ No saved state found for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
#
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 5
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
# 	RUNNING EXPERIMENTS IN PARALLEL
#
# STARTING PARALLEL MULTI-RUN EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# 	Running 3 experiments with 1 parallel workers
# ============================================================
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(9, 4, 20, 2)
# 🔄 Dynamic Allocation (Initial): (5, 8, 9, 13)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 16807
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_1-Random_Stochastic_Random-4000_1.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀STOCHASTIC (RANDOM) EXP 1: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 CPURSUITNEURALUCB   : Reward=1625.73, Efficiency=065.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 GNEURALUCB          : Reward=1709.83, Efficiency=068.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=1771.10, Efficiency=071.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 EXPNEURALUCB        : Reward=1903.50, Efficiency=076.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 16807
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:023.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:4000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(5, 8, 9, 13)
# 🔄 Dynamic Allocation (Initial): (19, 11, 3, 2)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 13738
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_2-Random_Stochastic_Random-6000_2.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀STOCHASTIC (RANDOM) EXP 2: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 GNEURALUCB          : Reward=5189.61, Efficiency=091.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 CPURSUITNEURALUCB   : Reward=5375.84, Efficiency=094.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 EXPNEURALUCB        : Reward=5342.44, Efficiency=094.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=5234.27, Efficiency=092.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 13738
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:005.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(19, 11, 3, 2)
# 🔄 Dynamic Allocation (Initial): (6, 2, 18, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 13755
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_3-Random_Stochastic_Random-8000_3.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀STOCHASTIC (RANDOM) EXP 3: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 CPURSUITNEURALUCB   : Reward=4058.34, Efficiency=056.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 GNEURALUCB          : Reward=3972.58, Efficiency=055.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 EXPNEURALUCB        : Reward=3978.75, Efficiency=055.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=4067.85, Efficiency=056.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 13755
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:043.2%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=8000, Alloc=Random]
#
# 	⏱️  Total multi-run time: 6188.8s
# 	Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
# 	RUNNING EXPERIMENTS IN PARALLEL
#
# STARTING PARALLEL MULTI-RUN EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# 	Running 3 experiments with 1 parallel workers
# ============================================================
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(6, 2, 18, 9)
# 🔄 Dynamic Allocation (Initial): (5, 7, 17, 6)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 16504
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_1-Random_Adversarial_Markov-4000_1.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (MARKOV) EXP 1: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 CPURSUITNEURALUCB   : Reward=1576.50, Efficiency=045.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 GNEURALUCB          : Reward=1507.11, Efficiency=044.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=1573.86, Efficiency=045.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 EXPNEURALUCB        : Reward=2462.46, Efficiency=071.4% [Retries=2, Failed=0, < Threshold=2, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 16504
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:028.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(5, 7, 17, 6)
# 🔄 Dynamic Allocation (Initial): (7, 8, 6, 14)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 17487
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_2-Random_Adversarial_Markov-6000_2.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (MARKOV) EXP 2: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
#
# 	EVALUATOR Saved Succesfully
# 	EXP 2 EXPNEURALUCB        : Reward=2731.04, Efficiency=068.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	EVALUATOR Saved Succesfully
# 	EXP 2 GNEURALUCB          : Reward=2674.44, Efficiency=066.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=3378.90, Efficiency=084.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 CPURSUITNEURALUCB   : Reward=3349.47, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 17487
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:015.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:6000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(7, 8, 6, 14)
# 🔄 Dynamic Allocation (Initial): (3, 7, 4, 21)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 15359
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_3-Random_Adversarial_Markov-8000_3.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (MARKOV) EXP 3: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1522.23, Efficiency=022.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 GNEURALUCB          : Reward=3054.12, Efficiency=044.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 EXPNEURALUCB        : Reward=3056.17, Efficiency=044.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1497.50, Efficiency=023.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 15359
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:055.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Random]
#
# 	⏱️  Total multi-run time: 10712.9s
# 	Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
# 	RUNNING EXPERIMENTS IN PARALLEL
#
# STARTING PARALLEL MULTI-RUN EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# 	Running 3 experiments with 1 parallel workers
# ============================================================
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(3, 7, 4, 21)
# 🔄 Dynamic Allocation (Initial): (8, 5, 6, 16)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 20893
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_1-Random_Adversarial_Adaptive-4000_1.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ADAPTIVE) EXP 1: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 CPURSUITNEURALUCB   : Reward=2579.39, Efficiency=086.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 GNEURALUCB          : Reward=2478.61, Efficiency=083.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EVALUATOR Saved Succesfully
# 	EXP 1 EXPNEURALUCB        : Reward=2454.65, Efficiency=082.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2557.87, Efficiency=086.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 20893
# 	-->🏆 EXP1 Winner:CPursuitNeuralUCB   (Gap:013.2%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(8, 5, 6, 16)
# 🔄 Dynamic Allocation (Initial): (8, 13, 11, 3)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 20950
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_2-Random_Adversarial_Adaptive-6000_2.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ADAPTIVE) EXP 2: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 GNEURALUCB          : Reward=3883.22, Efficiency=088.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 CPURSUITNEURALUCB   : Reward=3844.76, Efficiency=087.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 EXPNEURALUCB        : Reward=3809.66, Efficiency=087.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=3940.99, Efficiency=090.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 20950
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:010.0%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:6000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(8, 13, 11, 3)
# 🔄 Dynamic Allocation (Initial): (18, 3, 8, 6)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 14381
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_3-Random_Adversarial_Adaptive-8000_3.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ADAPTIVE) EXP 3: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 CPURSUITNEURALUCB   : Reward=6417.94, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 GNEURALUCB          : Reward=7147.15, Efficiency=095.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 EXPNEURALUCB        : Reward=6982.08, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=7198.27, Efficiency=095.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 14381
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:004.1%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Random]
#
# 	⏱️  Total multi-run time: 4064.5s
# 	Experiments completed for adaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: ONLINE ADAPTIVE ATTACK
# ==================================================
# 	RUNNING EXPERIMENTS IN PARALLEL
#
# STARTING PARALLEL MULTI-RUN EXPERIMENTS: ONLINEADAPTIVE
# Category: Online Adaptive (Real-time Strategic)
# 	Running 3 experiments with 1 parallel workers
# ============================================================
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(18, 3, 8, 6)
# 🔄 Dynamic Allocation (Initial): (21, 4, 6, 4)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 19816
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_1-Random_Adversarial_OnlineAdaptive-4000_1.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 GNEURALUCB          : Reward=3400.03, Efficiency=093.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 EXPNEURALUCB        : Reward=3402.92, Efficiency=093.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=3415.61, Efficiency=093.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 CPURSUITNEURALUCB   : Reward=3429.27, Efficiency=094.0% [Retries=1, Failed=0, < Threshold=1, SCapacity=8000, Threshold=0.634]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 19816
# 	-->🏆 EXP1 Winner:CPursuitNeuralUCB   (Gap:006.0%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(21, 4, 6, 4)
# 🔄 Dynamic Allocation (Initial): (9, 12, 12, 2)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 21188
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_2-Random_Adversarial_OnlineAdaptive-6000_2.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 CPURSUITNEURALUCB   : Reward=4241.91, Efficiency=094.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 EXPNEURALUCB        : Reward=4189.42, Efficiency=092.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 GNEURALUCB          : Reward=3596.43, Efficiency=079.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=4192.63, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 21188
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:005.9%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:6000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(9, 12, 12, 2)
# 🔄 Dynamic Allocation (Initial): (5, 2, 12, 16)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 14153
# ======================================================================================================================================================
# 	🔄 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251111/QuantumExperimentRunner_3-Random_Adversarial_OnlineAdaptive-8000_3.pkl
# 	⚠️ ID mismatch - skipping resume
# 	Getting Oracle Rewards ...
#
# 	🚀ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting GNeuralUCB           in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 CPURSUITNEURALUCB   : Reward=3194.32, Efficiency=053.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 GNEURALUCB          : Reward=3056.58, Efficiency=051.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 EXPNEURALUCB        : Reward=5067.32, Efficiency=084.3% [Retries=1, Failed=0, < Threshold=1, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=3221.55, Efficiency=053.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 14153
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:015.7%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Random]
#
# 	⏱️  Total multi-run time: 16749.7s
# 	Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
# 	RUNNING EXPERIMENTS IN PARALLEL
#
# STARTING PARALLEL MULTI-RUN EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# 	Running 3 experiments with 1 parallel workers
# ============================================================
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(5, 2, 12, 16)
# 🔄 Dynamic Allocation (Initial): (5, 3, 15, 12)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 18102
# ======================================================================================================================================================
# 	⚠️ No saved state found for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251112
# 	Getting Oracle Rewards ...
#
# 	🚀BASELINE (NONE) (NO) EXP 1: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 EXPNEURALUCB        : Reward=1714.54, Efficiency=057.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 CPURSUITNEURALUCB   : Reward=3297.66, Efficiency=096.1% [Retries=1, Failed=0, < Threshold=1, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 GNEURALUCB          : Reward=3033.15, Efficiency=088.4% [Retries=1, Failed=0, < Threshold=1, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=1751.91, Efficiency=051.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 18102
# 	-->🏆 EXP1 Winner:CPursuitNeuralUCB   (Gap:003.9%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:4000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(5, 3, 15, 12)
# 🔄 Dynamic Allocation (Initial): (4, 5, 11, 15)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 17029
# ======================================================================================================================================================
# 	⚠️ No saved state found for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251112
# 	Getting Oracle Rewards ...
#
# 	🚀BASELINE (NONE) (NO) EXP 2: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 CPURSUITNEURALUCB   : Reward=2093.77, Efficiency=048.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 EXPNEURALUCB        : Reward=2030.49, Efficiency=047.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 GNEURALUCB          : Reward=3233.73, Efficiency=075.3% [Retries=1, Failed=0, < Threshold=1, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=2048.06, Efficiency=048.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 17029
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:024.7%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:6000, SCapacity=8000, Alloc=Random]
#
#
#  ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(4, 5, 11, 15)
# 🔄 Dynamic Allocation (Initial): (17, 2, 4, 12)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 16876
# ======================================================================================================================================================
# 	⚠️ No saved state found for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251112
# 	Getting Oracle Rewards ...
#
# 	🚀BASELINE (NONE) (NO) EXP 3: Running 4 models in parallel (max_workers=4)
# 	 ====================================================================================================
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting CPursuitNeuralUCB    in parallel...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting iCPursuitNeuralUCB   in parallel...
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 GNEURALUCB          : Reward=7528.49, Efficiency=098.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 CPURSUITNEURALUCB   : Reward=7467.84, Efficiency=097.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 EXPNEURALUCB        : Reward=7236.44, Efficiency=094.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	⚠️ Excluding: _save_lock, _model_lock, configs, environment, algorithm_configs
# 	EVALUATOR Saved Succesfully
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=7387.77, Efficiency=096.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Random, SC:16000 (Scale=2 x Cap=8000), Seed: 16876
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:001.5%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:8000, SCapacity=8000, Alloc=Random]
#
# 	⏱️  Total multi-run time: 17832.7s
# 	Experiments completed for none
# Scenario 'stochastic' evaluation completed.
# Scenario 'markov' evaluation completed.
# Scenario 'adaptive' evaluation completed.
# Scenario 'onlineadaptive' evaluation completed.
# Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 5111.70
# 	• Winner Avg Gap: 0024.61%
# 	• Winner Avg Reward: 3741.56
# 	• Winner Avg Efficiency: 0075.51%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- GNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	024.6%
# 	Winner Avg Efficiency: 	075.5%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	075.5% Efficiency 	(Won 1/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	072.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	071.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4765.82
# 	• Winner Avg Gap: 0038.55%
# 	• Winner Avg Reward: 2749.89
# 	• Winner Avg Efficiency: 0061.50%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	038.5%
# 	Winner Avg Efficiency: 	061.5%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	061.5% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	051.9% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	051.1% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	050.7% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4952.61
# 	• Winner Avg Gap: 0009.35%
# 	• Winner Avg Reward: 4565.71
# 	• Winner Avg Efficiency: 0090.65%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	009.3%
# 	Winner Avg Efficiency: 	090.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	090.7% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	089.1% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	087.5% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	086.7% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4723.23
# 	• Winner Avg Gap: 0009.84%
# 	• Winner Avg Reward: 4219.89
# 	• Winner Avg Efficiency: 0090.16%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	009.8%
# 	Winner Avg Efficiency: 	090.2%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	090.2% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	080.5% Efficiency 	(Won 2/3 experiments)
# 	• iCPursuitNeuralUCB: 	080.1% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	074.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 5124.64
# 	• Winner Avg Gap: 0012.63%
# 	• Winner Avg Reward: 4598.46
# 	• Winner Avg Efficiency: 0087.37%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	080.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.3% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	065.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (EXPNeuralUCB):
# 	• Stochastic Performance:    	3741.565
# 	• Baseline Performance:      	4598.456
# 	• Performance Retention:     	081.4%
# 	MODERATE:           	Some degradation under realistic network conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	024.6%
# 	Winner Avg Efficiency: 	075.5%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	075.5% Efficiency 	(Won 1/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	072.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	071.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_comparison_T_8000frames_20251112_071218.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	024.6%
# 	Winner Avg Efficiency: 	075.5%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	075.5% Efficiency 	(Won 1/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	072.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	071.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_T_8000frames_20251112_071218.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	038.5%
# 	Winner Avg Efficiency: 	061.5%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	061.5% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	051.9% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	051.1% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	050.7% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_markov_vs_baseline_T_8000frames_20251112_071218.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	009.3%
# 	Winner Avg Efficiency: 	090.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	090.7% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	089.1% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	087.5% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	086.7% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_adaptive_vs_baseline_T_8000frames_20251112_071218.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	009.8%
# 	Winner Avg Efficiency: 	090.2%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	090.2% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	080.5% Efficiency 	(Won 2/3 experiments)
# 	• iCPursuitNeuralUCB: 	080.1% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	074.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_onlineadaptive_vs_baseline_T_8000frames_20251112_071218.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	080.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.3% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	065.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_none_vs_baseline_T_8000frames_20251112_071218.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5111.696
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3624.005
#   • Oracle Efficiency: 71.9%
#   • Oracle Gap: 28.1%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3741.565
#   • Oracle Efficiency: 75.5%
#   • Oracle Gap: 24.6%
#   • Classification: MODERATE
#   ★ WINNER ★
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 3686.641
#   • Oracle Efficiency: 72.3%
#   • Oracle Gap: 27.8%
#   • Classification: MODERATE
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 3691.073
#   • Oracle Efficiency: 73.4%
#   • Oracle Gap: 26.6%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
saved_experiments = viz.save_all_evaluation_results(save_format='both')
# Out:
# ======================================================================
# SAVING EVALUATION RESULTS (Session: 20251112_063422)
# ======================================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 saved_experiments = viz.save_all_evaluation_results(save_format='both')
#
# File ~/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/evaluation/visualizer.py:379, in QuantumEvaluatorVisualizer.save_all_evaluation_results(self, save_format)
#     376 for exp_id in exp_ids:
#     377     exp_results = env_results[exp_id]
# --> 379     saved_info = self.save_experiment_results(
#     380         environment_name=environment,
#     381         experiment_id=exp_id,
#     382         results=exp_results,
#     383         num_runs=num_runs,
#     384         save_format=save_format
#     385     )
#     387     category = saved_info['model_category']
#     388     category_summary[category] += 1
#
# File ~/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/evaluation/visualizer.py:278, in QuantumEvaluatorVisualizer.save_experiment_results(self, environment_name, experiment_id, results, num_runs, model_category, save_format)
#     275         num_runs = 1
#     277 # Create directory with auto-detected category
# --> 278 self.exp_dir, detected_category = self._create_experiment_directory(
#     279     environment_name,
#     280     experiment_id,
#     281     num_runs,
#     282     model_category=model_category,
#     283     models_tested=models_tested
#     284 )
#     286 # Enhanced metadata
#     287 metadata = {
#     288     'environment': environment_name,
#     289     'experiment_id': experiment_id,
#    (...)    298     "allocator_config": self.allocator.get_config() if self.allocator else {}
#     299 }
#
# File ~/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/evaluation/visualizer.py:236, in QuantumEvaluatorVisualizer._create_experiment_directory(self, environment_name, experiment_id, num_runs, model_category, models_tested)
#     227 allocator_type = str(self.allocator) if self.allocator else "None"
#     229 # Build path with category layer
#     230 experiment_dir = (
#     231     self.output_dir /
#     232     "Environments" /
#     233     env_name /
#     234     allocator_type /
#     235     model_category /
# --> 236     f"Experiment_{experiment_id}_{num_runs}_Runs_{self.config._env_params.get('frame_length',100)}frames_{self.session_timestamp}"
#     237 )
#     239 # Create subdirectories
#     240 (experiment_dir / "results").mkdir(parents=True, exist_ok=True)
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
