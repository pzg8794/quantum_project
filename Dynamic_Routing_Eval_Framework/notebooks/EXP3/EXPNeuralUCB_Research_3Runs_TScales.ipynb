# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 3,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 3
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================
#   QUANTUM MAB – CLEAN RESET + FRESH IMPORT PIPELINE
# ============================================================
# This block:
#   ✓ Frees all global model objects
#   ✓ Clears CUDA + Python memory
#   ✓ Reloads all DAQR modules cleanly
#   ✓ Ensures any user can re-run cells safely in Colab
#
# This is the correct shared-drive-safe way to avoid
# stale state, GPU memory leaks, and broken reload logic.
# ============================================================



import subprocess

# os.chdir("/content/drive/Shareddrives/ai_quantum_computing/quantum_project")
# print("📌 Now in:", os.getcwd())
root = os.path.abspath("../..")
# Compute the absolute path of cleanup_state_duplicates.py
cleanup_script = os.path.abspath(f"{root}/cleanup_state_duplicates.py")

print(f"🚿 Running cleanup script at:\n{cleanup_script}\n")

# Execute the script exactly as-is
result = subprocess.run(
    ["python3", cleanup_script],
    text=True,
    capture_output=True
)

print("===== CLEANUP STDOUT =====")
print(result.stdout)

print("===== CLEANUP STDERR =====")
print(result.stderr)

print("🚿 Cleanup finished.")


# ============================================================
# STEP 1 — FULL CLEANUP
# ============================================================
import gc
import torch

def deep_cleanup():
    """
    Remove all instantiated model/evaluator objects from global scope
    and fully clear CPU/GPU memory.
    """
    to_clear = [
        "oracle", "gneuralucb", "expneuralucb",
        "cpursuitneuralucb", "icpursuitneuralucb",
        "evaluator", "results"
    ]

    for name in to_clear:
        if name in globals():
            obj = globals().get(name, None)
            # If a cleanup() method exists, call it
            try:
                if hasattr(obj, "cleanup"):
                    obj.cleanup(verbose=False)
            except:
                pass
            # Remove the variable
            globals().pop(name, None)

    # GPU cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Force Python garbage collector
    gc.collect()

    # Reset default dtype to ensure numerical stability
    torch.set_default_dtype(torch.float32)

    print("✓ Deep cleanup complete (memory cleared)")


deep_cleanup()


# ============================================================
# STEP 2 — CLEAN MODULE RELOAD
# ============================================================
import sys
import os
import importlib

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# ------------------------------------------------------------
# Import DAQR modules
# ------------------------------------------------------------
from daqr.config import experiment_config, gd_backup_manager, local_backup_manager
from daqr.core import network_environment, qubit_allocator
from daqr.algorithms import neural_bandits, predictive_bandits, base_bandit
from daqr.evaluation import multi_run_evaluator, visualizer, experiment_runner

# ------------------------------------------------------------
# Reload modules to ensure a clean environment
# ------------------------------------------------------------
importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(qubit_allocator)
importlib.reload(base_bandit)
importlib.reload(neural_bandits)
importlib.reload(predictive_bandits)
importlib.reload(experiment_runner)
importlib.reload(multi_run_evaluator)
importlib.reload(visualizer)

# ------------------------------------------------------------
# Import specific classes after reloads
# ------------------------------------------------------------
from daqr.config.gd_backup_manager import GoogleDriveBackupManager
from daqr.config.experiment_config import ExperimentConfiguration
from daqr.config.local_backup_manager import LocalBackupManager
from daqr.core.network_environment import *
from daqr.core.qubit_allocator import *
from daqr.algorithms.base_bandit import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.experiment_runner import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully (fresh environment ready)")
# Out:
# 🚿 Running cleanup script at:
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py
#
# ===== CLEANUP STDOUT =====
# Script dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework
# Project root: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework
#
# State roots:
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# ========== STARTING CLEANUP ==========
#
# [CLEANUP] Removing .0 float artifacts from filenames...
# [✓] Float artifacts fixed: 0
#
# [EXTRACT] Processing Random allocator files...
# 	NEW BASE: QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1
#
#    Processing: QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1.pkl
#       ✅ Renamed → QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_(8_10_8_9).pkl
#       ✅ Renamed → /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_(8_10_8_9).pkl
# 	NEW BASE: Oracle(base)_4000-Default_Stochastic_Random-4000
#
#    Processing: Oracle(base)_4000-Default_Stochastic_Random-4000.pkl
#       ✅ Renamed → Oracle_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
#       ✅ Renamed → /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
# 	NEW BASE: EXPUCB(exp3)_4000-Default_Stochastic_Random-4000
#
#    Processing: EXPUCB(exp3)_4000-Default_Stochastic_Random-4000.pkl
#       ✅ Renamed → EXPUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
#       ✅ Renamed → /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
# 	NEW BASE: GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000
#
#    Processing: GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000.pkl
#       ✅ Renamed → GNeuralUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
#       ✅ Renamed → /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
# 	NEW BASE: EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000
#
#    Processing: EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000.pkl
#       ✅ Renamed → EXPNeuralUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
#       ✅ Renamed → /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB_4000-Default_Stochastic_Random-4000_(8_10_8_9).pkl
#
# [✓] Random allocator extraction complete:
#     Renamed: 5
#     Failed: 0
#     Skipped: 3516
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: removed 0 duplicates
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: removed 0 duplicates
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: moved 0 files, removed 0 directories.
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: moved 0 files, removed 0 directories.
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/local_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [DEBUG]   Checking date_dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [DEBUG]   Checking date_dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
# [DEBUG]   Checking date_dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208
# [DEBUG]   → Day folder accepted: day_20251208
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_(8_10_8_9).pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_(8_10_8_9).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_(8_10_8_9).pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_(8_10_8_9).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_2_4000-Random_Adversarial_Adaptive-6000_2_(4_16_7_8).pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_2_4000-Random_Adversarial_Adaptive-6000_2_(4_16_7_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_2_4000-Random_Adversarial_Adaptive-6000_2_(4_16_7_8).pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_2_4000-Random_Adversarial_Adaptive-6000_2_(4_16_7_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_3_16000-Default_Baseline (None)_No-8000_3.pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_3_16000-Default_Baseline (None)_No-8000_3.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_3_16000-Default_Baseline (None)_No-8000_3.pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_3_16000-Default_Baseline (None)_No-8000_3.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_2_8000-Random_Baseline (None)_No-6000_2_(8_6_17_4).pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_2_8000-Random_Baseline (None)_No-6000_2_(8_6_17_4).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_2_8000-Random_Baseline (None)_No-6000_2_(8_6_17_4).pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_2_8000-Random_Baseline (None)_No-6000_2_(8_6_17_4).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_6000-Random_Adversarial_OnlineAdaptive-4000_1_(16_5_8_6).pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_1_6000-Random_Adversarial_OnlineAdaptive-4000_1_(16_5_8_6).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_6000-Random_Adversarial_OnlineAdaptive-4000_1_(16_5_8_6).pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_1_6000-Random_Adversarial_OnlineAdaptive-4000_1_(16_5_8_6).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_6_28000-Default_Adversarial_OnlineAdaptive-14000_6.pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_6_28000-Default_Adversarial_OnlineAdaptive-14000_6.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_6_28000-Default_Adversarial_OnlineAdaptive-14000_6.pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_6_28000-Default_Adversarial_OnlineAdaptive-14000_6.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_8000-ThompsonSampling_Stochastic_Random-4000_1_(9_9_9_8).pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_1_8000-ThompsonSampling_Stochastic_Random-4000_1_(9_9_9_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_8000-ThompsonSampling_Stochastic_Random-4000_1_(9_9_9_8).pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_1_8000-ThompsonSampling_Stochastic_Random-4000_1_(9_9_9_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/MultiRunEvaluator_8000-Dynamic_Adversarial_Markov-4000_2000_8_S2T.pkl
# [DEBUG]         File accepted: MultiRunEvaluator_8000-Dynamic_Adversarial_Markov-4000_2000_8_S2T.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/MultiRunEvaluator_8000-Dynamic_Adversarial_Markov-4000_2000_8_S2T.pkl
# [CORRECTED]    Updated: framework_state/day_20251208/MultiRunEvaluator_8000-Dynamic_Adversarial_Markov-4000_2000_8_S2T.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_2000-Default_Adversarial_Markov-1000_1.pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_1_2000-Default_Adversarial_Markov-1000_1.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_1_2000-Default_Adversarial_Markov-1000_1.pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_1_2000-Default_Adversarial
pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_9_8000-Default_Adversarial_Adaptive-20000_9.pkl
# [DEBUG]         File accepted: QuantumExperimentRunner_9_8000-Default_Adversarial_Adaptive-20000_9.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_9_8000-Default_Adversarial_Adaptive-20000_9.pkl
# [CORRECTED]    Updated: framework_state/day_20251208/QuantumExperimentRunner_9_8000-Default_Adversarial_Adaptive-20000_9.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251208/QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
# [DEBUG]         File accepted: QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
# ...
# [CORRECTED]    Updated: model_state/day_20251208/GNeuralUCB(neural)_6000-Dynamic_Stochastic_Random-4000_(9_9_9_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-ThompsonSampling_Stochastic_Random-8000_(9_9_9_8).pkl
# [DEBUG]         File accepted: iCPursuitNeuralUCB(neural)_16000-ThompsonSampling_Stochastic_Random-8000_(9_9_9_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-ThompsonSampling_Stochastic_Random-8000_(9_9_9_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-ThompsonSampling_Stochastic_Random-8000_(9_9_9_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_9000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]         File accepted: Oracle(base)_9000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_9000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/Oracle(base)_9000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         File accepted: EXPNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/EXPNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_12000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]         File accepted: iCPursuitNeuralUCB(neural)_12000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_12000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/iCPursuitNeuralUCB(neural)_12000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_24000-Random_Baseline _No-12000)_(3_3_3_26).pkl
# [DEBUG]         File accepted: GNeuralUCB(neural)_24000-Random_Baseline _No-12000)_(3_3_3_26).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_24000-Random_Baseline _No-12000)_(3_3_3_26).pkl
# [CORRECTED]    Updated: model_state/day_20251208/GNeuralUCB(neural)_24000-Random_Baseline _No-12000)_(3_3_3_26).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/NeuralUCB_3(neural)_10000-Dynamic-10000.pkl
# [DEBUG]         File accepted: NeuralUCB_3(neural)_10000-Dynamic-10000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/NeuralUCB_3(neural)_10000-Dynamic-10000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/NeuralUCB_3(neural)_10000-Dynamic-10000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/CPursuitNeuralUCB(neural)_36000-Default_Baseline(None)_No-18000.pkl
# [DEBUG]         File accepted: CPursuitNeuralUCB(neural)_36000-Default_Baseline(None)_No-18000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/CPursuitNeuralUCB(neural)_36000-Default_Baseline(None)_No-18000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/CPursuitNeuralUCB(neural)_36000-Default_Baseline(None)_No-18000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_28000-Default_Baseline(None)_No-14000.pkl
# [DEBUG]         File accepted: GNeuralUCB(neural)_28000-Default_Baseline(None)_No-14000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_28000-Default_Baseline(None)_No-14000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/GNeuralUCB(neural)_28000-Default_Baseline(None)_No-14000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         File accepted: Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_10000-Dynamic_Adversarial_Adaptive-10000.pkl
# [DEBUG]         File accepted: EXPNeuralUCB(hybrid)_10000-Dynamic_Adversarial_Adaptive-10000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_10000-Dynamic_Adversarial_Adaptive-10000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/EXPNeuralUCB(hybrid)_10000-Dynamic_Adversarial_Adaptive-10000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-ThompsonSampling_Adversarial_Markov-6000.pkl
# [DEBUG]         File accepted: EXPNeuralUCB(hybrid)_6000-ThompsonSampling_Adversarial_Markov-6000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-ThompsonSampling_Adversarial_Markov-6000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-ThompsonSampling_Adversarial_Markov-6000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/NeuralUCB_1(neural)_16000-Dynamic-6000.pkl
# [DEBUG]         File accepted: NeuralUCB_1(neural)_16000-Dynamic-6000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/NeuralUCB_1(neural)_16000-Dynamic-6000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/NeuralUCB_1(neural)_16000-Dynamic-6000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]         File accepted: EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         File accepted: GNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/GNeuralUCB_10000-Random_Adversarial_OnlineAdaptive-10000)_(4_6_17_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_6000-Dynamic_Stochastic_Random-4000_(9_9_9_8).pkl
# [DEBUG]         File accepted: iCPursuitNeuralUCB(neural)_6000-Dynamic_Stochastic_Random-4000_(9_9_9_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_6000-Dynamic_Stochastic_Random-4000_(9_9_9_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/iCPursuitNeuralUCB(neural)_6000-Dynamic_Stochastic_Random-4000_(9_9_9_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/CPursuitNeuralUCB(neural)_12000-Dynamic_Adversarial_Adaptive-6000.pkl
# [DEBUG]         File accepted: CPursuitNeuralUCB(neural)_12000-Dynamic_Adversarial_Adaptive-6000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/CPursuitNeuralUCB(neural)_12000-Dynamic_Adversarial_Adaptive-6000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/CPursuitNeuralUCB(neural)_12000-Dynamic_Adversarial_Adaptive-6000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_14000-Dynamic_Stochastic_Random-14000_(9_9_9_8).pkl
# [DEBUG]         File accepted: GNeuralUCB(neural)_14000-Dynamic_Stochastic_Random-14000_(9_9_9_8).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/GNeuralUCB(neural)_14000-Dynamic_Stochastic_Random-14000_(9_9_9_8).pkl
# [CORRECTED]    Updated: model_state/day_20251208/GNeuralUCB(neural)_14000-Dynamic_Stochastic_Random-14000_(9_9_9_8).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-Dynamic_Adversarial_OnlineAdaptive-16000.pkl
# [DEBUG]         File accepted: iCPursuitNeuralUCB(neural)_16000-Dynamic_Adversarial_OnlineAdaptive-16000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-Dynamic_Adversarial_OnlineAdaptive-16000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/iCPursuitNeuralUCB(neural)_16000-Dynamic_Adversarial_OnlineAdaptive-16000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_8000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]         File accepted: Oracle(base)_8000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle(base)_8000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/Oracle(base)_8000-ThompsonSampling_Adversarial_OnlineAdaptive-12000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-Default_Baseline(None)_No-4000.pkl
# [DEBUG]         File accepted: EXPNeuralUCB(hybrid)_6000-Default_Baseline(None)_No-4000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-Default_Baseline(None)_No-4000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/EXPNeuralUCB(hybrid)_6000-Default_Baseline(None)_No-4000.pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle_18000-Random_Adversarial_Adaptive-12000)_(3_22_8_2).pkl
# [DEBUG]         File accepted: Oracle_18000-Random_Adversarial_Adaptive-12000)_(3_22_8_2).pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/Oracle_18000-Random_Adversarial_Adaptive-12000)_(3_22_8_2).pkl
# [CORRECTED]    Updated: model_state/day_20251208/Oracle_18000-Random_Adversarial_Adaptive-12000)_(3_22_8_2).pkl
# [DEBUG]       Inspect file/dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_8000-Default_Baseline (None)_No-12000.pkl
# [DEBUG]         File accepted: iCPursuitNeuralUCB(neural)_8000-Default_Baseline (None)_No-12000.pkl
# [DEBUG]         Abs path: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251208/iCPursuitNeuralUCB(neural)_8000-Default_Baseline (None)_No-12000.pkl
# [CORRECTED]    Updated: model_state/day_20251208/iCPursuitNeuralUCB(neural)_8000-Default_Baseline (None)_No-12000.pkl
# [✓] Registry updated: 3533 corrected, 0 added
# [INFO] Registry not found, skipping update: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/backup_registry.json
#
# ========== DONE ==========
#
#
# ===== CLEANUP STDERR =====
#
# 🚿 Cleanup finished.
# ✓ Deep cleanup complete (memory cleared)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully (fresh environment ready)

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration

# Create allocator with correct parameters
allocator = ThompsonSamplingAllocator(
    total_qubits=35,           # Total qubits available (8+10+8+9=35)
    num_routes=4,              # Number of routes
    min_qubits_per_route=2     # Minimum qubits per route
)
# AFTER (UCB - Dynamic):

# allocator = DynamicQubitAllocator(              # ← Change class name
#     total_qubits=35,           
#     num_routes=4,              
#     min_qubits_per_route=2,
#     exploration_bonus=2.0      # ← NEW parameter (optional, default is 2.0)
# )



# Fully random (exploration only)
# allocator = RandomQubitAllocator(epsilon=1.0, seed=42)

# # 50-50 mix of random and baseline
# random_50 = RandomQubitAllocator(epsilon=0.5, seed=42)

# # Mostly baseline with occasional exploration (epsilon-greedy style)
# random_10 = RandomQubitAllocator(epsilon=0.1, seed=42)

# # Decaying randomness (start exploratory, become deterministic)
# decaying = RandomQubitAllocator(
#     epsilon=1.0,           # Start fully random
#     epsilon_decay=0.99,    # Decay 1% per timestep
#     min_epsilon=0.05,      # Eventually stabilize at 5% exploration
#     seed=42
# )

# # Fully deterministic (acts like fixed allocator)
# deterministic = RandomQubitAllocator(epsilon=0.0, seed=42)

# models = ['Oracle', 'GNeuralUCB', 'EXPNeuralUCB']
models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=False, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=1, base_capacity=False, overwrite=False) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1T_20251208_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1T_20251208_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15759
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2505.36, Efficiency=090.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1979.86, Efficiency=071.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXPNeuralUCB already processed
# 	EXPNeuralUCB already processed
# 	EXP 1 EXPNEURALUCB        : Reward=1655.92, Efficiency=059.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15759
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:4000, SCapacity=4000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 6000 frames (CAPACITY:6000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 14435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3791.88, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3171.64, Efficiency=076.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3212.20, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 14435
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=6000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:8000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 18460
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4376.03, Efficiency=079.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4279.88, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5055.57, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 18460
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=8000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 429.5s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2062.40, Efficiency=074.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1907.75, Efficiency=069.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2387.89, Efficiency=086.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15940
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:013.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 6000 frames (CAPACITY:6000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 17715
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3532.82, Efficiency=085.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3083.16, Efficiency=074.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3522.85, Efficiency=085.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 17715
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:014.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:6000, SCapacity=6000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:8000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 18883
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4929.62, Efficiency=089.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4178.09, Efficiency=075.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4984.91, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 18883
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 381.8s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 22267
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2513.97, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2003.10, Efficiency=072.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2364.59, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 22267
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.1%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 6000 frames (CAPACITY:6000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 16499
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3860.85, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3180.92, Efficiency=076.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3259.84, Efficiency=078.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 16499
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:007.0%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:6000, SCapacity=6000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:8000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 14932
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4667.84, Efficiency=084.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4417.79, Efficiency=079.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4996.83, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 14932
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 389.5s
# Experiments completed for adaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: ONLINE ADAPTIVE ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ONLINEADAPTIVE
# Category: Online Adaptive (Real-time Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 19265
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2137.43, Efficiency=077.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1905.99, Efficiency=069.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2165.17, Efficiency=078.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 19265
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:021.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 6000 frames (CAPACITY:6000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 14478
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3708.35, Efficiency=089.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3110.98, Efficiency=075.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3555.87, Efficiency=086.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 14478
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:010.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:6000, SCapacity=6000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:8000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 16294
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4633.81, Efficiency=083.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4688.90, Efficiency=084.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4953.92, Efficiency=088.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 16294
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:011.1%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 408.5s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15723
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2257.10, Efficiency=081.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2151.49, Efficiency=077.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2553.16, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:4000 (Scale=1 x Cap=4000), Seed: 15723
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:008.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:4000, SCapacity=4000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 6000 frames (CAPACITY:6000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 15195
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3504.62, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3431.61, Efficiency=082.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=4044.15, Efficiency=096.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:6000 (Scale=1 x Cap=6000), Seed: 15195
# 	-->🏆 EXP2 Winner:EXPNeuralUCB        (Gap:003.3%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:6000, SCapacity=6000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:8000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 22086
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=5108.08, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4645.40, Efficiency=083.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5363.51, Efficiency=096.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=1 x Cap=8000), Seed: 22086
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:003.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:8000, SCapacity=8000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 427.2s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4143.38
# 	• Winner Avg Gap: 0012.86%
# 	• Winner Avg Reward: 3557.76
# 	• Winner Avg Efficiency: 0087.14%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4133.79
# 	• Winner Avg Gap: 0012.56%
# 	• Winner Avg Reward: 3631.88
# 	• Winner Avg Efficiency: 0087.44%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4148.05
# 	• Winner Avg Gap: 0010.55%
# 	• Winner Avg Reward: 3680.88
# 	• Winner Avg Efficiency: 0089.45%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4150.75
# 	• Winner Avg Gap: 0015.41%
# 	• Winner Avg Reward: 3558.32
# 	• Winner Avg Efficiency: 0084.59%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0005.14%
# 	• Winner Avg Reward: 3986.94
# 	• Winner Avg Efficiency: 0094.86%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (GNeuralUCB):
# 	• Stochastic Performance:    	3557.759
# 	• Baseline Performance:      	3986.938
# 	• Performance Retention:     	089.2%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenario_performance(scenario=FRAMEWORK_CONFIG['main_env'])
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251208_213532.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251208_213532.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251208_213532.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251208_213532.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251208_213532.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251208_213532.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4143.383
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3557.759
#   • Oracle Efficiency: 87.1%
#   • Oracle Gap: 12.9%
#   • Classification: GOOD
#   ★ WINNER ★
#
# EXPUCB:
#   • Stochastic Performance: 3143.793
#   • Oracle Efficiency: 75.2%
#   • Oracle Gap: 24.8%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3307.898
#   • Oracle Efficiency: 76.3%
#   • Oracle Gap: 23.7%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
# saved_experiments = viz.save_all_evaluation_results(save_format='both')


models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=False, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=1.5, base_capacity=False, overwrite=False) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5T_20251208_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5T_20251208_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 6000.0 frames (CAPACITY:4000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15759
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2505.36, Efficiency=090.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1979.86, Efficiency=071.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXPNeuralUCB already processed
# 	EXPNeuralUCB already processed
# 	EXP 1 EXPNEURALUCB        : Reward=1655.92, Efficiency=059.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=6000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15759
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:4000, SCapacity=6000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 9000.0 frames (CAPACITY:6000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 14435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3791.88, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3171.64, Efficiency=076.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3212.20, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 14435
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=9000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 12000.0 frames (CAPACITY:8000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 18460
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4376.03, Efficiency=079.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4279.88, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5055.57, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 18460
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=12000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 427.6s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 6000.0 frames (CAPACITY:4000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2062.40, Efficiency=074.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1907.75, Efficiency=069.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2387.89, Efficiency=086.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15940
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:013.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 9000.0 frames (CAPACITY:6000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 17715
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3532.82, Efficiency=085.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3083.16, Efficiency=074.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3522.85, Efficiency=085.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 17715
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:014.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:6000, SCapacity=9000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 12000.0 frames (CAPACITY:8000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 18883
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4929.62, Efficiency=089.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4178.09, Efficiency=075.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4984.91, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 18883
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:8000, SCapacity=12000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 412.1s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 6000.0 frames (CAPACITY:4000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 22267
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2513.97, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2003.10, Efficiency=072.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2364.59, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 22267
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.1%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:4000, SCapacity=6000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 9000.0 frames (CAPACITY:6000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 16499
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3860.85, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3180.92, Efficiency=076.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3259.84, Efficiency=078.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 16499
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:007.0%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:6000, SCapacity=9000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 12000.0 frames (CAPACITY:8000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 14932
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4667.84, Efficiency=084.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4417.79, Efficiency=079.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4996.83, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 14932
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:8000, SCapacity=12000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 418.9s
# Experiments completed for adaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: ONLINE ADAPTIVE ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ONLINEADAPTIVE
# Category: Online Adaptive (Real-time Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 6000.0 frames (CAPACITY:4000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 19265
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2137.43, Efficiency=077.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1905.99, Efficiency=069.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2165.17, Efficiency=078.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 19265
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:021.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:4000, SCapacity=6000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 9000.0 frames (CAPACITY:6000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 14478
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3708.35, Efficiency=089.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3110.98, Efficiency=075.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3555.87, Efficiency=086.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 14478
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:010.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:6000, SCapacity=9000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 12000.0 frames (CAPACITY:8000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 16294
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4633.81, Efficiency=083.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4688.90, Efficiency=084.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4953.92, Efficiency=088.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 16294
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:011.1%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:8000, SCapacity=12000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 431.3s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 6000.0 frames (CAPACITY:4000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15723
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2257.10, Efficiency=081.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2151.49, Efficiency=077.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2553.16, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:6000.0 (Scale=1.5 x Cap=4000), Seed: 15723
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:008.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:4000, SCapacity=6000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 9000.0 frames (CAPACITY:6000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 15195
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3504.62, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3431.61, Efficiency=082.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=4044.15, Efficiency=096.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=9000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:9000.0 (Scale=1.5 x Cap=6000), Seed: 15195
# 	-->🏆 EXP2 Winner:EXPNeuralUCB        (Gap:003.3%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:6000, SCapacity=9000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 12000.0 frames (CAPACITY:8000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 22086
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=5108.08, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4645.40, Efficiency=083.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5363.51, Efficiency=096.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:12000.0 (Scale=1.5 x Cap=8000), Seed: 22086
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:003.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:8000, SCapacity=12000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 450.4s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4143.38
# 	• Winner Avg Gap: 0012.86%
# 	• Winner Avg Reward: 3557.76
# 	• Winner Avg Efficiency: 0087.14%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4133.79
# 	• Winner Avg Gap: 0012.56%
# 	• Winner Avg Reward: 3631.88
# 	• Winner Avg Efficiency: 0087.44%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4148.05
# 	• Winner Avg Gap: 0010.55%
# 	• Winner Avg Reward: 3680.88
# 	• Winner Avg Efficiency: 0089.45%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4150.75
# 	• Winner Avg Gap: 0015.41%
# 	• Winner Avg Reward: 3558.32
# 	• Winner Avg Efficiency: 0084.59%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0005.14%
# 	• Winner Avg Reward: 3986.94
# 	• Winner Avg Efficiency: 0094.86%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (GNeuralUCB):
# 	• Stochastic Performance:    	3557.759
# 	• Baseline Performance:      	3986.938
# 	• Performance Retention:     	089.2%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenario_performance(scenario=FRAMEWORK_CONFIG['main_env'])
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251208_221816.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251208_221816.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251208_221816.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251208_221816.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251208_221816.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251208_221816.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4143.383
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3557.759
#   • Oracle Efficiency: 87.1%
#   • Oracle Gap: 12.9%
#   • Classification: GOOD
#   ★ WINNER ★
#
# EXPUCB:
#   • Stochastic Performance: 3143.793
#   • Oracle Efficiency: 75.2%
#   • Oracle Gap: 24.8%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3307.898
#   • Oracle Efficiency: 76.3%
#   • Oracle Gap: 23.7%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
# saved_experiments = viz.save_all_evaluation_results(save_format='both')


models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=False, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=False, overwrite=False) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (6586 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2T_20251208_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2T_20251208_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15759
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2505.36, Efficiency=090.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1979.86, Efficiency=071.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXPNeuralUCB already processed
# 	EXPNeuralUCB already processed
# 	EXP 1 EXPNEURALUCB        : Reward=1655.92, Efficiency=059.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15759
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 14435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3791.88, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3171.64, Efficiency=076.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3212.20, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 14435
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 18460
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4376.03, Efficiency=079.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4279.88, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.5]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5055.57, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 18460
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:008.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 428.5s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2062.40, Efficiency=074.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1907.75, Efficiency=069.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2387.89, Efficiency=086.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15940
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:013.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 17715
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3532.82, Efficiency=085.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3083.16, Efficiency=074.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3522.85, Efficiency=085.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 17715
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:014.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 18883
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4929.62, Efficiency=089.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4178.09, Efficiency=075.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4984.91, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 18883
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 396.1s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 22267
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2513.97, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2003.10, Efficiency=072.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2364.59, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 22267
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.1%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 16499
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3860.85, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3180.92, Efficiency=076.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3259.84, Efficiency=078.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 2: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 16499
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:007.0%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 14932
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4667.84, Efficiency=084.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4417.79, Efficiency=079.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4996.83, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
#
# ADVERSARIAL (ADAPTIVE) EXP 3: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 14932
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.6%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 367.2s
# Experiments completed for adaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: ONLINE ADAPTIVE ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ONLINEADAPTIVE
# Category: Online Adaptive (Real-time Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 19265
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2137.43, Efficiency=077.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=1905.99, Efficiency=069.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2165.17, Efficiency=078.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 1: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 19265
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:021.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 14478
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3708.35, Efficiency=089.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3110.98, Efficiency=075.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=3555.87, Efficiency=086.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 2: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 14478
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:010.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 16294
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=4633.81, Efficiency=083.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4688.90, Efficiency=084.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.5]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=4953.92, Efficiency=088.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 3: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 16294
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:011.1%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 378.8s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15723
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=2257.10, Efficiency=081.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPUCB              : Reward=2151.49, Efficiency=077.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=2553.16, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15723
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:008.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 15195
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=3504.62, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPUCB              : Reward=3431.61, Efficiency=082.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=4044.15, Efficiency=096.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 15195
# 	-->🏆 EXP2 Winner:EXPNeuralUCB        (Gap:003.3%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 22086
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=5108.08, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPUCB               in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPUCB              : Reward=4645.40, Efficiency=083.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.5]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5363.51, Efficiency=096.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 22086
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:003.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# Total experiment time: 385.6s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4143.38
# 	• Winner Avg Gap: 0012.86%
# 	• Winner Avg Reward: 3557.76
# 	• Winner Avg Efficiency: 0087.14%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4133.79
# 	• Winner Avg Gap: 0012.56%
# 	• Winner Avg Reward: 3631.88
# 	• Winner Avg Efficiency: 0087.44%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4148.05
# 	• Winner Avg Gap: 0010.55%
# 	• Winner Avg Reward: 3680.88
# 	• Winner Avg Efficiency: 0089.45%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4150.75
# 	• Winner Avg Gap: 0015.41%
# 	• Winner Avg Reward: 3558.32
# 	• Winner Avg Efficiency: 0084.59%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0005.14%
# 	• Winner Avg Reward: 3986.94
# 	• Winner Avg Efficiency: 0094.86%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (GNeuralUCB):
# 	• Stochastic Performance:    	3557.759
# 	• Baseline Performance:      	3986.938
# 	• Performance Retention:     	089.2%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenario_performance(scenario=FRAMEWORK_CONFIG['main_env'])
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251208_225224.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.9%
# 	Winner Avg Efficiency: 	087.1%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	087.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251208_225224.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	012.6%
# 	Winner Avg Efficiency: 	087.4%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.4% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.2% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251208_225224.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	010.5%
# 	Winner Avg Efficiency: 	089.5%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	089.5% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	084.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251208_225224.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	015.4%
# 	Winner Avg Efficiency: 	084.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	084.6% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	083.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	076.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251208_225224.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	005.1%
# 	Winner Avg Efficiency: 	094.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	094.9% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	085.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	080.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251208_225224.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4143.383
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3557.759
#   • Oracle Efficiency: 87.1%
#   • Oracle Gap: 12.9%
#   • Classification: GOOD
#   ★ WINNER ★
#
# EXPUCB:
#   • Stochastic Performance: 3143.793
#   • Oracle Efficiency: 75.2%
#   • Oracle Gap: 24.8%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3307.898
#   • Oracle Efficiency: 76.3%
#   • Oracle Gap: 23.7%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
