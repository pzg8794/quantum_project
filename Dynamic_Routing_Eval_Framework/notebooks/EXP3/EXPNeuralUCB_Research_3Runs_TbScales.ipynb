# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 3,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (9908 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (9908 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 3
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================
#   QUANTUM MAB – CLEAN RESET + FRESH IMPORT PIPELINE
# ============================================================
# This block:
#   ✓ Frees all global model objects
#   ✓ Clears CUDA + Python memory
#   ✓ Reloads all DAQR modules cleanly
#   ✓ Ensures any user can re-run cells safely in Colab
#
# This is the correct shared-drive-safe way to avoid
# stale state, GPU memory leaks, and broken reload logic.
# ============================================================



import subprocess

# os.chdir("/content/drive/Shareddrives/ai_quantum_computing/quantum_project")
# print("📌 Now in:", os.getcwd())
root = os.path.abspath("../..")
# Compute the absolute path of cleanup_state_duplicates.py
cleanup_script = os.path.abspath(f"{root}/cleanup_state_duplicates.py")

print(f"🚿 Running cleanup script at:\n{cleanup_script}\n")

# Execute the script exactly as-is
result = subprocess.run(
    ["python3", cleanup_script],
    text=True,
    capture_output=True
)

print("===== CLEANUP STDOUT =====")
print(result.stdout)

print("===== CLEANUP STDERR =====")
print(result.stderr)

print("🚿 Cleanup finished.")


# ============================================================
# STEP 1 — FULL CLEANUP
# ============================================================
import gc
import torch

def deep_cleanup():
    """
    Remove all instantiated model/evaluator objects from global scope
    and fully clear CPU/GPU memory.
    """
    to_clear = [
        "oracle", "gneuralucb", "expneuralucb",
        "cpursuitneuralucb", "icpursuitneuralucb",
        "evaluator", "results"
    ]

    for name in to_clear:
        if name in globals():
            obj = globals().get(name, None)
            # If a cleanup() method exists, call it
            try:
                if hasattr(obj, "cleanup"):
                    obj.cleanup(verbose=False)
            except:
                pass
            # Remove the variable
            globals().pop(name, None)

    # GPU cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Force Python garbage collector
    gc.collect()

    # Reset default dtype to ensure numerical stability
    torch.set_default_dtype(torch.float32)

    print("✓ Deep cleanup complete (memory cleared)")


deep_cleanup()


# ============================================================
# STEP 2 — CLEAN MODULE RELOAD
# ============================================================
import sys
import os
import importlib

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# ------------------------------------------------------------
# Import DAQR modules
# ------------------------------------------------------------
from daqr.config import experiment_config, gd_backup_manager, local_backup_manager
from daqr.core import network_environment, qubit_allocator
from daqr.algorithms import neural_bandits, predictive_bandits, base_bandit
from daqr.evaluation import multi_run_evaluator, visualizer, experiment_runner

# ------------------------------------------------------------
# Reload modules to ensure a clean environment
# ------------------------------------------------------------
importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(qubit_allocator)
importlib.reload(base_bandit)
importlib.reload(neural_bandits)
importlib.reload(predictive_bandits)
importlib.reload(experiment_runner)
importlib.reload(multi_run_evaluator)
importlib.reload(visualizer)

# ------------------------------------------------------------
# Import specific classes after reloads
# ------------------------------------------------------------
from daqr.config.gd_backup_manager import GoogleDriveBackupManager
from daqr.config.experiment_config import ExperimentConfiguration
from daqr.config.local_backup_manager import LocalBackupManager
from daqr.core.network_environment import *
from daqr.core.qubit_allocator import *
from daqr.algorithms.base_bandit import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.experiment_runner import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully (fresh environment ready)")
# Out:
# 🚿 Running cleanup script at:
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py
#
# ===== CLEANUP STDOUT =====
# Script dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework
# Project root: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework
#
# State roots:
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
# MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1T_EXP3.pkl
# MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
# MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1T_EXP3.pkl
# MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1Tb_EXP3.pkl
# MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5T_EXP3.pkl
# MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
# MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_5_S1_5T_EXP3.pkl
# MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_5_S1_5Tb_EXP3.pkl
# MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2T_EXP3.pkl
# MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
# MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2T_EXP3.pkl
# MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2Tb_EXP3.pkl
#
# ================================================================================
# CONVERTING KEY STATE FILES TO CSV
# ================================================================================
# Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/
# Keyword: (?=.*MultiRunEvaluator)(?=.*EXP3\.pkl)
# Extension: .pkl
# CONVERTING STATE FILES TO CSV
# Found 12 state files
#
# ================================================================================
# Loading: MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1T_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.24815424005807,
#     "EXPUCB": 73.20690568446642,
#     "EXPNeuralUCB": 87.44089485186156
#   },
#   "oracle_avg_reward": 4133.78755992771,
#   "avg_gap": 12.559105148138443,
#   "avg_reward": 3631.8823644026147,
#   "avg_efficiency": 87.44089485186156
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.24815424005807,
#     "EXPUCB": 73.20690568446642,
#     "EXPNeuralUCB": 87.44089485186156
#   },
#   "oracle_avg_reward": 4133.78755992771,
#   "avg_gap": 12.559105148138443,
#   "avg_reward": 3631.8823644026147,
#   "avg_efficiency": 87.44089485186156
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.13813020620796,
#     "EXPUCB": 75.22832911558383,
#     "EXPNeuralUCB": 76.32739984572538
#   },
#   "oracle_avg_reward": 4143.383349848041,
#   "avg_gap": 12.861869793792033,
#   "avg_reward": 3557.7587108950283,
#   "avg_efficiency": 87.13813020620796
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.13813020620796,
#     "EXPUCB": 75.22832911558383,
#     "EXPNeuralUCB": 76.32739984572538
#   },
#   "oracle_avg_reward": 4143.383349848041,
#   "avg_gap": 12.861869793792033,
#   "avg_reward": 3557.7587108950283,
#   "avg_efficiency": 87.13813020620796
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.45305369064859,
#     "EXPUCB": 76.32819442605785,
#     "EXPNeuralUCB": 84.81249639460822
#   },
#   "oracle_avg_reward": 4148.048758844175,
#   "avg_gap": 10.546946309351398,
#   "avg_reward": 3680.883589737934,
#   "avg_efficiency": 89.45305369064859
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.45305369064859,
#     "EXPUCB": 76.32819442605785,
#     "EXPNeuralUCB": 84.81249639460822
#   },
#   "oracle_avg_reward": 4148.048758844175,
#   "avg_gap": 10.546946309351398,
#   "avg_reward": 3680.883589737934,
#   "avg_efficiency": 89.45305369064859
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.56524729450639,
#     "EXPUCB": 76.26686990781093,
#     "EXPNeuralUCB": 84.58584840338881
#   },
#   "oracle_avg_reward": 4150.751861906764,
#   "avg_gap": 15.414151596611186,
#   "avg_reward": 3558.3196057573296,
#   "avg_efficiency": 84.58584840338881
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.56524729450639,
#     "EXPUCB": 76.26686990781093,
#     "EXPNeuralUCB": 84.58584840338881
#   },
#   "oracle_avg_reward": 4150.751861906764,
#   "avg_gap": 15.414151596611186,
#   "avg_reward": 3558.3196057573296,
#   "avg_efficiency": 84.58584840338881
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 85.48510262807109,
#     "EXPUCB": 80.87317360518836,
#     "EXPNeuralUCB": 94.8554211911959
#   },
#   "oracle_avg_reward": 4180.579206045788,
#   "avg_gap": 5.1445788088040985,
#   "avg_reward": 3986.938356726447,
#   "avg_efficiency": 94.8554211911959
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 85.48510262807109,
#     "EXPUCB": 80.87317360518836,
#     "EXPNeuralUCB": 94.8554211911959
#   },
#   "oracle_avg_reward": 4180.579206045788,
#   "avg_gap": 5.1445788088040985,
#   "avg_reward": 3986.938356726447,
#   "avg_efficiency": 94.8554211911959
# }
#   ✅ MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1T_EXP3.pkl
#      → MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1T_EXP3.csv
#      → 45 records, 5 scenarios, 3 models
# Loading: MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.8710728073068,
#     "EXPUCB": 73.20550661505308,
#     "EXPNeuralUCB": 85.12074911714453
#   },
#   "oracle_avg_reward": 4134.03612112887,
#   "avg_gap": 14.879250882855473,
#   "avg_reward": 3565.0726727545284,
#   "avg_efficiency": 85.12074911714453
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.8710728073068,
#     "EXPUCB": 73.20550661505308,
#     "EXPNeuralUCB": 85.12074911714453
#   },
#   "oracle_avg_reward": 4134.03612112887,
#   "avg_gap": 14.879250882855473,
#   "avg_reward": 3565.0726727545284,
#   "avg_efficiency": 85.12074911714453
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 86.76794069101356,
#     "EXPUCB": 76.38310792459471,
#     "EXPNeuralUCB": 88.11811542831227
#   },
#   "oracle_avg_reward": 4140.97677197254,
#   "avg_gap": 11.88188457168774,
#   "avg_reward": 3697.733434226029,
#   "avg_efficiency": 88.11811542831227
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 86.76794069101356,
#     "EXPUCB": 76.38310792459471,
#     "EXPNeuralUCB": 88.11811542831227
#   },
#   "oracle_avg_reward": 4140.97677197254,
#   "avg_gap": 11.88188457168774,
#   "avg_reward": 3697.733434226029,
#   "avg_efficiency": 88.11811542831227
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 82.33264770614666,
#     "EXPUCB": 74.83595227358536,
#     "EXPNeuralUCB": 83.88688257267741
#   },
#   "oracle_avg_reward": 4141.834728815221,
#   "avg_gap": 16.11311742732259,
#   "avg_reward": 3538.0409652384024,
#   "avg_efficiency": 83.88688257267741
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 82.33264770614666,
#     "EXPUCB": 74.83595227358536,
#     "EXPNeuralUCB": 83.88688257267741
#   },
#   "oracle_avg_reward": 4141.834728815221,
#   "avg_gap": 16.11311742732259,
#   "avg_reward": 3538.0409652384024,
#   "avg_efficiency": 83.88688257267741
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 75.58943908790754,
#     "EXPUCB": 74.35773697028993,
#     "EXPNeuralUCB": 88.8214049517034
#   },
#   "oracle_avg_reward": 4123.472270079641,
#   "avg_gap": 11.178595048296609,
#   "avg_reward": 3655.191215999712,
#   "avg_efficiency": 88.8214049517034
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 75.58943908790754,
#     "EXPUCB": 74.35773697028993,
#     "EXPNeuralUCB": 88.8214049517034
#   },
#   "oracle_avg_reward": 4123.472270079641,
#   "avg_gap": 11.178595048296609,
#   "avg_reward": 3655.191215999712,
#   "avg_efficiency": 88.8214049517034
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 92.57656743850613,
#     "EXPUCB": 81.04250954176712,
#     "EXPNeuralUCB": 77.5012821429724
#   },
#   "oracle_avg_reward": 4180.579206045788,
#   "avg_gap": 7.423432561493868,
#   "avg_reward": 3940.48370016021,
#   "avg_efficiency": 92.57656743850613
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 92.57656743850613,
#     "EXPUCB": 81.04250954176712,
#     "EXPNeuralUCB": 77.5012821429724
#   },
#   "oracle_avg_reward": 4180.579206045788,
#   "avg_gap": 7.423432561493868,
#   "avg_reward": 3940.48370016021,
#   "avg_efficiency": 92.57656743850613
# }
#   ✅ MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
#      → MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.csv
#      → 45 records, 5 scenarios, 3 models
# Loading: MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1T_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 86.55110536556711,
#     "EXPUCB": 75.94706532969143,
#     "EXPNeuralUCB": 89.08250386605387
#   },
#   "oracle_avg_reward": 5512.77313167473,
#   "avg_gap": 10.91749613394614,
#   "avg_reward": 4955.419511480888,
#   "avg_efficiency": 89.08250386605387
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 86.55110536556711,
#     "EXPUCB": 75.94706532969143,
#     "EXPNeuralUCB": 89.08250386605387
#   },
#   "oracle_avg_reward": 5512.77313167473,
#   "avg_gap": 10.91749613394614,
#   "avg_reward": 4955.419511480888,
#   "avg_efficiency": 89.08250386605387
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.39705825070504,
#     "EXPUCB": 77.59628738756153,
#     "EXPNeuralUCB": 82.95942375444562
#   },
#   "oracle_avg_reward": 5523.53568150827,
#   "avg_gap": 10.602941749294953,
#   "avg_reward": 4954.3326725891775,
#   "avg_efficiency": 89.39705825070504
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.39705825070504,
#     "EXPUCB": 77.59628738756153,
#     "EXPNeuralUCB": 82.95942375444562
#   },
#   "oracle_avg_reward": 5523.53568150827,
#   "avg_gap": 10.602941749294953,
#   "avg_reward": 4954.3326725891775,
#   "avg_efficiency": 89.39705825070504
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 90.73432026891078,
#     "EXPUCB": 78.25154053256816,
#     "EXPNeuralUCB": 87.86699064813267
#   },
#   "oracle_avg_reward": 5525.7480263752,
#   "avg_gap": 9.265679731089227,
#   "avg_reward": 5022.941375582875,
#   "avg_efficiency": 90.73432026891078
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 90.73432026891078,
#     "EXPUCB": 78.25154053256816,
#     "EXPNeuralUCB": 87.86699064813267
#   },
#   "oracle_avg_reward": 5525.7480263752,
#   "avg_gap": 9.265679731089227,
#   "avg_reward": 5022.941375582875,
#   "avg_efficiency": 90.73432026891078
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.2760982506758,
#     "EXPUCB": 79.56146952620067,
#     "EXPNeuralUCB": 89.62886049743
#   },
#   "oracle_avg_reward": 5550.933490082589,
#   "avg_gap": 10.371139502569994,
#   "avg_reward": 5108.414566970168,
#   "avg_efficiency": 89.62886049743
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.2760982506758,
#     "EXPUCB": 79.56146952620067,
#     "EXPNeuralUCB": 89.62886049743
#   },
#   "oracle_avg_reward": 5550.933490082589,
#   "avg_gap": 10.371139502569994,
#   "avg_reward": 5108.414566970168,
#   "avg_efficiency": 89.62886049743
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 90.67909291567352,
#     "EXPUCB": 83.06754499601912,
#     "EXPNeuralUCB": 94.06500387073193
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 5.934996129268074,
#   "avg_reward": 5223.286899792654,
#   "avg_efficiency": 94.06500387073193
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 90.67909291567352,
#     "EXPUCB": 83.06754499601912,
#     "EXPNeuralUCB": 94.06500387073193
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 5.934996129268074,
#   "avg_reward": 5223.286899792654,
#   "avg_efficiency": 94.06500387073193
# }
#   ✅ MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1T_EXP3.pkl
#      → MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1T_EXP3.csv
#      → 75 records, 5 scenarios, 3 models
# Loading: MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1Tb_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 85.56844198457961,
#     "EXPUCB": 75.86612842981955,
#     "EXPNeuralUCB": 85.36521902076609
#   },
#   "oracle_avg_reward": 5512.437574053166,
#   "avg_gap": 14.43155801542039,
#   "avg_reward": 4742.679765072344,
#   "avg_efficiency": 85.56844198457961
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 85.56844198457961,
#     "EXPUCB": 75.86612842981955,
#     "EXPNeuralUCB": 85.36521902076609
#   },
#   "oracle_avg_reward": 5512.437574053166,
#   "avg_gap": 14.43155801542039,
#   "avg_reward": 4742.679765072344,
#   "avg_efficiency": 85.56844198457961
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.37511790006546,
#     "EXPUCB": 77.99783656529303,
#     "EXPNeuralUCB": 85.678538319838
#   },
#   "oracle_avg_reward": 5523.957811138471,
#   "avg_gap": 14.321461680161999,
#   "avg_reward": 4679.416178186971,
#   "avg_efficiency": 85.678538319838
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.37511790006546,
#     "EXPUCB": 77.99783656529303,
#     "EXPNeuralUCB": 85.678538319838
#   },
#   "oracle_avg_reward": 5523.957811138471,
#   "avg_gap": 14.321461680161999,
#   "avg_reward": 4679.416178186971,
#   "avg_efficiency": 85.678538319838
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.92219012295938,
#     "EXPUCB": 77.172481810205,
#     "EXPNeuralUCB": 84.76810481481415
#   },
#   "oracle_avg_reward": 5523.86517527643,
#   "avg_gap": 15.231895185185852,
#   "avg_reward": 4720.91591323697,
#   "avg_efficiency": 84.76810481481415
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.92219012295938,
#     "EXPUCB": 77.172481810205,
#     "EXPNeuralUCB": 84.76810481481415
#   },
#   "oracle_avg_reward": 5523.86517527643,
#   "avg_gap": 15.231895185185852,
#   "avg_reward": 4720.91591323697,
#   "avg_efficiency": 84.76810481481415
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 81.79196811273066,
#     "EXPUCB": 77.69539054942167,
#     "EXPNeuralUCB": 89.74594143704155
#   },
#   "oracle_avg_reward": 5520.323178159946,
#   "avg_gap": 10.254058562958448,
#   "avg_reward": 4952.211902195281,
#   "avg_efficiency": 89.74594143704155
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 81.79196811273066,
#     "EXPUCB": 77.69539054942167,
#     "EXPNeuralUCB": 89.74594143704155
#   },
#   "oracle_avg_reward": 5520.323178159946,
#   "avg_gap": 10.254058562958448,
#   "avg_reward": 4952.211902195281,
#   "avg_efficiency": 89.74594143704155
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 91.99338545131987,
#     "EXPUCB": 83.08522999257846,
#     "EXPNeuralUCB": 83.21342794800393
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 8.006614548680142,
#   "avg_reward": 5135.908472366684,
#   "avg_efficiency": 91.99338545131987
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 91.99338545131987,
#     "EXPUCB": 83.08522999257846,
#     "EXPNeuralUCB": 83.21342794800393
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 8.006614548680142,
#   "avg_reward": 5135.908472366684,
#   "avg_efficiency": 91.99338545131987
# }
#   ✅ MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1Tb_EXP3.pkl
#      → MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_5_S1Tb_EXP3.csv
#      → 75 records, 5 scenarios, 3 models
# Loading: MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5T_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.24815424005807,
#     "EXPUCB": 73.20690568446642,
#     "EXPNeuralUCB": 87.44089485186156
#   },
#   "oracle_avg_reward": 4133.78755992771,
#   "avg_gap": 12.559105148138443,
#   "avg_reward": 3631.8823644026147,
#   "avg_efficiency": 87.44089485186156
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 3,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.24815424005807,
#     "EXPUCB": 73.20690568446642,
#     "EXPNeuralUCB": 87.44089485186156
#   },
#   "oracle_avg_reward": 4133.78755992771,
#   "avg_gap": 12.559105148138443,
#   "avg_reward": 3631.8823644026147,
#   "avg_efficiency": 87.44089485186156
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.13813020620796,
#     "EXPUCB": 75.22832911558383,
#     "EXPNeuralUCB": 76.32739984572538
#   },
#   "oracle_avg_reward": 4143.383349848041,
#   "avg_gap": 12.861869793792033,
#   "avg_reward": 3557.7587108950283,
#   "avg_efficiency": 87.13813020620796
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.13813020620796,
#     "EXPUCB": 75.22832911558383,
#     "EXPNeuralUCB": 76.32739984572538
#   },
#   "oracle_avg_reward": 4143.383349848041,
#   "avg_gap": 12.861869793792033,
#   "avg_reward": 3557.7587108950283,
#   "avg_efficiency": 87.13813020620796
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.45305369064859,
#     "EXPUCB": 76.32819442605785,
#     "EXPNeuralUCB": 84.81249639460822
#   },
#   "oracle_avg_reward": 4148.048758844175,
#   "avg_gap": 10.546946309351398,
#   "avg_reward": 3680.883589737934,
#   "avg_efficiency": 89.45305369064859
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 3,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 89.45305369064859,
#     "EXPUCB": 76.32819442605785,
#     "EXPNeuralUCB": 84.81249639460822
#   },
#   "oracle_avg_reward": 4148.048758844175,
#   "avg_gap": 10.546946309351398,
#   "avg_reward": 3680.883589737934,
#   "avg_efficiency": 89.45305369064859
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# ...
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 88.19885801035625,
#     "EXPUCB": 78.38261190320387,
#     "EXPNeuralUCB": 85.06017432642406
#   },
#   "oracle_avg_reward": 5528.86125541971,
#   "avg_gap": 11.801141989643757,
#   "avg_reward": 4814.130503604827,
#   "avg_efficiency": 88.19885801035625
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 88.19885801035625,
#     "EXPUCB": 78.38261190320387,
#     "EXPNeuralUCB": 85.06017432642406
#   },
#   "oracle_avg_reward": 5528.86125541971,
#   "avg_gap": 11.801141989643757,
#   "avg_reward": 4814.130503604827,
#   "avg_efficiency": 88.19885801035625
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.36132628925061,
#     "EXPUCB": 79.30980060726867,
#     "EXPNeuralUCB": 84.61075636914981
#   },
#   "oracle_avg_reward": 5543.420727777558,
#   "avg_gap": 15.389243630850178,
#   "avg_reward": 4698.3459094301525,
#   "avg_efficiency": 84.61075636914981
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 1,
#     "EXPUCB": 1,
#     "EXPNeuralUCB": 1
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.36132628925061,
#     "EXPUCB": 79.30980060726867,
#     "EXPNeuralUCB": 84.61075636914981
#   },
#   "oracle_avg_reward": 5543.420727777558,
#   "avg_gap": 15.389243630850178,
#   "avg_reward": 4698.3459094301525,
#   "avg_efficiency": 84.61075636914981
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 5,
#     "EXPUCB": 5,
#     "EXPNeuralUCB": 5
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.7354989734885,
#     "EXPUCB": 83.02780838977702,
#     "EXPNeuralUCB": 95.38504401370615
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 4.614955986293859,
#   "avg_reward": 5333.780406667856,
#   "avg_efficiency": 95.38504401370615
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 5,
#     "EXPUCB": 5,
#     "EXPNeuralUCB": 5
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 87.7354989734885,
#     "EXPUCB": 83.02780838977702,
#     "EXPNeuralUCB": 95.38504401370615
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 4.614955986293859,
#   "avg_reward": 5333.780406667856,
#   "avg_efficiency": 95.38504401370615
# }
#   ✅ MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2T_EXP3.pkl
#      → MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2T_EXP3.csv
#      → 75 records, 5 scenarios, 3 models
# Loading: MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2Tb_EXP3.pkl
# evaluation_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none', 'scenarios_results'])
# scenarios_results:  dict_keys(['stochastic', 'markov', 'adaptive', 'onlineadaptive', 'none'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario markov:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 80.13517742515025,
#     "EXPUCB": 76.37861045523945,
#     "EXPNeuralUCB": 81.86754353840278
#   },
#   "oracle_avg_reward": 5512.568068683773,
#   "avg_gap": 18.132456461597208,
#   "avg_reward": 4514.555490312425,
#   "avg_efficiency": 81.86754353840278
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 80.13517742515025,
#     "EXPUCB": 76.37861045523945,
#     "EXPNeuralUCB": 81.86754353840278
#   },
#   "oracle_avg_reward": 5512.568068683773,
#   "avg_gap": 18.132456461597208,
#   "avg_reward": 4514.555490312425,
#   "avg_efficiency": 81.86754353840278
# }
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario stochastic:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.41929772381607,
#     "EXPUCB": 77.95181566334365,
#     "EXPNeuralUCB": 80.61716846126457
#   },
#   "oracle_avg_reward": 5524.272320746105,
#   "avg_gap": 15.580702276183937,
#   "avg_reward": 4675.785274334385,
#   "avg_efficiency": 84.41929772381607
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.41929772381607,
#     "EXPUCB": 77.95181566334365,
#     "EXPNeuralUCB": 80.61716846126457
#   },
#   "oracle_avg_reward": 5524.272320746105,
#   "avg_gap": 15.580702276183937,
#   "avg_reward": 4675.785274334385,
#   "avg_efficiency": 84.41929772381607
# }
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario adaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.78721180805765,
#     "EXPUCB": 76.92535435804959,
#     "EXPNeuralUCB": 56.4545491943599
#   },
#   "oracle_avg_reward": 5525.393826663552,
#   "avg_gap": 16.212788191942348,
#   "avg_reward": 4783.675337083888,
#   "avg_efficiency": 83.78721180805765
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 4,
#     "EXPUCB": 4,
#     "EXPNeuralUCB": 4
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 83.78721180805765,
#     "EXPUCB": 76.92535435804959,
#     "EXPNeuralUCB": 56.4545491943599
#   },
#   "oracle_avg_reward": 5525.393826663552,
#   "avg_gap": 16.212788191942348,
#   "avg_reward": 4783.675337083888,
#   "avg_efficiency": 83.78721180805765
# }
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario onlineadaptive:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.47498570666744,
#     "EXPUCB": 75.85467757807461,
#     "EXPNeuralUCB": 85.10899288107433
#   },
#   "oracle_avg_reward": 5469.299777592083,
#   "avg_gap": 14.89100711892568,
#   "avg_reward": 4640.009187896509,
#   "avg_efficiency": 85.10899288107433
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 2,
#     "EXPUCB": 2,
#     "EXPNeuralUCB": 2
#   },
#   "total_experiments": 5,
#   "overall_winner": "EXPNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 84.47498570666744,
#     "EXPUCB": 75.85467757807461,
#     "EXPNeuralUCB": 85.10899288107433
#   },
#   "oracle_avg_reward": 5469.299777592083,
#   "avg_gap": 14.89100711892568,
#   "avg_reward": 4640.009187896509,
#   "avg_efficiency": 85.10899288107433
# }
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'all_model_metrics', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'winner_avg_metrics', 'avg_efficiency'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# dict_keys(['Oracle', 'GNeuralUCB', 'EXPUCB', 'EXPNeuralUCB'])
# evaluation_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# scenarios_results for scenario none:  dict_keys(['win_counts', 'total_experiments', 'overall_winner', 'winner_efficients', 'oracle_avg_reward', 'avg_gap', 'avg_reward', 'avg_efficiency'])
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 92.89666681028142,
#     "EXPUCB": 82.27584898563171,
#     "EXPNeuralUCB": 82.65926524857409
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 7.103333189718578,
#   "avg_reward": 5170.374931375836,
#   "avg_efficiency": 92.89666681028142
# }
# {
#   "win_counts": {
#     "GNeuralUCB": 3,
#     "EXPUCB": 3,
#     "EXPNeuralUCB": 3
#   },
#   "total_experiments": 5,
#   "overall_winner": "GNeuralUCB",
#   "winner_efficients": {
#     "GNeuralUCB": 92.89666681028142,
#     "EXPUCB": 82.27584898563171,
#     "EXPNeuralUCB": 82.65926524857409
#   },
#   "oracle_avg_reward": 5574.105608060588,
#   "avg_gap": 7.103333189718578,
#   "avg_reward": 5170.374931375836,
#   "avg_efficiency": 92.89666681028142
# }
#   ✅ MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2Tb_EXP3.pkl
#      → MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_5_S2Tb_EXP3.csv
#      → 75 records, 5 scenarios, 3 models
#
# ================================================================================
# CONVERSION COMPLETE
# ================================================================================
# Converted 720 entries
# Converted 12 files
# ================================================================================
#
#                                             log_file  ... threshold
# 0  MultiRunEvaluator_4000-Default_Adversarial_Mar...  ...     0.582
# 1  MultiRunEvaluator_4000-Default_Adversarial_Mar...  ...     0.500
# 2  MultiRunEvaluator_4000-Default_Adversarial_Mar...  ...     0.628
# 3  MultiRunEvaluator_4000-Default_Adversarial_Mar...  ...     0.582
# 4  MultiRunEvaluator_4000-Default_Adversarial_Mar...  ...     0.500
#
# [5 rows x 30 columns]
#
# ===== CLEANUP STDERR =====
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py:1343: SyntaxWarning: invalid escape sequence '\('
#   "scenario_cat": re.split("\(|\)", scenario_cat)[-2],
#
# 🚿 Cleanup finished.
# ✓ Deep cleanup complete (memory cleared)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully (fresh environment ready)

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration

# Create allocator with correct parameters
allocator = ThompsonSamplingAllocator(
    total_qubits=35,           # Total qubits available (8+10+8+9=35)
    num_routes=4,              # Number of routes
    min_qubits_per_route=2     # Minimum qubits per route
)
# AFTER (UCB - Dynamic):

# allocator = DynamicQubitAllocator(              # ← Change class name
#     total_qubits=35,           
#     num_routes=4,              
#     min_qubits_per_route=2,
#     exploration_bonus=2.0      # ← NEW parameter (optional, default is 2.0)
# )



# Fully random (exploration only)
# allocator = RandomQubitAllocator(epsilon=1.0, seed=42)

# # 50-50 mix of random and baseline
# random_50 = RandomQubitAllocator(epsilon=0.5, seed=42)

# # Mostly baseline with occasional exploration (epsilon-greedy style)
# random_10 = RandomQubitAllocator(epsilon=0.1, seed=42)

# # Decaying randomness (start exploratory, become deterministic)
# decaying = RandomQubitAllocator(
#     epsilon=1.0,           # Start fully random
#     epsilon_decay=0.99,    # Decay 1% per timestep
#     min_epsilon=0.05,      # Eventually stabilize at 5% exploration
#     seed=42
# )

# # Fully deterministic (acts like fixed allocator)
# deterministic = RandomQubitAllocator(epsilon=0.0, seed=42)

# models = ['Oracle', 'GNeuralUCB', 'EXPNeuralUCB']
models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=True, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=1, base_capacity=True, overwrite=True) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (9908 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        4000
#   • allocator_id:  Default
#   • env_id:        Adversarial
#   • attack_id:     Markov
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       3
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/3 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_No-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_Markov-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_Adaptive-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Stochastic_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_No-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_Random-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_Random-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_Markov-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_Adaptive-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Default_Adversarial_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#
#   • Model keys: 40
#     - Oracle(base)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#
# --- Run 2/3 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_No-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_Random-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_Random-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_Markov-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_Adaptive-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Stochastic_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_No-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_Random-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_Random-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_Markov-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_Adaptive-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Default_Adversarial_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_No-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Random-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Markov-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Adaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_No-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Random-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Markov-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Adaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#
#   • Model keys: 80
#     - Oracle(base)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#
# --- Run 3/3 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_No-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_Markov-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_Adaptive-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Stochastic_OnlineAdaptive-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_No-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_Random-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_Random-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_Markov-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_Adaptive-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Default_Adversarial_OnlineAdaptive-8000_3_S1Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Stochastic_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_No-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Random-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Markov-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_Adaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_4000-Default_Adversarial_OnlineAdaptive-4000_1_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_No-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Random-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Markov-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_Adaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Stochastic_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_No-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Random-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Markov-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_Adaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_4000-Default_Adversarial_OnlineAdaptive-6000_2_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Stochastic_No-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Stochastic_Random-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Stochastic_Markov-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Stochastic_Adaptive-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Stochastic_OnlineAdaptive-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Adversarial_No-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Adversarial_Random-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Adversarial_Markov-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Adversarial_Adaptive-8000_3_S1Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_4000-Default_Adversarial_OnlineAdaptive-8000_3_S1Tb_EXP3.pkl
#
#   • Model keys: 120
#     - Oracle(base)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-4000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-6000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_No-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Random-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Markov-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_Adaptive-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Stochastic_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_No-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Random-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Markov-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_Adaptive-8000_S1Tb_EXP3.pkl
#     - Oracle(base)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - GNeuralUCB(neural)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - EXPUCB(exp3)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_4000-Default_Adversarial_OnlineAdaptive-8000_S1Tb_EXP3.pkl
#
# EXPECTED KEY GENERATION COMPLETE
#
# RESTORING FROM DRIVE 1
# RESTORING FROM DRIVE 2
# 	⚠️ Registry exists → aborting restore
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
# 	✓ MultiRunEvaluator Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_4000-Default_Adversarial_Markov-4000_2000_3_S1Tb_EXP3.pkl
# 	   File exists: True, size: 83752870
# 	✓ Pickle loaded (standard pickle)
# EQUAL METHOD
# 	   Equality check: True
# 	✅ Resuming state
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1Tb
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1Tb_20251217_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1Tb_20251217_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2145.26, Efficiency=077.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=2026.61, Efficiency=073.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=2222.35, Efficiency=080.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:019.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=3803.33, Efficiency=091.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3226.70, Efficiency=077.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=3843.70, Efficiency=092.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:EXPNeuralUCB        (Gap:007.2%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5011.46, Efficiency=090.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4297.43, Efficiency=077.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=5027.15, Efficiency=091.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:008.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2218.10, Efficiency=080.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# ...
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:EXPNeuralUCB        (Gap:002.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4402.09, Efficiency=080.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=3986.04, Efficiency=073.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=4559.93, Efficiency=083.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:016.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.3s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2298.52, Efficiency=082.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=2159.55, Efficiency=077.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=2267.43, Efficiency=081.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:017.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=4082.92, Efficiency=097.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3420.38, Efficiency=081.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=2842.60, Efficiency=068.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:002.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5440.01, Efficiency=097.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4672.57, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=4635.00, Efficiency=083.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:002.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4140.98
# 	• Winner Avg Gap: 0011.88%
# 	• Winner Avg Reward: 3697.73
# 	• Winner Avg Efficiency: 0088.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.9%
# 	Winner Avg Efficiency: 	088.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.1% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	076.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.04
# 	• Winner Avg Gap: 0014.88%
# 	• Winner Avg Reward: 3565.07
# 	• Winner Avg Efficiency: 0085.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.9%
# 	Winner Avg Efficiency: 	085.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	085.1% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	084.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4141.83
# 	• Winner Avg Gap: 0016.11%
# 	• Winner Avg Reward: 3538.04
# 	• Winner Avg Efficiency: 0083.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.1%
# 	Winner Avg Efficiency: 	083.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	083.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	082.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4123.47
# 	• Winner Avg Gap: 0011.18%
# 	• Winner Avg Reward: 3655.19
# 	• Winner Avg Efficiency: 0088.82%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.2%
# 	Winner Avg Efficiency: 	088.8%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.8% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	075.6% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	074.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0007.42%
# 	• Winner Avg Reward: 3940.48
# 	• Winner Avg Efficiency: 0092.58%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	007.4%
# 	Winner Avg Efficiency: 	092.6%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	092.6% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	081.0% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	077.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (EXPNeuralUCB):
# 	• Stochastic Performance:    	3697.733
# 	• Baseline Performance:      	3940.484
# 	• Performance Retention:     	093.8%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4140.98
# 	• Winner Avg Gap: 0011.88%
# 	• Winner Avg Reward: 3697.73
# 	• Winner Avg Efficiency: 0088.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.9%
# 	Winner Avg Efficiency: 	088.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.1% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	076.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.04
# 	• Winner Avg Gap: 0014.88%
# 	• Winner Avg Reward: 3565.07
# 	• Winner Avg Efficiency: 0085.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.9%
# 	Winner Avg Efficiency: 	085.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	085.1% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	084.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4141.83
# 	• Winner Avg Gap: 0016.11%
# 	• Winner Avg Reward: 3538.04
# 	• Winner Avg Efficiency: 0083.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.1%
# 	Winner Avg Efficiency: 	083.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	083.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	082.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4123.47
# 	• Winner Avg Gap: 0011.18%
# 	• Winner Avg Reward: 3655.19
# 	• Winner Avg Efficiency: 0088.82%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.2%
# 	Winner Avg Efficiency: 	088.8%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.8% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	075.6% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	074.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0007.42%
# 	• Winner Avg Reward: 3940.48
# 	• Winner Avg Efficiency: 0092.58%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	007.4%
# 	Winner Avg Efficiency: 	092.6%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	092.6% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	081.0% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	077.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251217_215743.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.9%
# 	Winner Avg Efficiency: 	088.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.1% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	076.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251217_215743.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.9%
# 	Winner Avg Efficiency: 	085.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	085.1% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	084.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	073.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251217_215743.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.1%
# 	Winner Avg Efficiency: 	083.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	083.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	082.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251217_215743.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.2%
# 	Winner Avg Efficiency: 	088.8%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	088.8% Efficiency 	(Won 3/3 experiments)
# 	• GNeuralUCB     : 	075.6% Efficiency 	(Won 0/3 experiments)
# 	• EXPUCB         : 	074.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251217_215743.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	007.4%
# 	Winner Avg Efficiency: 	092.6%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	092.6% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	081.0% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	077.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251217_215743.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4140.977
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3653.350
#   • Oracle Efficiency: 86.8%
#   • Oracle Gap: 13.2%
#   • Classification: GOOD
#
# EXPUCB:
#   • Stochastic Performance: 3183.580
#   • Oracle Efficiency: 76.4%
#   • Oracle Gap: 23.6%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3697.733
#   • Oracle Efficiency: 88.1%
#   • Oracle Gap: 11.9%
#   • Classification: GOOD
#   ★ WINNER ★
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
# saved_experiments = viz.save_all_evaluation_results(save_format='both')


models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=True, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=1.5, base_capacity=True, overwrite=True) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (9908 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        6000
#   • allocator_id:  Default
#   • env_id:        Adversarial
#   • attack_id:     Markov
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       3
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/3 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_No-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_Random-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_Random-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_Markov-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Stochastic_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_No-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_Random-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_Random-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_Markov-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Default_Adversarial_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#
#   • Model keys: 40
#     - Oracle(base)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#
# --- Run 2/3 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_No-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_Random-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_Random-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_Markov-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Stochastic_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_No-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_Random-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_Random-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_Markov-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Default_Adversarial_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_No-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Random-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Markov-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_No-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Random-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Markov-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#
#   • Model keys: 80
#     - Oracle(base)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#
# --- Run 3/3 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_No-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_Random-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_Random-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_Markov-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_Adaptive-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Stochastic_OnlineAdaptive-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_No-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_Random-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_Random-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_Markov-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_Adaptive-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Default_Adversarial_OnlineAdaptive-8000_3_S1_5Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Stochastic_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_No-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Random-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Markov-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_Adaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_6000.0-Default_Adversarial_OnlineAdaptive-4000_1_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_No-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Random-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Markov-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Stochastic_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_No-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Random-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Markov-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_Adaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_6000.0-Default_Adversarial_OnlineAdaptive-6000_2_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Stochastic_No-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Stochastic_Random-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Stochastic_Markov-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Stochastic_Adaptive-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Stochastic_OnlineAdaptive-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Adversarial_No-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Adversarial_Random-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Adversarial_Markov-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Adversarial_Adaptive-8000_3_S1_5Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_6000.0-Default_Adversarial_OnlineAdaptive-8000_3_S1_5Tb_EXP3.pkl
#
#   • Model keys: 120
#     - Oracle(base)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-4000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-6000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_No-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Random-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Markov-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Stochastic_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_No-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Random-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Markov-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_Adaptive-8000_S1_5Tb_EXP3.pkl
#     - Oracle(base)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - GNeuralUCB(neural)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPUCB(exp3)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Default_Adversarial_OnlineAdaptive-8000_S1_5Tb_EXP3.pkl
#
# EXPECTED KEY GENERATION COMPLETE
#
# RESTORING FROM DRIVE 1
# RESTORING FROM DRIVE 2
# 	⚠️ Registry exists → aborting restore
# 	✓ MultiRunEvaluator Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_6000-Default_Adversarial_Markov-4000_2000_3_S1_5Tb_EXP3.pkl
# 	   File exists: True, size: 83757689
# 	✓ Pickle loaded (standard pickle)
# EQUAL METHOD
# 	   Equality check: True
# 	✅ Resuming state
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5Tb
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5Tb_20251217_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S1.5Tb_20251217_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2512.73, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=1985.01, Efficiency=071.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=1694.53, Efficiency=061.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=6000.0, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.1%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=3271.64, Efficiency=078.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3171.26, Efficiency=076.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=3266.77, Efficiency=078.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.628]
# ...
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:020.0%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5380.52, Efficiency=096.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4670.26, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=5372.43, Efficiency=096.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:003.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2679.04, Efficiency=096.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=2064.43, Efficiency=074.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=2439.05, Efficiency=087.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:003.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=4063.16, Efficiency=097.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3419.53, Efficiency=081.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=3801.31, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:002.8%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4561.03, Efficiency=081.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4610.22, Efficiency=082.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=6000.0, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=3145.31, Efficiency=056.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=6000.0, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPUCB              (Gap:017.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=6000.0, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4142.47
# 	• Winner Avg Gap: 0016.74%
# 	• Winner Avg Reward: 3398.22
# 	• Winner Avg Efficiency: 0083.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.91
# 	• Winner Avg Gap: 0023.36%
# 	• Winner Avg Reward: 3246.37
# 	• Winner Avg Efficiency: 0076.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	023.4%
# 	Winner Avg Efficiency: 	076.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	076.6% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	076.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4144.54
# 	• Winner Avg Gap: 0011.10%
# 	• Winner Avg Reward: 3700.59
# 	• Winner Avg Efficiency: 0088.90%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.1%
# 	Winner Avg Efficiency: 	088.9%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	088.9% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	074.1% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	060.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4135.99
# 	• Winner Avg Gap: 0012.15%
# 	• Winner Avg Reward: 3676.45
# 	• Winner Avg Efficiency: 0087.85%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0008.29%
# 	• Winner Avg Reward: 3767.74
# 	• Winner Avg Efficiency: 0091.71%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (GNeuralUCB):
# 	• Stochastic Performance:    	3398.216
# 	• Baseline Performance:      	3767.741
# 	• Performance Retention:     	090.2%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4142.47
# 	• Winner Avg Gap: 0016.74%
# 	• Winner Avg Reward: 3398.22
# 	• Winner Avg Efficiency: 0083.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.91
# 	• Winner Avg Gap: 0023.36%
# 	• Winner Avg Reward: 3246.37
# 	• Winner Avg Efficiency: 0076.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	023.4%
# 	Winner Avg Efficiency: 	076.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	076.6% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	076.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4144.54
# 	• Winner Avg Gap: 0011.10%
# 	• Winner Avg Reward: 3700.59
# 	• Winner Avg Efficiency: 0088.90%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.1%
# 	Winner Avg Efficiency: 	088.9%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	088.9% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	074.1% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	060.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4135.99
# 	• Winner Avg Gap: 0012.15%
# 	• Winner Avg Reward: 3676.45
# 	• Winner Avg Efficiency: 0087.85%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0008.29%
# 	• Winner Avg Reward: 3767.74
# 	• Winner Avg Efficiency: 0091.71%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251217_215917.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251217_215917.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	023.4%
# 	Winner Avg Efficiency: 	076.6%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	076.6% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	076.1% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251217_215917.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/3 experiments)
# 	Winner Avg Gap: 	011.1%
# 	Winner Avg Efficiency: 	088.9%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	088.9% Efficiency 	(Won 3/3 experiments)
# 	• EXPUCB         : 	074.1% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	060.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251217_215917.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251217_215917.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251217_215917.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4142.468
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3398.216
#   • Oracle Efficiency: 83.3%
#   • Oracle Gap: 16.7%
#   • Classification: GOOD
#   ★ WINNER ★
#
# EXPUCB:
#   • Stochastic Performance: 3178.055
#   • Oracle Efficiency: 75.9%
#   • Oracle Gap: 24.1%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3321.451
#   • Oracle Efficiency: 76.9%
#   • Oracle Gap: 23.1%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
# saved_experiments = viz.save_all_evaluation_results(save_format='both')


models = [
            'Oracle',
            'GNeuralUCB', 
            'EXPUCB',
            'EXPNeuralUCB',
            # 'LinUCB'
        ]
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=True, suffix="EXP3",
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=True, overwrite=True) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Attempting to load local registry cache...
# ✓ Local registry loaded (9908 keys)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Default Dynamic Allocation (Initial): (8, 10, 8, 9)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        8000
#   • allocator_id:  Default
#   • env_id:        Adversarial
#   • attack_id:     Markov
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       3
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/3 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#
#   • Model keys: 40
#     - Oracle(base)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#
# --- Run 2/3 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_No-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_Random-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_Random-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_Markov-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_Adaptive-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Stochastic_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_No-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_Random-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_Random-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_Markov-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_Adaptive-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Default_Adversarial_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_No-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Random-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Markov-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Adaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_No-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Random-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Markov-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Adaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#
#   • Model keys: 80
#     - Oracle(base)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#
# --- Run 3/3 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_No-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_Random-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_Random-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_Markov-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_Adaptive-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Stochastic_OnlineAdaptive-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_No-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_Random-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_Random-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_Markov-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_Adaptive-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Default_Adversarial_OnlineAdaptive-8000_3_S2Tb_EXP3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_No-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Random-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Markov-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_Adaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Stochastic_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_No-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Random-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Markov-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_Adaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_2_8000-Default_Adversarial_OnlineAdaptive-6000_2_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Stochastic_No-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Stochastic_Random-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Stochastic_Markov-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Stochastic_Adaptive-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Stochastic_OnlineAdaptive-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Adversarial_No-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Adversarial_Random-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Adversarial_Markov-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Adversarial_Adaptive-8000_3_S2Tb_EXP3.pkl
#     - QuantumExperimentRunner_3_8000-Default_Adversarial_OnlineAdaptive-8000_3_S2Tb_EXP3.pkl
#
#   • Model keys: 120
#     - Oracle(base)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-6000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-8000_S2Tb_EXP3.pkl
#     - Oracle(base)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - EXPUCB(exp3)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-8000_S2Tb_EXP3.pkl
#
# EXPECTED KEY GENERATION COMPLETE
#
# RESTORING FROM DRIVE 1
# RESTORING FROM DRIVE 2
# 	⚠️ Registry exists → aborting restore
# 	✓ MultiRunEvaluator Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251217/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_3_S2Tb_EXP3.pkl
# 	   File exists: True, size: 83752830
# 	✓ Pickle loaded (standard pickle)
# EQUAL METHOD
# 	   Equality check: True
# 	✅ Resuming state
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 8000 (step: 2000)
# quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2Tb
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2Tb_20251217_log.txt
# PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(EXP3)_alloc-all_envs-5_attacks-4000_2000-3_runs-S2Tb_20251217_log.txt')
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 4
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPUCB, EXPNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	3
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2512.73, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=1985.01, Efficiency=071.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=1694.53, Efficiency=061.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.1%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=3271.64, Efficiency=078.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3171.26, Efficiency=076.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=3266.77, Efficiency=078.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:021.1%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4410.28, Efficiency=079.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4377.90, Efficiency=079.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=5003.05, Efficiency=090.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:009.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2320.16, Efficiency=084.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=1986.60, Efficiency=072.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# ...
# 	EXP 2 EXPNEURALUCB        : Reward=3234.20, Efficiency=079.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:020.0%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5380.52, Efficiency=096.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4670.26, Efficiency=083.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=5372.43, Efficiency=096.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:003.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2679.04, Efficiency=096.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 1 EXPUCB              : Reward=2064.43, Efficiency=074.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 1 EXPNEURALUCB        : Reward=2439.05, Efficiency=087.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:003.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=4063.16, Efficiency=097.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 2 EXPUCB              : Reward=3419.53, Efficiency=081.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 2 EXPNEURALUCB        : Reward=3801.31, Efficiency=090.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:002.8%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4561.03, Efficiency=081.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 3 EXPUCB              : Reward=4610.22, Efficiency=082.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.5]
# 	EXP 3 EXPNEURALUCB        : Reward=3145.31, Efficiency=056.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPUCB              (Gap:017.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4142.47
# 	• Winner Avg Gap: 0016.74%
# 	• Winner Avg Reward: 3398.22
# 	• Winner Avg Efficiency: 0083.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.07
# 	• Winner Avg Gap: 0018.10%
# 	• Winner Avg Reward: 3390.81
# 	• Winner Avg Efficiency: 0081.90%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	018.1%
# 	Winner Avg Efficiency: 	081.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	081.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	078.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4143.76
# 	• Winner Avg Gap: 0020.04%
# 	• Winner Avg Reward: 3453.56
# 	• Winner Avg Efficiency: 0079.96%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	020.0%
# 	Winner Avg Efficiency: 	080.0%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	080.0% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	049.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4135.99
# 	• Winner Avg Gap: 0012.15%
# 	• Winner Avg Reward: 3676.45
# 	• Winner Avg Efficiency: 0087.85%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0008.29%
# 	• Winner Avg Reward: 3767.74
# 	• Winner Avg Efficiency: 0091.71%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (GNeuralUCB):
# 	• Stochastic Performance:    	3398.216
# 	• Baseline Performance:      	3767.741
# 	• Performance Retention:     	090.2%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	4
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4142.47
# 	• Winner Avg Gap: 0016.74%
# 	• Winner Avg Reward: 3398.22
# 	• Winner Avg Efficiency: 0083.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4134.07
# 	• Winner Avg Gap: 0018.10%
# 	• Winner Avg Reward: 3390.81
# 	• Winner Avg Efficiency: 0081.90%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	018.1%
# 	Winner Avg Efficiency: 	081.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	081.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	078.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4143.76
# 	• Winner Avg Gap: 0020.04%
# 	• Winner Avg Reward: 3453.56
# 	• Winner Avg Efficiency: 0079.96%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	020.0%
# 	Winner Avg Efficiency: 	080.0%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	080.0% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	049.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 4135.99
# 	• Winner Avg Gap: 0012.15%
# 	• Winner Avg Reward: 3676.45
# 	• Winner Avg Efficiency: 0087.85%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 4180.58
# 	• Winner Avg Gap: 0008.29%
# 	• Winner Avg Reward: 3767.74
# 	• Winner Avg Efficiency: 0091.71%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_comparison_20251217_220100.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	016.7%
# 	Winner Avg Efficiency: 	083.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	083.3% Efficiency 	(Won 2/3 experiments)
# 	• EXPNeuralUCB   : 	076.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	075.9% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: None_stochastic_vs_baseline_20251217_220100.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	018.1%
# 	Winner Avg Efficiency: 	081.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	081.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	078.9% Efficiency 	(Won 1/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: None_markov_vs_baseline_20251217_220100.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	020.0%
# 	Winner Avg Efficiency: 	080.0%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	080.0% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	074.8% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	049.5% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_adaptive_vs_baseline_20251217_220100.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	012.1%
# 	Winner Avg Efficiency: 	087.9%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	087.9% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	086.8% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	075.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: None_onlineadaptive_vs_baseline_20251217_220100.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	091.7% Efficiency 	(Won 2/3 experiments)
# 	• EXPUCB         : 	079.5% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	078.3% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: None_none_vs_baseline_20251217_220100.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 4142.468
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3398.216
#   • Oracle Efficiency: 83.3%
#   • Oracle Gap: 16.7%
#   • Classification: GOOD
#   ★ WINNER ★
#
# EXPUCB:
#   • Stochastic Performance: 3178.055
#   • Oracle Efficiency: 75.9%
#   • Oracle Gap: 24.1%
#   • Classification: MODERATE
#
# EXPNeuralUCB:
#   • Stochastic Performance: 3321.451
#   • Oracle Efficiency: 76.9%
#   • Oracle Gap: 23.1%
#   • Classification: MODERATE
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
