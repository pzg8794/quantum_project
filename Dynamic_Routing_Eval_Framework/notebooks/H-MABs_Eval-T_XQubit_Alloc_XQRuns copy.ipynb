# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# ============================================================
# Setup: Quantum MAB Framework (Paper 7 QBGP Testbed)
# ============================================================

# --- Install Dependencies ---
# !pip install -q torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn pmdarima networkx

# --- Core Imports ---
import os, sys, gc, warnings, importlib, subprocess
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import networkx as nx
from pathlib import Path
from tqdm import tqdm

warnings.filterwarnings('ignore')

# --- Path Setup ---
print(f"Current working directory: {os.getcwd().split('/')[-1]}")
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")
except ImportError:
    print("Running locally (not in Colab)")

sys.path.append(os.path.join(os.getcwd(), 'src'))
print(f"Now working from: {os.getcwd().split('/')[-1]}")

# --- Framework Verification ---
print("Framework dependencies installed successfully")
print(f"Python version: {sys.version.split()[0]}")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"NetworkX version: {nx.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for Paper 7 (QBGP) testing")

# --- Cleanup Script Execution ---
root = os.path.abspath("../..")
cleanup_script = os.path.join(root, "cleanup_state_duplicates.py")
if os.path.exists(cleanup_script):
    print(f"\n🚿 Running cleanup script at: {cleanup_script}\n")
    result = subprocess.run(["python3", cleanup_script], text=True, capture_output=True)
    print("===== CLEANUP STDOUT =====\n", result.stdout)
    print("===== CLEANUP STDERR =====\n", result.stderr)
else:
    print("⚠️ Cleanup script not found, skipping...")

# --- Deep Cleanup ---
def deep_cleanup():
    to_clear = ["oracle", "gneuralucb", "expneuralucb", "cpursuitneuralucb",
                "icpursuitneuralucb", "evaluator", "results"]
    for name in to_clear:
        if name in globals():
            obj = globals().get(name)
            if hasattr(obj, "cleanup"): obj.cleanup(verbose=False)
            globals().pop(name, None)
    gc.collect()
    torch.set_default_dtype(torch.float32)
    if torch.cuda.is_available(): torch.cuda.empty_cache()
    print("✓ Deep cleanup complete (memory cleared)")

deep_cleanup()

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# --- Final Module Setup ---
from daqr.core.qubit_allocator              import (QubitAllocator, RandomQubitAllocator, DynamicQubitAllocator, ThompsonSamplingAllocator)
from daqr.core.quantum_physics              import (MemoryNoiseModel, FullPaper2FidelityCalculator, Paper2RewardFunction)
from daqr.evaluation                        import experiment_runner, multi_run_evaluator, visualizer, allocator_runner
from daqr.config                            import experiment_config, gd_backup_manager, local_backup_manager
from daqr.algorithms                        import base_bandit, neural_bandits, predictive_bandits
from daqr.core                              import network_environment, qubit_allocator
from daqr.evaluation.visualizer             import QuantumEvaluatorVisualizer
from daqr.config.gd_backup_manager          import GoogleDriveBackupManager
from daqr.config.experiment_config          import ExperimentConfiguration
from experiments                            import stochastic_evaluation
from daqr.config.local_backup_manager       import LocalBackupManager
from daqr.core.network_environment          import *
from daqr.core.qubit_allocator              import *
from daqr.algorithms.base_bandit            import *
from daqr.algorithms.neural_bandits         import *
from daqr.algorithms.predictive_bandits     import *
from daqr.evaluation.multi_run_evaluator    import *
from daqr.evaluation.experiment_runner      import *

# ============================================================================
# PAPER-SPECIFIC IMPORTS
# ============================================================================
from daqr.core.topology_generator           import Paper2TopologyGenerator
from daqr.core.topology_generator           import Paper7ASTopologyGenerator  # 🆕 Paper 7
from daqr.core.topology_generator           import Paper12WaxmanTopologyGenerator
from daqr.core.quantum_physics              import FiberLossNoiseModel, CascadedFidelityCalculator
from daqr.core.quantum_physics              import FusionNoiseModel, FusionFidelityCalculator, QuARCRewardFunction
from daqr.core.quantum_physics              import Paper12RetryFidelityCalculator
from daqr.core.quantum_physics              import Paper7RewardFunction  # 🆕 Paper 7
from daqr.core                              import attack_strategy

print("✓ All modules reloaded successfully (Paper 7 environment ready)")

# --- Config & Model Setup ---
for module in [experiment_config, network_environment, qubit_allocator, attack_strategy, base_bandit, 
               neural_bandits, predictive_bandits, experiment_runner, multi_run_evaluator, visualizer, 
               stochastic_evaluation]:
    importlib.reload(module)

config = ExperimentConfiguration()
models = config.NEURAL_MODELS

# ============================================================================
# FRAMEWORK CONFIGURATION (Paper 7 Optimized)
# ============================================================================
FRAMEWORK_CONFIG = {
    'exp_num': 5,
    'test_mode': True,
    'base_frames': 4000,
    'frame_step': 2000,
    'models': models,
    'intensity': 0.25,
    'routing_strategy': 'fixed',
    'capacity': 10000,
    'main_env': 'stochastic',

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,
        'base_seed': 12345,
        'reproducible': True
    },

    'default': {
        'num_paths': 4,
        'total_qubits': 35,
        'min_qubits_per_route': 2,
        'exploration_bonus': 2.0,
        'epsilon': 1.0,
        'seed': 42
    },
    
    # 🎯 Paper #7 (Liu et al. 2024 - QBGP) - PRIMARY TESTBED
    'paper7': {
        # Topology Configuration
        'k': 5,                      # k-shortest paths per ISP pair
        'n_qisps': 3,                # Number of quantum ISP nodes
        'num_paths': 4,              # Total paths for framework compatibility
        'max_nodes': 50,             # AS subgraph size (30-80 for testing, None for full)
        'network_scale': 'small',    # 'small' (30-50), 'medium' (100-200), 'large' (full)
        'topology_path': '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/core/topology_data/as20000101.txt',
        
        # Framework Parameters
        'total_qubits': 35,
        'min_qubits_per_route': 2,
        'exploration_bonus': 2.0,
        
        # Context & Reward Configuration
        'use_context_rewards': True,      # Enable context-aware reward function
        'reward_mode': 'neg_hop',         # Options: 'neg_hop', 'neg_degree', 'neg_length'
        'use_synthetic': False,           # Force synthetic topology (ignore topology_path)
        
        # Topology Processing
        'largest_cc_only': True,          # Use largest connected component
        'relabel_to_int': True,           # Relabel nodes to integers
        
        # Synthetic Fallback (if topology_path fails or use_synthetic=True)
        'synthetic_kind': 'barabasi_albert',
        'synthetic_params': {
            'n': 50,                      # Number of nodes
            'm': 3                        # Edges per new node
        }
    },
    
    # Paper #2 (Huang et al. - Neural Bandit Work)
    'paper2': {
        # Topology & Paths
        'num_paths': 4,
        'num_total_qubits': 35,
        'dest_node': 14,
        'num_nodes': 15,
        'source_node': 1,
        
        # Base Physics
        'p_init': 0.00001,
        'total_qubits': 35,
        'f_attenuation': 0.05,
        
        # Stochastic Noise Parameters
        'p_BSM': 0.2,
        'p_GateErrors': 0.2,
        'p_depol': 0.1,

        # State Configuration
        'testbed': 'paper2',
        'initial_state': 'idle',
        'state_total_qubits': {'busy': 35, 'idle': 43},
        
        # Bandit Algorithm
        'exploration_bonus': 2.0,
        'min_qubits_per_route': 2,
        'transition_trigger': True,
        'paper2_transition_interval': 50,
        'entanglement_success_factor': 4000,
        
        # Paper2 Features
        'use_paper2_rewards': True,
        'swap_mode': 'async',
        'memory_T2': 5000,
        'gate_error_rate': 0.02,
        'swap_delay_per_link': 100,
        'use_gate_error': True,
        'use_memory_decay': True,
    },
    # Paper #12 (Wang et al. 2024 - QuARC)
    # Reference: Clayton et al., ICNP 2024 - "Efficient Routing on Quantum Networks using Adaptive Clustering"
    # Repository: https://github.com/cbclayton/clustered-quantum-routing
    'paper12': {
        'testbed': 'paper12',
        
        # ========== TOPOLOGY CONFIGURATION ==========
        'topology_type': 'waxman_qcast',
        
        # Network parameters (Paper 12 baseline)
        'n_nodes': 100,              # ✅ Baseline: 100 nodes
        'avg_degree': 6,             # ✅ E_d: Average node degree
        'entanglement_prob': 0.6,    # ✅ E_p: Paper 12 ORIGINAL value
        'fusion_prob': 0.9,          # ✅ q: Paper 12 ORIGINAL value
        
        # Waxman topology parameters
        'waxman_alpha': 0.4,
        'waxman_beta': 0.2,
        
        # ========== SIMULATION PARAMETERS ==========
        'num_sd_pairs': 10,          # ✅ nsd: Concurrent S-D pairs
        'epoch_length': 500,         # ✅ T_epoch: QuARC reconfiguration interval
        'total_timeslots': 5000,     # ✅ T: Baseline simulation length
        'cutoff': 1e9,               # Request timeout
        
        # ========== QUART PROTOCOL PARAMETERS ==========
        'split_constant': 3,         # ✅ k: Number of shortest paths
        'enable_clustering': True,   # ✅ Dynamic cluster merge/split
        'enable_secondary_fusions': True,  # ✅ Paper 12 fusion protocol
        'use_dynamic_thresholding': True,
        
        # ========== FRAMEWORK ADAPTATION ==========
        'num_paths': 4,              # For framework: paths for bandit arms
        'total_qubits': 100,         # Estimated: n_nodes * avg_qubits_per_node
        'exploration_bonus': 1.5,    # For bandit algorithms
        'min_qubits_per_route': 3,   # For framework allocation
        'use_fusion_rewards': True,  # Use entanglement success as reward
    }
}

# --- Test Scenarios ---
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    test_scenarios = {
        'none': 'Baseline (Optimal Conditions)',
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack'
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)',
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# # --- Display Configuration ---
# print("=" * 70)
# print("DYNAMIC ROUTING EVALUATION FRAMEWORK - PAPER 7 (QBGP) CONFIGURATION")
# print("=" * 70)
# print(f"Primary Testbed: Paper 7 (Liu et al., 2024) - QBGP Multi-ISP Routing")
# print(f"Models to evaluate: {len(models)} total")
# print(f"Topology: {'Real AS data' if not FRAMEWORK_CONFIG['paper7']['use_synthetic'] else 'Synthetic Barabási-Albert'}")
# print(f"AS Nodes: {FRAMEWORK_CONFIG['paper7']['max_nodes'] or 'Full network'}")
# print(f"ISP Nodes: {FRAMEWORK_CONFIG['paper7']['n_qisps']}")
# print(f"Paths per ISP pair: {FRAMEWORK_CONFIG['paper7']['k']}-shortest")
# print(f"Reward Mode: {FRAMEWORK_CONFIG['paper7']['reward_mode']}")
# print(f"Context-aware Rewards: {FRAMEWORK_CONFIG['paper7']['use_context_rewards']}")
# print("\n✓ Configuration loaded successfully - Ready for Paper 7 evaluation")
# print("=" * 70)
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Framework dependencies installed successfully
# Python version: 3.12.11
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# NetworkX version: 3.5
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for Paper 7 (QBGP) testing
#
# 🚿 Running cleanup script at: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py
#
# ===== CLEANUP STDOUT =====
#  Script dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework
# Project root: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework
#
# State roots:
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# ========== STARTING CLEANUP ==========
#
# [CLEANUP] Removing .0 float artifacts from filenames...
# [✓] Float artifacts fixed: 0
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: removed 0 duplicates
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: removed 0 duplicates
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: moved 0 files, removed 0 directories.
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: moved 0 files, removed 0 directories.
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/local_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 8025 corrected, 0 added
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/drive_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 8025 corrected, 0 added
# [INFO] Registry not found, skipping update: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/backup_registry.json
#
# ========== DONE ==========
#
#
# ===== CLEANUP STDERR =====
#  /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py:1338: SyntaxWarning: invalid escape sequence '\('
#   "scenario_cat": re.split("\(|\)", scenario_cat)[-2],
#
# ✓ Deep cleanup complete (memory cleared)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully (Paper 7 environment ready)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
#       Relative: framework_state/day_20260130
#       Component: framework_state
#       Date: day_20260130
#       📄 Processing 1880 files in framework_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260130: 1880/1880 files processed
#       📊 framework_state/day_20260130: 0/1880 files skipped
#       📊 framework_state/day_20260130: 0/1880 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
#       Relative: model_state/day_20260130
#       Component: model_state
#       Date: day_20260130
#       📄 Processing 6145 files in model_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260130: 6145/6145 files processed
#       📊 model_state/day_20260130: 0/6145 files skipped
#       📊 model_state/day_20260130: 0/6145 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1880 files
#   • model_state: 6145 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 8025
# ================================================================================
#
# 	→ Filesystem scan found 8025 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================================
# PAPER 12 (QUART) HELPER FUNCTIONS
# ============================================================================

def generate_paper12_paths(topology, num_paths: int, seed: int):
    """
    Generate random source-destination paths for Paper 12 (QuARC).
    
    Unlike Paper 7's ISP-based selection, Paper 12 uses random S-D pairs
    to evaluate adaptive clustering behavior across diverse routing scenarios.
    
    Args:
        topology: NetworkX graph (Waxman topology)
        num_paths: Number of paths to generate (typically 4 for framework testing)
        seed: Random seed
        
    Returns:
        List of paths (each path is a list of nodes)
    """
    rng = np.random.default_rng(seed)
    nodes = list(topology.nodes())
    paths = []
    attempts = 0
    max_attempts = 10 * num_paths
    
    while len(paths) < num_paths and attempts < max_attempts:
        attempts += 1
        src, dst = rng.choice(nodes, 2, replace=False)
        try:
            path = nx.shortest_path(topology, src, dst)
            if path not in paths:
                paths.append(path)
        except nx.NetworkXNoPath:
            continue
    
    if len(paths) < num_paths:
        raise RuntimeError(f"Could not find {num_paths} valid paths in Waxman topology")
    
    return paths


def generate_paper12_contexts(paths, topology, fusion_prob: float = 0.9):
    """
    Generate context vectors for Paper 12 (QuARC) paths.
    
    Context features match QuARC protocol state:
    - hop_count: Number of quantum hops (links) in path
    - normalized_avg_degree: Average node degree normalized by max degree
    - fusion_prob: Quantum fusion gate success probability
    
    Args:
        paths: List of paths (each path is a list of nodes)
        topology: NetworkX graph
        fusion_prob: Fusion gate success probability (q parameter)
        
    Returns:
        List of context arrays (one per path), each with shape [1, 3]
    """
    contexts = []
    degrees = dict(topology.degree())
    max_degree = max(degrees.values()) if degrees else 1.0
    
    for path in paths:
        # Feature 1: Hop count (number of quantum links)
        hop_count = float(len(path) - 1)
        
        # Feature 2: Average node degree (normalized)
        path_degrees = [degrees[n] for n in path]
        avg_degree = float(sum(path_degrees) / len(path_degrees)) if path_degrees else 0.0
        normalized_avg_degree = avg_degree / max_degree if max_degree > 0 else 0.0
        
        # Feature 3: Fusion probability (constant per configuration)
        fusion_prob_feature = float(fusion_prob)
        
        # Context vector: [hop_count, normalized_avg_degree, fusion_prob]
        context_vector = np.array([hop_count, normalized_avg_degree, fusion_prob_feature], dtype=float)
        contexts.append([context_vector])  # Wrap in list for framework compatibility
    
    return contexts


def get_paper12_thresholds(n_nodes: int):
    """
    Get merge/split thresholds for QuARC clustering (Paper 12).
    
    In Paper 12, thresholds are computed via interpolation based on network size.
    This is a simplified version that returns basic thresholds.
    
    For full Paper 12 alignment, use get_thresholds(n) from quarc/thresholding.py
    which computes dynamic thresholds via:
        scale_thresholds(n, 16**2, merge_th_16x16_ent_passing, split_th_16x16_ent_passing)
    
    Args:
        n_nodes: Number of nodes in network
        
    Returns:
        tuple: (merge_threshold_func, split_threshold_func)
    """
    # Baseline thresholds from Paper 12 Table 2 / recreate_figs.py
    # For n=100, merge_th ≈ 0.65, split_th ≈ 0.85 (approximate values)
    
    # Simplified linear interpolation for now
    base_merge = 0.65
    base_split = 0.85
    
    # Scale adjustment based on network size (larger networks = tighter thresholds)
    size_factor = min(1.0, 100.0 / max(n_nodes, 1))
    
    merge_th = base_merge * size_factor
    split_th = base_split * size_factor
    
    # Return functions for compatibility with protocol interface
    merge_threshold_func = lambda: merge_th
    split_threshold_func = lambda: split_th
    
    return merge_threshold_func, split_threshold_func


# ============================================================================
# PAPER 7 HELPER FUNCTIONS
# ============================================================================

def generate_paper7_paths(topology, k: int, n_qisps: int, seed: int):
    """
    Generate k-shortest paths between n_qisps quantum ISP nodes.
    
    Args:
        topology: NetworkX graph (AS-level topology)
        k: Number of shortest paths per ISP pair
        n_qisps: Number of quantum ISP nodes
        seed: Random seed
        
    Returns:
        List of paths (each path is a list of nodes)
    """
    rng = np.random.default_rng(seed)
    nodes = list(topology.nodes())

    if len(nodes) < n_qisps:
        raise ValueError(f"Topology has {len(nodes)} nodes, need {n_qisps} for ISPs")
    
    # Select ISP nodes (prefer high-degree nodes like real BGP)
    degrees = dict(topology.degree())
    sorted_nodes = sorted(nodes, key=lambda n: degrees[n], reverse=True)
    isp_nodes = sorted_nodes[:n_qisps]  # Take top-degree nodes
    
    all_paths = []
    for src, dst in itertools.combinations(isp_nodes, 2):
        try:
            path_generator = nx.shortest_simple_paths(topology, src, dst, weight='distance')
            paths = list(itertools.islice(path_generator, k))
            all_paths.extend(paths)
        except nx.NetworkXNoPath:
            continue
    
    if not all_paths:
        raise RuntimeError(f"Could not find any paths between {n_qisps} ISP nodes")
    
    return all_paths


def generate_paper7_contexts(paths, topology):
    """
    Generate context vectors for each path: [hop_count, avg_degree, path_length].
    
    Args:
        paths: List of paths (each path is a list of nodes)
        topology: NetworkX graph
        
    Returns:
        List of context arrays, one per path (shape: [1, 3])
    """
    contexts = []
    
    for path in paths:
        # Feature 1: Hop count (AS path length)
        hop_count = len(path) - 1
        
        # Feature 2: Average node degree (bottleneck indicator)
        degrees = [topology.degree(node) for node in path]
        avg_degree = sum(degrees) / len(degrees) if degrees else 0.0

        # Feature 3: Physical path length (sum of edge distances)
        path_length = 0.0
        for i in range(len(path) - 1):
            edge_data = topology.get_edge_data(path[i], path[i+1])
            path_length += edge_data.get('distance', 1.0)

        # Context vector: [hop_count, avg_degree, path_length]
        context_vector = np.array([hop_count, avg_degree, path_length], dtype=float)
        contexts.append([context_vector])  # Wrap in list for framework compatibility
    
    return contexts


def get_physics_params(
    physics_model: str = "default",
    current_frames: int = 4000,
    base_seed: int = 42,
    qubit_cap=None,
    *,
    topology: "nx.Graph | None" = None,
    topology_model: str | None = None,
    topology_path: str | Path | None = None,
    topology_max_nodes: int | None = None,
    topology_largest_cc_only: bool = True,
    topology_relabel_to_int: bool = True,
    synthetic_kind: str = "barabasi_albert",
    synthetic_params: dict | None = None,
):
    """
    Unified physics parameter generator for all testbeds.
    
    Returns:
        dict: {noise_model, fidelity_calculator, external_topology, 
               external_contexts, external_rewards}
    """
    
    # ============================================================================
    # 🎯 PAPER 7 (QBGP) - PRIMARY TESTBED
    # ============================================================================
    if physics_model == "paper7":
        import time
        start_time = time.time()
        
        paper7_cfg = FRAMEWORK_CONFIG['paper7']
        node_num = paper7_cfg.get('max_nodes')

        # --- Topology Generation ---
        if topology is not None:
            final_topology = topology
            print(f"📊 Paper7 Topology: User-provided ({len(topology.nodes())} nodes)")
        else:
            # Determine if using synthetic or real AS data
            if paper7_cfg.get('use_synthetic', False) or not paper7_cfg.get('topology_path'):
                # Synthetic fallback
                synth_params = synthetic_params or paper7_cfg.get('synthetic_params', {'n': 50, 'm': 3})
                topo_gen = Paper7ASTopologyGenerator(
                    edge_list_path="dummy_nonexistent.txt",
                    max_nodes=topology_max_nodes or node_num,
                    seed=base_seed,
                    synthetic_fallback=True,
                    synthetic_kind=paper7_cfg.get('synthetic_kind', 'barabasi_albert'),
                    synthetic_params=synth_params
                )
                print(f"📊 Paper7 Topology: Synthetic ({paper7_cfg.get('synthetic_kind')}, n={synth_params.get('n', 50)})")
            else:
                # Real AS topology
                topo_gen = Paper7ASTopologyGenerator(
                    edge_list_path=paper7_cfg['topology_path'],
                    max_nodes=node_num,
                    seed=base_seed,
                    relabel_to_integers=paper7_cfg.get('relabel_to_int', True),
                    largest_cc_only=paper7_cfg.get('largest_cc_only', True),
                    synthetic_fallback=True
                )
                topo_path_short = paper7_cfg['topology_path'].split('/')[-1]
                print(f"📊 Paper7 Topology: Real AS ({topo_path_short})")
            
            final_topology = topo_gen.generate()

        # --- Path Generation ---
        k = paper7_cfg["k"]
        n_qisps = paper7_cfg["n_qisps"]
        paths = generate_paper7_paths(final_topology, k, n_qisps, base_seed)
        contexts = generate_paper7_contexts(paths, final_topology)
        
        elapsed_ms = (time.time() - start_time) * 1000
        print(f"📊 Paper7 Paths: {len(paths)} paths from {k}-shortest between {n_qisps} ISPs")
        print(f"📊 Paper7 Contexts: {len(contexts)} context vectors generated")

        # --- Reward Function (Optional) ---
        external_rewards = None
        if paper7_cfg.get('use_context_rewards', False):
            reward_mode = paper7_cfg.get('reward_mode', 'neg_hop')
            reward_func = Paper7RewardFunction(mode=reward_mode)
            external_rewards = []
            for ctx_list in contexts:
                path_rewards = [reward_func.compute(ctx) for ctx in ctx_list]
                external_rewards.append(path_rewards)
            print(f"📊 Paper7 Rewards: Context-aware (mode={reward_mode})")
        else:
            print(f"📊 Paper7 Rewards: Using default framework rewards")

        print(f"⏱️  get_physics_params_paper7() time: {elapsed_ms:.1f} ms")
        
        return {
            "noise_model": None,
            "fidelity_calculator": None,
            "external_topology": final_topology,
            "external_contexts": contexts,
            "external_rewards": external_rewards
        }
    
    # ============================================================================
    # PAPER 2 (Huang et al.)
    # ============================================================================
    elif physics_model == "paper2":
        p2_config = FRAMEWORK_CONFIG["paper2"]
        topo_gen = Paper2TopologyGenerator(num_nodes=p2_config["num_nodes"], seed=base_seed)
        topo = topo_gen.generate()
        
        try:
            path_generator = nx.shortest_simple_paths(
                topo, p2_config["source_node"], p2_config["dest_node"], weight="distance"
            )
            paths = list(itertools.islice(path_generator, p2_config["num_paths"]))
        except nx.NetworkXNoPath:
            paths = [[p2_config["source_node"], p2_config["dest_node"]]] * p2_config["num_paths"]
        
        # Stochastic noise model
        noise_model = FiberLossNoiseModel(
            topology=topo,
            paths=paths,
            p_init=p2_config.get("p_init", 0.00001),
            f_attenuation=p2_config.get("f_attenuation", 0.05)
        )
        
        # Fidelity calculator with optional memory decay
        if p2_config.get('use_memory_decay', False):
            memory_model = MemoryNoiseModel(
                T2=p2_config.get("memory_T2", 5000),
                swap_delay_per_link=p2_config.get("swap_delay_per_link", 100)
            )
            if p2_config.get("swap_mode", "sync") == "sync":
                memory_model = None
        else:
            memory_model = None
        
        fidelity_calc = FullPaper2FidelityCalculator(
            gate_error_rate=p2_config.get("gate_error_rate", 0.02) if p2_config.get('use_gate_error', False) else 0.0,
            memory_model=memory_model
        )
        
        print(f"📊 Paper2 Physics: Fiber Loss + {'Memory Decay' if memory_model else 'No Memory'}")
        
        return {
            "noise_model": noise_model,
            "fidelity_calculator": fidelity_calc,
            "external_topology": topo,
            "external_contexts": None,
            "external_rewards": None
        }

    # ============================================================================
    # PAPER 12 (Wang et al. - QuARC)
    # ============================================================================
    # ============================================================================
    # PAPER 12 (Wang et al. - QuARC)
    # ============================================================================
    elif physics_model == 'paper12':
        p12config = FRAMEWORK_CONFIG['paper12']
        
        # Get base Paper12 physics
        physics_params = get_physics_params_paper12(p12config, seed=base_seed, qubit_cap=qubit_cap)
        base_fidelity_calc = physics_params['fidelity_calculator']
        
        # Optional retry logic (only if config provides it)
        retry_threshold = p12config.get('retry_threshold', None)
        if retry_threshold is not None:
            max_attempts = p12config.get('max_retry_attempts', 3)
            decay_rate = p12config.get('retry_decay_rate', 0.95)
            fidelity_calc = Paper12RetryFidelityCalculator(
                base_calculator=base_fidelity_calc,
                threshold=retry_threshold,
                max_attempts=max_attempts,
                decay_rate=decay_rate
            )
            physics_params['fidelity_calculator'] = fidelity_calc
            
            metadata = {
                'paper': 'Wang2024Paper12',
                'retry_enabled': True,
                'retry_threshold': retry_threshold,
                'max_attempts': max_attempts,
                'decay_rate': decay_rate,
            }
            physics_params['metadata'] = metadata
            print(f"📊 Paper12 Physics: Fusion (prob={p12config['fusion_prob']}) + Retry Logic")
        else:
            metadata = {
                'paper': 'Wang2024Paper12',
                'retry_enabled': False,
            }
            physics_params['metadata'] = metadata
            print(f"📊 Paper12 Physics: Fusion (prob={p12config['fusion_prob']})")
        
        return physics_params
    
    # ============================================================================
    # DEFAULT (No special physics)
    # ============================================================================
    else:
        return {
            "noise_model": None,
            "fidelity_calculator": None,
            "external_topology": topology,
            "external_contexts": None,
            "external_rewards": None
        }


def get_physics_params_paper12(config, seed, qubit_cap):
    """
    Paper #12 (QuARC) physics adapter - CORRECTED VERSION.
    
    Uses Paper 12 standard parameters:
    - E_p = 0.6 (entanglement probability)
    - q = 0.9 (fusion success probability)
    - k = 3 (split constant for Girvan-Newman)
    """
    
    # Generate Waxman topology
    topology = Paper12WaxmanTopologyGenerator().generate()
    
    # Generate 4 paths for framework testing
    num_paths = 4
    nodes = list(topology.nodes())
    rng = np.random.default_rng(seed)
    
    paths = []
    attempts = 0
    max_attempts = 10 * num_paths
    
    while len(paths) < num_paths and attempts < max_attempts:
        attempts += 1
        src, dst = rng.choice(nodes, 2, replace=False)
        try:
            path = nx.shortest_path(topology, src, dst)
            if path not in paths:
                paths.append(path)
        except nx.NetworkXNoPath:
            continue
    
    if len(paths) < num_paths:
        raise RuntimeError(f"Could not find {num_paths} valid paths")
    
    # ✅ CORRECT Paper 12 parameters
    fusion_prob = 0.9           # q from Paper 12
    entanglement_prob = 0.6     # E_p from Paper 12
    
    noise_model = FusionNoiseModel(
        topology=topology, 
        paths=paths, 
        fusion_prob=fusion_prob, 
        entanglement_prob=entanglement_prob
    )
    fidelity_calc = FusionFidelityCalculator()
    
    # ✅ CORRECT: Derive arms from topology
    external_contexts = []
    external_rewards = []
    degrees = dict(topology.degree())
    max_degree = max(degrees.values()) if degrees else 1.0
    
    for path in paths:
        # Get qubit capacity for this path
        min_qubits = min(topology.nodes[node].get('qubits', 5) for node in path)
        num_arms = min_qubits  # Or use k=3 for Paper 12 standard
        
        # Generate contexts
        hop_count = len(path) - 1
        path_degrees = [degrees[n] for n in path]
        avg_degree = float(sum(path_degrees) / len(path_degrees))
        f2_deg_norm = avg_degree / max_degree if max_degree > 0 else 0.0
        
        ctx = np.full((num_arms, 3), 
                     [float(hop_count), f2_deg_norm, fusion_prob], 
                     dtype=float)
        external_contexts.append(ctx)
        
        # ✅ CORRECT: Use actual entanglement physics (no Beta sampling)
        path_rewards = []
        for q_alloc in range(1, num_arms + 1):
            # Per-link success probability with q_alloc qubits
            p_link = 1 - (1 - entanglement_prob) ** q_alloc
            # End-to-end success (product over hops × fusion)
            p_path = (p_link ** hop_count) * fusion_prob
            # No ×100 scaling - use actual probability
            path_rewards.append(float(p_path))
        
        external_rewards.append(path_rewards)
    
    return {
        "external_topology": topology,
        "external_contexts": external_contexts,
        "external_rewards": external_rewards,
        "noise_model": noise_model,
        "fidelity_calculator": fidelity_calc,
    }



def force_release_resources(evaluator=None, verbose=True):
    """Force release of ALL resources that could block. Call AFTER each allocator completes."""
    cleanup_log = []

    # 1. Stop logging and close file handles
    if evaluator is not None:
        try:
            if hasattr(evaluator, 'configs') and hasattr(evaluator.configs, 'backup_mgr'):
                backup_mgr = evaluator.configs.backup_mgr
                if hasattr(backup_mgr, 'stop_logging_redirect'):
                    backup_mgr.stop_logging_redirect()
                if hasattr(backup_mgr, '_log_file'):
                    try:
                        backup_mgr._log_file.close()
                    except:
                        pass
                if hasattr(backup_mgr, 'backup_registry'):
                    backup_mgr.backup_registry.clear()
            cleanup_log.append("✅ Backup manager cleaned")
        except Exception as e:
            cleanup_log.append(f"⚠️ Backup cleanup: {e}")

    # 2. Clear environment graphs
    if evaluator is not None:
        try:
            if hasattr(evaluator, 'configs') and hasattr(evaluator.configs, 'environment'):
                env = evaluator.configs.environment
                if hasattr(env, 'topology') and hasattr(env.topology, 'clear'):
                    env.topology.clear()
                    del env.topology
                if hasattr(env, 'paths'):
                    env.paths = []
            cleanup_log.append("✅ Environment graphs cleared")
        except Exception as e:
            cleanup_log.append(f"⚠️ Environment cleanup: {e}")

    # 3. Break circular references
    if evaluator is not None:
        try:
            if hasattr(evaluator, 'configs'):
                if hasattr(evaluator.configs, 'backup_mgr'):
                    evaluator.configs.backup_mgr = None
                if hasattr(evaluator.configs, 'environment'):
                    evaluator.configs.environment = None
                evaluator.configs = None
            cleanup_log.append("✅ Circular references broken")
        except Exception as e:
            cleanup_log.append(f"⚠️ Reference cleanup: {e}")

    # 4. Clear model registries
    try:
        import sys
        for mod_name in list(sys.modules.keys()):
            if 'bandit' in mod_name.lower() or 'neural' in mod_name.lower():
                mod = sys.modules[mod_name]
                if hasattr(mod, '_model_registry'):
                    mod._model_registry.clear()
                if hasattr(mod, '_global_models'):
                    mod._global_models.clear()
        cleanup_log.append("✅ Model registries cleared")
    except Exception as e:
        cleanup_log.append(f"⚠️ Registry cleanup: {e}")

    # 5. Torch cleanup
    try:
        import torch
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            torch.cuda.synchronize()
        cleanup_log.append("✅ Torch CUDA cleared")
    except Exception as e:
        cleanup_log.append(f"⚠️ Torch cleanup: {e}")

    # 6. Garbage collection
    collected = [gc.collect() for _ in range(3)]
    cleanup_log.append(f"✅ GC collected: {sum(collected)} objects")

    # 7. Close file descriptors
    try:
        import psutil
        process = psutil.Process()
        for f in process.open_files():
            if any(ext in f.path for ext in ['.pkl', '.log', '.csv']):
                try:
                    os.close(f.fd)
                except:
                    pass
        cleanup_log.append("✅ File descriptors closed")
    except Exception as e:
        cleanup_log.append(f"⚠️ FD cleanup: {e}")

    # 8. Delete evaluator and final collection
    if evaluator is not None:
        del evaluator
    gc.collect(2)

    if verbose:
        print("\n" + "="*70)
        print("🧹 FORCED RESOURCE RELEASE")
        print("="*70)
        for log in cleanup_log:
            print(log)
        print("="*70 + "\n")

    return True


# ============================================================================
# VALIDATION: Quick Paper 7 Sanity Check
# ============================================================================
print("\n" + "="*70)
print("🔍 PAPER 7 QUICK VALIDATION")
print("="*70)

try:
    # Test Paper 7 physics generation
    test_params = get_physics_params(
        physics_model='paper7',
        base_seed=42
    )
    
    print(f"✅ Topology: {len(test_params['external_topology'].nodes())} nodes, "
          f"{len(test_params['external_topology'].edges())} edges")
    print(f"✅ Contexts: {len(test_params['external_contexts'])} paths")
    print(f"✅ Rewards: {'Enabled' if test_params['external_rewards'] else 'Disabled'}")
    print("\n✓ Paper 7 integration validated successfully")
    
except Exception as e:
    print(f"❌ Validation failed: {e}")
    import traceback
    traceback.print_exc()

print("="*70 + "\n")

print("🚀 Ready to run Paper 7 (QBGP) experiments!")
print("   Example: PHYSICS_MODELS = ['paper7']")
print("            ALLOCATORS = ['ThompsonSampling', 'DynamicUCB']")

# ============================================================================
# VALIDATION: Quick Paper 12 Sanity Check
# ============================================================================
print("\n" + "="*70)
print("🔍 PAPER 12 (QuARC) QUICK VALIDATION")
print("="*70)

try:
    # Test Paper 12 physics generation
    test_params_p12 = get_physics_params(
        physics_model='paper12',
        base_seed=42
    )
    
    print(f"✅ Topology: {len(test_params_p12['external_topology'].nodes())} nodes, "
          f"{len(test_params_p12['external_topology'].edges())} edges")
    print(f"✅ Contexts: {len(test_params_p12['external_contexts'])} paths")
    print(f"✅ Context features per path: {test_params_p12['external_contexts'][0][0].shape}")
    
    # Print actual reward values
    print(f"✅ Rewards: {len(test_params_p12['external_rewards'])} reward lists")
    total_rew = sum(sum(r) for r in test_params_p12['external_rewards'])
    avg_rew = total_rew / sum(len(r) for r in test_params_p12['external_rewards'])
    print(f"   → Path 0 rewards (first 3): {[f'{r:.1f}' for r in test_params_p12['external_rewards'][0][:3]]}")
    print(f"   → Total aggregate reward: {total_rew:.1f}")
    print(f"   → Average per-arm reward: {avg_rew:.1f}")
    
    print(f"✅ Fusion probability: {FRAMEWORK_CONFIG['paper12']['fusion_prob']}")
    print(f"✅ Entanglement probability: {FRAMEWORK_CONFIG['paper12']['entanglement_prob']}")
    print(f"✅ Epoch length: {FRAMEWORK_CONFIG['paper12']['epoch_length']} timeslots")
    print(f"✅ Total simulation: {FRAMEWORK_CONFIG['paper12']['total_timeslots']} timeslots")
    print("\n✓ Paper 12 (QuARC) integration validated successfully")
    
except Exception as e:
    print(f"❌ Paper 12 validation failed: {e}")
    import traceback
    traceback.print_exc()

print("="*70 + "\n")

print("🚀 Ready to run Paper 12 (QuARC) experiments!")
print("   Example: PHYSICS_MODELS = ['paper12']")
print("            ALLOCATORS = ['Default', 'Dynamic', 'ThompsonSampling', 'Random']")
print("\n   Note: For full Paper 12 alignment, obtain Q-CAST .net topology files")
print("         and enable BlobbedQCastNetwork in get_physics_params_paper12()")
# Out:
# ======================================================================
# 🔍 PAPER 7 QUICK VALIDATION
# ======================================================================
# 📊 Paper7 Topology: Real AS (as20000101.txt)
# 📊 Paper7 Paths: 15 paths from 5-shortest between 3 ISPs
# 📊 Paper7 Contexts: 15 context vectors generated
# 📊 Paper7 Rewards: Context-aware (mode=neg_hop)
# ⏱️  get_physics_params_paper7() time: 4.2 ms
# ✅ Topology: 50 nodes, 141 edges
# ✅ Contexts: 15 paths
# ✅ Rewards: Enabled
#
# ✓ Paper 7 integration validated successfully
# ======================================================================
#
# 🚀 Ready to run Paper 7 (QBGP) experiments!
#    Example: PHYSICS_MODELS = ['paper7']
#             ALLOCATORS = ['ThompsonSampling', 'DynamicUCB']
#
# ======================================================================
# 🔍 PAPER 12 (QuARC) QUICK VALIDATION
# ======================================================================
# Generated paper12 Waxman topology: 100 nodes, 355 edges, avg degree: 7.10
# 📊 Paper12 Physics: Fusion (prob=0.9)
# ✅ Topology: 100 nodes, 355 edges
# ✅ Contexts: 4 paths
# ✅ Context features per path: (3,)
# ✅ Rewards: 4 reward lists
#    → Path 0 rewards (first 3): ['0.3', '0.6', '0.8']
#    → Total aggregate reward: 13.1
#    → Average per-arm reward: 0.7
# ✅ Fusion probability: 0.9
# ✅ Entanglement probability: 0.6
# ✅ Epoch length: 500 timeslots
# ✅ Total simulation: 5000 timeslots
#
# ✓ Paper 12 (QuARC) integration validated successfully
# ======================================================================
#
# 🚀 Ready to run Paper 12 (QuARC) experiments!
#    Example: PHYSICS_MODELS = ['paper12']
#             ALLOCATORS = ['Default', 'Dynamic', 'ThompsonSampling', 'Random']
#
#    Note: For full Paper 12 alignment, obtain Q-CAST .net topology files
#          and enable BlobbedQCastNetwork in get_physics_params_paper12()

# %%
# ============================================================
# Cell: Allocator + ExperimentConfiguration for Paper #12
# ALLOCATOR: Default (Baseline for Paper 12 QuARC)
# ============================================================
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.quantum_physics              import *
from daqr.evaluation.allocator_runner       import AllocatorRunner
from daqr.evaluation.multi_run_evaluator    import MultiRunEvaluator
from daqr.config.experiment_config          import ExperimentConfiguration

print("=" * 70)
print("PAPER #12 (QuARC) - DEFAULT ALLOCATOR")
print("=" * 70)

# ============================================================================
# PAPER 12 EXECUTION FLOW:
# ============================================================================
# 1. get_physics_params(physics_model='paper12', ...):
#    → Calls get_physics_params_paper12(config, seed, qubit_cap)
#    → Generates Waxman topology (fallback) or BlobbedQCastNetwork (.net files)
#    → Calls generate_paper12_paths() to find 4 S-D paths
#    → Calls generate_paper12_contexts() to create context vectors
#    → Computes rewards via FusionNoiseModel (fusion_prob=0.9)
#
# 2. AllocatorRunner.run():
#    → Instantiates allocator (Default/Dynamic/ThompsonSampling/Random)
#    → Iterates through frame_step checkpoints (aligned to epoch_length=500)
#    → Each checkpoint: allocator.allocate() → select qubit distribution
#    → Rewards update via FusionNoiseModel.get_error_rates(path_idx)
#    → QuARC protocol checks thresholds at epoch boundaries
#
# 3. Results aggregated and saved:
#    → Metadata: paper=Wang2024Paper12, retry_enabled=False
#    → Topology: Waxman (n=100, E_d=6)
#    → Physics: E_p=0.6, q=0.9
#    → Simulation: T=1500ts, epoch=500, 3 epochs
# ============================================================================

# --- Paper 12 Allocator Configuration ---
ALLOCATORS = ["Default"]

# --- Paper 12 Run Parameters (Aligned with ICNP 2024 spec) ---
# Frame configuration aligned to QuARC epoch length
epoch_length_ts = FRAMEWORK_CONFIG['paper12']['epoch_length']  # 500 timeslots
total_sim_ts = FRAMEWORK_CONFIG['paper12']['total_timeslots']  # 5000 timeslots

attack_intensity    = FRAMEWORK_CONFIG['intensity']
current_frames      = min(1500, total_sim_ts)  # 3 epochs for testing
frame_step          = epoch_length_ts           # Checkpoint every epoch
current_experiments = 1
last_backup         = False
base_cap            = False
overwrite           = True

RUNS                = [5]               # Acceptable for initial testing
SCALES              = [1.5]             # Single scale
ATTACK_SCENARIOS    = ['stochastic']    # Start simple
print(f"✅ Testing QuARC with {current_frames} timeslots")
print(f"✅ Expected reconfigurations: {current_frames // 500}")
print(f"✅ Statistical runs: {RUNS[0]}")

FRAMEWORK_CONFIG['exp_num']     = current_experiments
FRAMEWORK_CONFIG['base_frames'] = current_frames
FRAMEWORK_CONFIG['frame_step']  = frame_step

# Testbed Configuration
PHYSICS_MODELS = ['paper12']  # Paper 12 (QuARC)
ATTACK_SCENARIOS = ['stochastic']  # Start simple

print("\n" + "=" * 70)
print("PAPER 12 ALLOCATOR EVALUATION")
print("=" * 70)
print(f"Allocators:                 {ALLOCATORS}")
print(f"Physics Models:             {PHYSICS_MODELS}")
print(f"Attack Scenarios:           {ATTACK_SCENARIOS}")
print(f"Scales:                     {SCALES}")
print(f"Runs per Scale:             {RUNS}")
print(f"Total Frames:               {current_frames}")
print("=" * 70)

for allocator_type in ALLOCATORS:
    print(f"\n{'='*70}")
    print(f"RUNNING: {allocator_type} on Paper 12 (QuARC)")
    print('='*70)

    try:
        # Create isolated runner instance
        custom_config = ExperimentConfiguration(
            env_type=FRAMEWORK_CONFIG['main_env'],
            scenarios=test_scenarios,
            use_last_backup=last_backup,
            models=models,
            attack_intensity=attack_intensity,
            scale=1,
            base_capacity=base_cap,
            overwrite=overwrite
        )

        alloc_runner = AllocatorRunner(
            allocator_type=allocator_type,
            physics_models=PHYSICS_MODELS,
            framework_config=FRAMEWORK_CONFIG,
            scales=SCALES,
            runs=RUNS,
            models=models,
            test_scenarios=test_scenarios,
            config=custom_config
        )

        # Run with Paper 12 physics
        alloc_runner.run(get_physics_params_func=get_physics_params)
        print(f"\n{allocator_type} COMPLETED SUCCESSFULLY")

    except Exception as e:
        print(f"\n{allocator_type} FAILED: {e}")
        import traceback
        traceback.print_exc()

print("\n" + "=" * 70)
print("ALL ALLOCATORS COMPLETE!")
print("=" * 70)
# Out:
# ======================================================================
# PAPER #12 (QuARC) - DEFAULT ALLOCATOR
# ======================================================================
# ✅ Testing QuARC with 1500 timeslots
# ✅ Expected reconfigurations: 3
# ✅ Statistical runs: 5
#
# ======================================================================
# PAPER 12 ALLOCATOR EVALUATION
# ======================================================================
# Allocators:                 ['Default']
# Physics Models:             ['paper12']
# Attack Scenarios:           ['stochastic']
# Scales:                     [1.5]
# Runs per Scale:             [5]
# Total Frames:               1500
# ======================================================================
#
# ======================================================================
# RUNNING: Default on Paper 12 (QuARC)
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
#       Relative: framework_state/day_20260130
#       Component: framework_state
#       Date: day_20260130
#       📄 Processing 1981 files in framework_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260130: 1981/1981 files processed
#       📊 framework_state/day_20260130: 0/1981 files skipped
#       📊 framework_state/day_20260130: 0/1981 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
#       Relative: model_state/day_20260130
#       Component: model_state
#       Date: day_20260130
#       📄 Processing 6273 files in model_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260130: 6273/6273 files processed
#       📊 model_state/day_20260130: 0/6273 files skipped
#       📊 model_state/day_20260130: 0/6273 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1981 files
#   • model_state: 6273 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 8254
# ================================================================================
#
# 	→ Filesystem scan found 8254 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# ======================================================================
# 🎯 AllocatorRunner initialized: Default
# ======================================================================
#
# ======================================================================
# 🚀 STARTING ALLOCATOR: Default
# ======================================================================
#
# 📊 Physics Model: paper12
#
# 📋 Allocator Config:
#    Type: Default
#    Testbed: paper12
#    Paths: 4
#    Total Qubits: 100
#    Min per route: 3
#    Seed: 42
# ✅ Allocator created: (25, 25, 25, 25)
# ✓ Allocator: QubitAllocator (4 paths)
#    Initial allocation: (25, 25, 25, 25)
# Generated paper12 Waxman topology: 100 nodes, 379 edges, avg degree: 7.58
# 📊 Paper12 Physics: Fusion (prob=0.9)
#
# ======================================================================
# RUN 1 | Scale: 1.5 | Exp: 5
# ======================================================================
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 1500 -> 3500 (step: 500)
# quantum_exps-Default(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T_20260130_log.txt
# ⚙ Running evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Experiments per Scenario:   	5
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=0 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 1: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0839.51, Efficiency=062.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=2250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0611.14, Efficiency=045.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0822.13, Efficiency=061.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0847.12, Efficiency=063.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:036.6%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:1500, SCapacity=2250, Alloc=Default]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=1 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 2: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=1124.35, Efficiency=063.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=3000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=1135.88, Efficiency=063.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=3000, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=1140.88, Efficiency=064.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=3000, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=1115.52, Efficiency=062.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:036.0%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2000, SCapacity=3000, Alloc=Default]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=2 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 3: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1433.38, Efficiency=064.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=3750, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=1424.31, Efficiency=064.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=3750, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1435.31, Efficiency=064.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=3750, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1439.33, Efficiency=064.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:035.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2500, SCapacity=3750, Alloc=Default]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=3 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 4: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1711.01, Efficiency=064.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1563.70, Efficiency=058.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1690.18, Efficiency=063.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1695.98, Efficiency=063.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:036.0%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3000, SCapacity=4500, Alloc=Default]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=4 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 5: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1982.10, Efficiency=063.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=2007.74, Efficiency=064.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1993.35, Efficiency=063.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=2040.67, Efficiency=065.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:034.5%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3500, SCapacity=5250, Alloc=Default]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 607.3s
# Experiments completed for none
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=0 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 1: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0782.15, Efficiency=058.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=2250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0809.47, Efficiency=060.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0795.82, Efficiency=059.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0784.09, Efficiency=058.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:039.4%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:1500, SCapacity=2250, Alloc=Default]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=1 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 2: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=1039.53, Efficiency=058.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=3000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0947.20, Efficiency=053.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=1047.57, Efficiency=058.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=1078.09, Efficiency=060.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:039.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2000, SCapacity=3000, Alloc=Default]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=2 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 3: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1331.67, Efficiency=059.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=3750, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=1375.81, Efficiency=061.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1317.96, Efficiency=059.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1323.96, Efficiency=059.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:038.2%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2500, SCapacity=3750, Alloc=Default]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=3 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 4: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1588.26, Efficiency=059.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1564.87, Efficiency=058.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1583.92, Efficiency=059.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1581.33, Efficiency=059.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:040.6%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3000, SCapacity=4500, Alloc=Default]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=4 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 5: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1892.37, Efficiency=060.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1924.87, Efficiency=061.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1858.53, Efficiency=059.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1853.81, Efficiency=059.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:038.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3500, SCapacity=5250, Alloc=Default]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 1593.1s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=0 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 1: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0404.10, Efficiency=032.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0383.94, Efficiency=031.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0417.10, Efficiency=033.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0425.75, Efficiency=034.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:065.7%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:1500, SCapacity=2250, Alloc=Default]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=1 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 2: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0580.34, Efficiency=034.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0527.54, Efficiency=031.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0550.25, Efficiency=032.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0627.69, Efficiency=037.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Default, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:062.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2000, SCapacity=3000, Alloc=Default]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=2 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 3: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0725.40, Efficiency=034.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0700.30, Efficiency=033.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=0766.01, Efficiency=036.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0761.40, Efficiency=036.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Default, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:063.1%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2500, SCapacity=3750, Alloc=Default]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=3 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 4: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=0911.63, Efficiency=036.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=0629.68, Efficiency=025.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=0883.54, Efficiency=035.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=0967.22, Efficiency=038.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Default, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:061.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=Default]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=4 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 5: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20713
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1023.93, Efficiency=035.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=0959.66, Efficiency=032.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1039.17, Efficiency=035.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1073.44, Efficiency=036.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20713
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:063.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3500, SCapacity=5250, Alloc=Default]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 1204.7s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=0 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for ADAPTIVE Exp 1: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 19674
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0606.78, Efficiency=045.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0611.09, Efficiency=045.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0614.56, Efficiency=046.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0625.84, Efficiency=047.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:1500, QubitAlloc=Default, SC:2250 (Scale=1.5 x Cap=1500), Seed: 19674
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:053.0%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:1500, SCapacity=2250, Alloc=Default]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=1 → allocation=(25, 25, 25, 25)
# ...
# 	-->🏆 EXP4 Winner:CPursuitNeuralUCB   (Gap:050.8%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=Default]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=4 → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for ONLINEADAPTIVE Exp 5: (25, 25, 25, 25)
# 🔄 Default Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.54, 0.756, 0.8423999999999999, 0.8769600000000001, 0.890784], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1454.22, Efficiency=046.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1398.64, Efficiency=045.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1507.57, Efficiency=048.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1446.84, Efficiency=046.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Default, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# 	-->🏆 EXP5 Winner:CPursuitNeuralUCB   (Gap:051.4%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3500, SCapacity=5250, Alloc=Default]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 2076.8s
# Experiments completed for onlineadaptive
# ✓ Scenario 'none' evaluation completed.
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2226.96
# 	• Winner Avg Gap: 0036.09%
# 	• Winner Avg Reward: 1427.72
# 	• Winner Avg Efficiency: 0063.91%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	036.1%
# 	Winner Avg Efficiency: 	063.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	063.9% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	063.6% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	063.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	059.3% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2226.80
# 	• Winner Avg Gap: 0040.54%
# 	• Winner Avg Reward: 1324.26
# 	• Winner Avg Efficiency: 0059.46%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	040.5%
# 	Winner Avg Efficiency: 	059.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	059.5% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	059.3% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	059.2% Efficiency 	(Won 3/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2083.14
# 	• Winner Avg Gap: 0063.22%
# 	• Winner Avg Reward: 0771.10
# 	• Winner Avg Efficiency: 0036.78%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	063.2%
# 	Winner Avg Efficiency: 	036.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	036.8% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	034.9% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	034.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	030.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2217.12
# 	• Winner Avg Gap: 0051.97%
# 	• Winner Avg Reward: 1075.14
# 	• Winner Avg Efficiency: 0048.03%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	052.0%
# 	Winner Avg Efficiency: 	048.0%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	048.0% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	047.3% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.0% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	046.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2216.82
# 	• Winner Avg Gap: 0052.20%
# 	• Winner Avg Reward: 1065.24
# 	• Winner Avg Efficiency: 0047.80%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	052.2%
# 	Winner Avg Efficiency: 	047.8%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	047.8% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	047.4% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.2% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	042.4% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (iCPursuitNeuralUCB):
# 	• Stochastic Performance:    	1324.257
# 	• Baseline Performance:      	1427.723
# 	• Performance Retention:     	092.8%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2226.96
# 	• Winner Avg Gap: 0036.09%
# 	• Winner Avg Reward: 1427.72
# 	• Winner Avg Efficiency: 0063.91%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	036.1%
# 	Winner Avg Efficiency: 	063.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	063.9% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	063.6% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	063.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	059.3% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2226.80
# 	• Winner Avg Gap: 0040.54%
# 	• Winner Avg Reward: 1324.26
# 	• Winner Avg Efficiency: 0059.46%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	040.5%
# 	Winner Avg Efficiency: 	059.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	059.5% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	059.3% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	059.2% Efficiency 	(Won 3/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2083.14
# 	• Winner Avg Gap: 0063.22%
# 	• Winner Avg Reward: 0771.10
# 	• Winner Avg Efficiency: 0036.78%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	063.2%
# 	Winner Avg Efficiency: 	036.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	036.8% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	034.9% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	034.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	030.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2217.12
# 	• Winner Avg Gap: 0051.97%
# 	• Winner Avg Reward: 1075.14
# 	• Winner Avg Efficiency: 0048.03%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	052.0%
# 	Winner Avg Efficiency: 	048.0%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	048.0% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	047.3% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.0% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	046.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2216.82
# 	• Winner Avg Gap: 0052.20%
# 	• Winner Avg Reward: 1065.24
# 	• Winner Avg Efficiency: 0047.80%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	052.2%
# 	Winner Avg Efficiency: 	047.8%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	047.8% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	047.4% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.2% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	042.4% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✅ Evaluation completed!
# [Logging Redirect Stopped]
#
# 🧹 Final cleanup for Default
#
# ======================================================================
# ✅ COMPLETED: Default
# ======================================================================
#
# Default COMPLETED SUCCESSFULLY
#
# ======================================================================
# ALL ALLOCATORS COMPLETE!
# ======================================================================

# %%
# ============================================================
# Cell: Allocator + ExperimentConfiguration for Paper #12
# ============================================================
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.quantum_physics              import *
from daqr.evaluation.allocator_runner       import AllocatorRunner
from daqr.evaluation.multi_run_evaluator    import MultiRunEvaluator
from daqr.config.experiment_config          import ExperimentConfiguration

print("=" * 70)
print("PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS")
print("=" * 70)

# ------------------------------------------------------------
# 1) Allocator Selection
# ------------------------------------------------------------
ALLOCATORS = ["Dynamic"]

# ------------------------------------------------------------
# 2) Run Parameters
# ------------------------------------------------------------
# CORRECTED Paper 12 Evaluation
attack_intensity    = FRAMEWORK_CONFIG['intensity']
current_frames      = 1500      # 3 reconfiguration cycles
frame_step          = 500       # Epoch-aligned checkpoints
current_experiments = 1
last_backup         = False
base_cap            = False
overwrite           = True

RUNS                = [5]               # Acceptable for initial testing
SCALES              = [1.5]             # Single scale
ATTACK_SCENARIOS    = ['stochastic']    # Start simple
print(f"✅ Testing QuARC with {current_frames} timeslots")
print(f"✅ Expected reconfigurations: {current_frames // 500}")
print(f"✅ Statistical runs: {RUNS[0]}")

FRAMEWORK_CONFIG['exp_num']     = current_experiments
FRAMEWORK_CONFIG['base_frames'] = current_frames
FRAMEWORK_CONFIG['frame_step']  = frame_step

# Testbed Configuration
PHYSICS_MODELS = ['paper12']  # Paper 12 (QuARC)
ATTACK_SCENARIOS = ['stochastic']  # Start simple

print("\n" + "=" * 70)
print("PAPER 12 ALLOCATOR EVALUATION")
print("=" * 70)
print(f"Allocators:                 {ALLOCATORS}")
print(f"Physics Models:             {PHYSICS_MODELS}")
print(f"Attack Scenarios:           {ATTACK_SCENARIOS}")
print(f"Scales:                     {SCALES}")
print(f"Runs per Scale:             {RUNS}")
print(f"Total Frames:               {current_frames}")
print("=" * 70)

for allocator_type in ALLOCATORS:
    print(f"\n{'='*70}")
    print(f"RUNNING: {allocator_type} on Paper 12 (QuARC)")
    print('='*70)

    try:
        # Create isolated runner instance
        custom_config = ExperimentConfiguration(
            env_type=FRAMEWORK_CONFIG['main_env'],
            scenarios=test_scenarios,
            use_last_backup=last_backup,
            models=models,
            attack_intensity=attack_intensity,
            scale=1,
            base_capacity=base_cap,
            overwrite=overwrite
        )

        alloc_runner = AllocatorRunner(
            allocator_type=allocator_type,
            physics_models=PHYSICS_MODELS,
            framework_config=FRAMEWORK_CONFIG,
            scales=SCALES,
            runs=RUNS,
            models=models,
            test_scenarios=test_scenarios,
            config=custom_config
        )

        # Run with Paper 12 physics
        alloc_runner.run(get_physics_params_func=get_physics_params)
        print(f"\n{allocator_type} COMPLETED SUCCESSFULLY")

    except Exception as e:
        print(f"\n{allocator_type} FAILED: {e}")
        import traceback
        traceback.print_exc()

print("\n" + "=" * 70)
print("ALL ALLOCATORS COMPLETE!")
print("=" * 70)
# Out:
# ======================================================================
# PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS
# ======================================================================
# ✅ Testing QuARC with 1500 timeslots
# ✅ Expected reconfigurations: 3
# ✅ Statistical runs: 5
#
# ======================================================================
# PAPER 12 ALLOCATOR EVALUATION
# ======================================================================
# Allocators:                 ['Dynamic']
# Physics Models:             ['paper12']
# Attack Scenarios:           ['stochastic']
# Scales:                     [1.5]
# Runs per Scale:             [5]
# Total Frames:               1500
# ======================================================================
#
# ======================================================================
# RUNNING: Dynamic on Paper 12 (QuARC)
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260128
#       Relative: framework_state/day_20260128
#       Component: framework_state
#       Date: day_20260128
#       📄 Processing 1 files in framework_state/day_20260128
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260128: 0/1 files processed
#       📊 framework_state/day_20260128: 0/1 files skipped
#       📊 framework_state/day_20260128: 1/1 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260129
#       Relative: framework_state/day_20260129
#       Component: framework_state
#       Date: day_20260129
#       📄 Processing 41 files in framework_state/day_20260129
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260129: 40/41 files processed
#       📊 framework_state/day_20260129: 0/41 files skipped
#       📊 framework_state/day_20260129: 1/41 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
#       Relative: framework_state/day_20260130
#       Component: framework_state
#       Date: day_20260130
#       📄 Processing 2007 files in framework_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260130: 2007/2007 files processed
#       📊 framework_state/day_20260130: 0/2007 files skipped
#       📊 framework_state/day_20260130: 0/2007 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
#       Relative: model_state/day_20260130
#       Component: model_state
#       Date: day_20260130
#       📄 Processing 6334 files in model_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260130: 6334/6334 files processed
#       📊 model_state/day_20260130: 0/6334 files skipped
#       📊 model_state/day_20260130: 0/6334 files conflicted
#
#    📊 Processed 4 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 2009 files
#   • model_state: 6334 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 8343
# ================================================================================
#
# 	→ Filesystem scan found 8343 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# ======================================================================
# 🎯 AllocatorRunner initialized: Dynamic
# ======================================================================
#
# ======================================================================
# 🚀 STARTING ALLOCATOR: Dynamic
# ======================================================================
#
# 📊 Physics Model: paper12
#
# 📋 Allocator Config:
#    Type: Dynamic
#    Testbed: paper12
#    Paths: 4
#    Total Qubits: 100
#    Min per route: 3
#    Seed: 42
#    Exploration bonus: 1.5
# ✅ Allocator created: (25, 25, 25, 25)
# ✓ Allocator: DynamicQubitAllocator (4 paths)
#    Initial allocation: (25, 25, 25, 25)
# Generated paper12 Waxman topology: 100 nodes, 430 edges, avg degree: 8.60
# 📊 Paper12 Physics: Fusion (prob=0.9)
#
# ======================================================================
# RUN 1 | Scale: 1.5 | Exp: 5
# ======================================================================
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 1500 -> 3500 (step: 500)
# quantum_exps-Dynamic(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Dynamic(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T_20260131_log.txt
# ⚙ Running evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Experiments per Scenario:   	5
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 1: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0812.69, Efficiency=060.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=2250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0807.25, Efficiency=060.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0802.96, Efficiency=060.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0802.76, Efficiency=060.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:039.2%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:1500, SCapacity=2250, Alloc=Dynamic]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 2: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=1128.68, Efficiency=063.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=3000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=1110.57, Efficiency=062.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=1067.68, Efficiency=059.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=1095.68, Efficiency=061.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:036.6%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2000, SCapacity=3000, Alloc=Dynamic]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 3: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1356.60, Efficiency=060.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=3750, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=1379.52, Efficiency=061.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1393.15, Efficiency=062.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1351.88, Efficiency=060.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:037.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2500, SCapacity=3750, Alloc=Dynamic]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 4: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1656.37, Efficiency=062.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1762.90, Efficiency=066.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1669.56, Efficiency=062.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1649.21, Efficiency=061.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# 	-->🏆 EXP4 Winner:EXPNeuralUCB        (Gap:034.0%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3000, SCapacity=4500, Alloc=Dynamic]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 5: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1941.29, Efficiency=062.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=2046.04, Efficiency=065.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=5250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1896.11, Efficiency=060.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1941.30, Efficiency=062.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:034.4%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3500, SCapacity=5250, Alloc=Dynamic]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 1805.1s
# Experiments completed for none
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 1: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0722.45, Efficiency=054.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0809.08, Efficiency=060.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0727.30, Efficiency=054.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0759.88, Efficiency=056.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:039.4%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:1500, SCapacity=2250, Alloc=Dynamic]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 2: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=1004.10, Efficiency=056.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0807.43, Efficiency=045.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=1036.68, Efficiency=058.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=1000.91, Efficiency=056.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:041.8%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2000, SCapacity=3000, Alloc=Dynamic]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 3: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1244.94, Efficiency=055.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=1248.36, Efficiency=056.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1239.48, Efficiency=055.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1242.40, Efficiency=055.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:043.9%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2500, SCapacity=3750, Alloc=Dynamic]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 4: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1543.48, Efficiency=057.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1276.66, Efficiency=047.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1528.85, Efficiency=057.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1513.08, Efficiency=056.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:042.2%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3000, SCapacity=4500, Alloc=Dynamic]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 5: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1796.78, Efficiency=057.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1628.80, Efficiency=052.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1838.75, Efficiency=059.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1869.06, Efficiency=060.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:040.0%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3500, SCapacity=5250, Alloc=Dynamic]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 791.3s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 1: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0384.78, Efficiency=031.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0419.09, Efficiency=033.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0390.88, Efficiency=031.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0418.76, Efficiency=033.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:066.2%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:1500, SCapacity=2250, Alloc=Dynamic]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 2: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0542.70, Efficiency=032.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0543.16, Efficiency=032.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0544.22, Efficiency=032.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0589.82, Efficiency=035.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Dynamic, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:064.7%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2000, SCapacity=3000, Alloc=Dynamic]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 3: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0653.68, Efficiency=031.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0601.46, Efficiency=029.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=0679.90, Efficiency=032.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0715.64, Efficiency=034.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Dynamic, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:065.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2500, SCapacity=3750, Alloc=Dynamic]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 4: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=0816.55, Efficiency=032.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=0640.33, Efficiency=025.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=0795.81, Efficiency=031.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=0839.70, Efficiency=033.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Dynamic, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:066.4%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=Dynamic]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 5: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20713
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=0920.09, Efficiency=031.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=0855.42, Efficiency=029.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=0929.82, Efficiency=031.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=0984.60, Efficiency=033.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20713
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:066.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3500, SCapacity=5250, Alloc=Dynamic]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 670.5s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for ADAPTIVE Exp 1: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:1500, QubitAlloc=Dynamic, SC:2250 (Scale=1.5 x Cap=1500), Seed: 19674
# ...
# 	-->🏆 EXP4 Winner:CPursuitNeuralUCB   (Gap:051.8%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=Dynamic]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [DynamicAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for ONLINEADAPTIVE Exp 5: (25, 25, 25, 25)
# 🔄 Dynamic Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.324, 0.6350399999999999, 0.7884863999999999, 0.8545098240000001, 0.88166237184], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1449.03, Efficiency=046.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1096.51, Efficiency=035.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1415.34, Efficiency=045.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1407.97, Efficiency=045.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Dynamic, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:053.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3500, SCapacity=5250, Alloc=Dynamic]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 766.3s
# Experiments completed for onlineadaptive
# ✓ Scenario 'none' evaluation completed.
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2226.96
# 	• Winner Avg Gap: 0036.74%
# 	• Winner Avg Reward: 1421.26
# 	• Winner Avg Efficiency: 0063.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	036.7%
# 	Winner Avg Efficiency: 	063.3%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	063.3% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	061.9% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	061.3% Efficiency 	(Won 0/5 experiments)
# 	• CPursuitNeuralUCB: 	061.2% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2225.47
# 	• Winner Avg Gap: 0042.88%
# 	• Winner Avg Reward: 1277.07
# 	• Winner Avg Efficiency: 0057.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	042.9%
# 	Winner Avg Efficiency: 	057.1%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	057.1% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	056.9% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	052.4% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2080.48
# 	• Winner Avg Gap: 0065.81%
# 	• Winner Avg Reward: 0709.70
# 	• Winner Avg Efficiency: 0034.19%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	065.8%
# 	Winner Avg Efficiency: 	034.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	034.2% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	032.1% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	031.8% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	030.1% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2214.01
# 	• Winner Avg Gap: 0054.36%
# 	• Winner Avg Reward: 1010.17
# 	• Winner Avg Efficiency: 0045.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 4 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	054.4%
# 	Winner Avg Efficiency: 	045.6%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	045.6% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	045.5% Efficiency 	(Won 4/5 experiments)
# 	• GNeuralUCB     : 	045.2% Efficiency 	(Won 0/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.5% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 2213.63
# 	• Winner Avg Gap: 0055.01%
# 	• Winner Avg Reward: 1001.11
# 	• Winner Avg Efficiency: 0044.99%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 4 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	055.0%
# 	Winner Avg Efficiency: 	045.0%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	045.0% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	044.8% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	039.6% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (iCPursuitNeuralUCB):
# 	• Stochastic Performance:    	1277.067
# 	• Baseline Performance:      	1421.255
# 	• Performance Retention:     	089.9%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2226.96
# 	• Winner Avg Gap: 0036.74%
# 	• Winner Avg Reward: 1421.26
# 	• Winner Avg Efficiency: 0063.26%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	036.7%
# 	Winner Avg Efficiency: 	063.3%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	063.3% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	061.9% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	061.3% Efficiency 	(Won 0/5 experiments)
# 	• CPursuitNeuralUCB: 	061.2% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2225.47
# 	• Winner Avg Gap: 0042.88%
# 	• Winner Avg Reward: 1277.07
# 	• Winner Avg Efficiency: 0057.12%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	042.9%
# 	Winner Avg Efficiency: 	057.1%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	057.1% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	056.9% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	052.4% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2080.48
# 	• Winner Avg Gap: 0065.81%
# 	• Winner Avg Reward: 0709.70
# 	• Winner Avg Efficiency: 0034.19%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	065.8%
# 	Winner Avg Efficiency: 	034.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	034.2% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	032.1% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	031.8% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	030.1% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2214.01
# 	• Winner Avg Gap: 0054.36%
# 	• Winner Avg Reward: 1010.17
# 	• Winner Avg Efficiency: 0045.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 4 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	054.4%
# 	Winner Avg Efficiency: 	045.6%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	045.6% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	045.5% Efficiency 	(Won 4/5 experiments)
# 	• GNeuralUCB     : 	045.2% Efficiency 	(Won 0/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.5% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 2213.63
# 	• Winner Avg Gap: 0055.01%
# 	• Winner Avg Reward: 1001.11
# 	• Winner Avg Efficiency: 0044.99%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 4 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	055.0%
# 	Winner Avg Efficiency: 	045.0%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	045.0% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	044.8% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	039.6% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✅ Evaluation completed!
# [Logging Redirect Stopped]
#
# 🧹 Final cleanup for Dynamic
#
# ======================================================================
# ✅ COMPLETED: Dynamic
# ======================================================================
#
# Dynamic COMPLETED SUCCESSFULLY
#
# ======================================================================
# ALL ALLOCATORS COMPLETE!
# ======================================================================

# %%
# ============================================================
# Cell: Allocator + ExperimentConfiguration for Paper #12
# ============================================================
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.quantum_physics              import *
from daqr.evaluation.allocator_runner       import AllocatorRunner
from daqr.evaluation.multi_run_evaluator    import MultiRunEvaluator
from daqr.config.experiment_config          import ExperimentConfiguration

print("=" * 70)
print("PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS")
print("=" * 70)

# ------------------------------------------------------------
# 1) Allocator Selection
# ------------------------------------------------------------
ALLOCATORS = ["ThompsonSampling"]

# ------------------------------------------------------------
# 2) Run Parameters
# ------------------------------------------------------------
# CORRECTED Paper 12 Evaluation
attack_intensity    = FRAMEWORK_CONFIG['intensity']
current_frames      = 1500      # 3 reconfiguration cycles
frame_step          = 500       # Epoch-aligned checkpoints
current_experiments = 1
last_backup         = False
base_cap            = False
overwrite           = True

RUNS                = [5]               # Acceptable for initial testing
SCALES              = [1.5]             # Single scale
ATTACK_SCENARIOS    = ['stochastic']    # Start simple
print(f"✅ Testing QuARC with {current_frames} timeslots")
print(f"✅ Expected reconfigurations: {current_frames // 500}")
print(f"✅ Statistical runs: {RUNS[0]}")

FRAMEWORK_CONFIG['exp_num']     = current_experiments
FRAMEWORK_CONFIG['base_frames'] = current_frames
FRAMEWORK_CONFIG['frame_step']  = frame_step


# Testbed Configuration
PHYSICS_MODELS = ['paper12']  # Paper 12 (QuARC)
ATTACK_SCENARIOS = ['stochastic']  # Start simple

print("\n" + "=" * 70)
print("PAPER 12 ALLOCATOR EVALUATION")
print("=" * 70)
print(f"Allocators:                 {ALLOCATORS}")
print(f"Physics Models:             {PHYSICS_MODELS}")
print(f"Attack Scenarios:           {ATTACK_SCENARIOS}")
print(f"Scales:                     {SCALES}")
print(f"Runs per Scale:             {RUNS}")
print(f"Total Frames:               {current_frames}")
print("=" * 70)

for allocator_type in ALLOCATORS:
    print(f"\n{'='*70}")
    print(f"RUNNING: {allocator_type} on Paper 12 (QuARC)")
    print('='*70)

    try:
        # Create isolated runner instance
        custom_config = ExperimentConfiguration(
            env_type=FRAMEWORK_CONFIG['main_env'],
            scenarios=test_scenarios,
            use_last_backup=last_backup,
            models=models,
            attack_intensity=attack_intensity,
            scale=1,
            base_capacity=base_cap,
            overwrite=overwrite
        )

        alloc_runner = AllocatorRunner(
            allocator_type=allocator_type,
            physics_models=PHYSICS_MODELS,
            framework_config=FRAMEWORK_CONFIG,
            scales=SCALES,
            runs=RUNS,
            models=models,
            test_scenarios=test_scenarios,
            config=custom_config
        )

        # Run with Paper 12 physics
        alloc_runner.run(get_physics_params_func=get_physics_params)
        print(f"\n{allocator_type} COMPLETED SUCCESSFULLY")

    except Exception as e:
        print(f"\n{allocator_type} FAILED: {e}")
        import traceback
        traceback.print_exc()

print("\n" + "=" * 70)
print("ALL ALLOCATORS COMPLETE!")
print("=" * 70)
# Out:
# ======================================================================
# PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS
# ======================================================================
# ✅ Testing QuARC with 1500 timeslots
# ✅ Expected reconfigurations: 3
# ✅ Statistical runs: 5
#
# ======================================================================
# PAPER 12 ALLOCATOR EVALUATION
# ======================================================================
# Allocators:                 ['ThompsonSampling']
# Physics Models:             ['paper12']
# Attack Scenarios:           ['stochastic']
# Scales:                     [1.5]
# Runs per Scale:             [5]
# Total Frames:               1500
# ======================================================================
#
# ======================================================================
# RUNNING: ThompsonSampling on Paper 12 (QuARC)
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260128
#       Relative: framework_state/day_20260128
#       Component: framework_state
#       Date: day_20260128
#       📄 Processing 1 files in framework_state/day_20260128
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260128: 0/1 files processed
#       📊 framework_state/day_20260128: 0/1 files skipped
#       📊 framework_state/day_20260128: 1/1 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260129
#       Relative: framework_state/day_20260129
#       Component: framework_state
#       Date: day_20260129
#       📄 Processing 5 files in framework_state/day_20260129
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260129: 4/5 files processed
#       📊 framework_state/day_20260129: 0/5 files skipped
#       📊 framework_state/day_20260129: 1/5 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
#       Relative: framework_state/day_20260130
#       Component: framework_state
#       Date: day_20260130
#       📄 Processing 2021 files in framework_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260130: 2007/2021 files processed
#       📊 framework_state/day_20260130: 0/2021 files skipped
#       📊 framework_state/day_20260130: 14/2021 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260131
#       Relative: framework_state/day_20260131
#       Component: framework_state
#       Date: day_20260131
#       📄 Processing 27 files in framework_state/day_20260131
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260131: 27/27 files processed
#       📊 framework_state/day_20260131: 0/27 files skipped
#       📊 framework_state/day_20260131: 0/27 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
#       Relative: model_state/day_20260130
#       Component: model_state
#       Date: day_20260130
#       📄 Processing 6334 files in model_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260130: 6334/6334 files processed
#       📊 model_state/day_20260130: 0/6334 files skipped
#       📊 model_state/day_20260130: 0/6334 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260131
#       Relative: model_state/day_20260131
#       Component: model_state
#       Date: day_20260131
#       📄 Processing 52 files in model_state/day_20260131
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260131: 52/52 files processed
#       📊 model_state/day_20260131: 0/52 files skipped
#       📊 model_state/day_20260131: 0/52 files conflicted
#
#    📊 Processed 6 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 2034 files
#   • model_state: 6380 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 8414
# ================================================================================
#
# 	→ Filesystem scan found 8414 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# ======================================================================
# 🎯 AllocatorRunner initialized: ThompsonSampling
# ======================================================================
#
# ======================================================================
# 🚀 STARTING ALLOCATOR: ThompsonSampling
# ======================================================================
#
# 📊 Physics Model: paper12
#
# 📋 Allocator Config:
#    Type: ThompsonSampling
#    Testbed: paper12
#    Paths: 4
#    Total Qubits: 100
#    Min per route: 3
#    Seed: 42
#    Priors: α=1.0, β=1.0
# ✅ Allocator created: (25, 25, 25, 25)
# ✓ Allocator: ThompsonSamplingAllocator (4 paths)
#    Initial allocation: (25, 25, 25, 25)
# Generated paper12 Waxman topology: 100 nodes, 398 edges, avg degree: 7.96
# 📊 Paper12 Physics: Fusion (prob=0.9)
#
# ======================================================================
# RUN 1 | Scale: 1.5 | Exp: 5
# ======================================================================
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 1500 -> 3500 (step: 500)
# quantum_exps-ThompsonSampling(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-ThompsonSampling(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1.5T_20260131_log.txt
# ⚙ Running evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Experiments per Scenario:   	5
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 1: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0550.13, Efficiency=041.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0581.08, Efficiency=043.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0584.86, Efficiency=044.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0610.15, Efficiency=046.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 18435
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:053.9%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:1500, SCapacity=2250, Alloc=ThompsonSampling]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 2: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0826.07, Efficiency=046.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0799.24, Efficiency=045.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0844.67, Efficiency=047.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0817.00, Efficiency=046.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20125
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:052.1%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2000, SCapacity=3000, Alloc=ThompsonSampling]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 3: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1041.69, Efficiency=047.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0985.19, Efficiency=044.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1053.08, Efficiency=047.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1050.12, Efficiency=047.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 21826
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:052.2%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2500, SCapacity=3750, Alloc=ThompsonSampling]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 4: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1302.11, Efficiency=049.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1280.96, Efficiency=048.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1201.08, Efficiency=045.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1269.50, Efficiency=048.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 17516
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:050.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3000, SCapacity=4500, Alloc=ThompsonSampling]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for NONE Exp 5: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1447.61, Efficiency=046.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1579.58, Efficiency=051.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1436.19, Efficiency=046.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1502.18, Efficiency=048.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 15568
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:048.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3500, SCapacity=5250, Alloc=ThompsonSampling]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 673.0s
# Experiments completed for none
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 1: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0560.48, Efficiency=042.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0599.26, Efficiency=045.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0585.07, Efficiency=044.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0554.81, Efficiency=042.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 17102
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:054.7%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:1500, SCapacity=2250, Alloc=ThompsonSampling]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 2: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0786.53, Efficiency=044.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0788.15, Efficiency=044.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0794.28, Efficiency=045.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0773.90, Efficiency=043.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 12774
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:055.0%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2000, SCapacity=3000, Alloc=ThompsonSampling]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 3: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0949.77, Efficiency=043.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0922.98, Efficiency=041.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1007.41, Efficiency=045.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0989.76, Efficiency=044.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 12940
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:054.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2500, SCapacity=3750, Alloc=ThompsonSampling]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 4: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1167.48, Efficiency=044.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1256.41, Efficiency=047.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1171.45, Efficiency=044.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1186.26, Efficiency=044.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 12978
# 	-->🏆 EXP4 Winner:EXPNeuralUCB        (Gap:052.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3000, SCapacity=4500, Alloc=ThompsonSampling]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for STOCHASTIC Exp 5: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1365.00, Efficiency=044.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1277.64, Efficiency=041.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1355.69, Efficiency=043.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1385.09, Efficiency=044.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 21261
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:055.1%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3500, SCapacity=5250, Alloc=ThompsonSampling]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 728.5s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 2250.0 frames (CAPACITY:1500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=0 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 1: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0309.94, Efficiency=025.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0235.07, Efficiency=019.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0309.62, Efficiency=025.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0313.66, Efficiency=025.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=2250, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=ThompsonSampling, SC:2250 (Scale=1.5 x Cap=1500), Seed: 12678
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:074.5%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:1500, SCapacity=2250, Alloc=ThompsonSampling]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 3000.0 frames (CAPACITY:2000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=1 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 2: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0444.62, Efficiency=026.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0436.23, Efficiency=026.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0452.07, Efficiency=027.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0469.33, Efficiency=028.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=ThompsonSampling, SC:3000 (Scale=1.5 x Cap=2000), Seed: 20894
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:071.7%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2000, SCapacity=3000, Alloc=ThompsonSampling]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 3750.0 frames (CAPACITY:2500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=2 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 3: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0527.71, Efficiency=025.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0532.03, Efficiency=025.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=0513.84, Efficiency=025.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0553.94, Efficiency=026.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3750, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=ThompsonSampling, SC:3750 (Scale=1.5 x Cap=2500), Seed: 18852
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:073.1%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2500, SCapacity=3750, Alloc=ThompsonSampling]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 4500.0 frames (CAPACITY:3000 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=3 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 4: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=0610.93, Efficiency=024.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=0567.52, Efficiency=022.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=0626.48, Efficiency=025.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=0672.08, Efficiency=027.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=ThompsonSampling, SC:4500 (Scale=1.5 x Cap=3000), Seed: 20491
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:072.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=ThompsonSampling]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for MARKOV Exp 5: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20713
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=0712.68, Efficiency=024.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# ...
# 	-->🏆 EXP4 Winner:CPursuitNeuralUCB   (Gap:063.8%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3000, SCapacity=4500, Alloc=ThompsonSampling]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 5250.0 frames (CAPACITY:3500 X SCALE:1.5)
# ----------------------------------------------------------------------------------------------------
# [ThompsonAllocator] timestep=4 (uniform init) → allocation=(25, 25, 25, 25)
# 🔧 Allocated qubits for ONLINEADAPTIVE Exp 5: (25, 25, 25, 25)
# 🔄 ThompsonSampling Dynamic Allocation (Initial): (25, 25, 25, 25)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1127.98, Efficiency=036.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1085.76, Efficiency=035.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1052.12, Efficiency=034.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1089.59, Efficiency=035.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=5250, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=ThompsonSampling, SC:5250 (Scale=1.5 x Cap=3500), Seed: 20079
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:063.3%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3500, SCapacity=5250, Alloc=ThompsonSampling]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 694.1s
# Experiments completed for onlineadaptive
# ✓ Scenario 'none' evaluation completed.
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.16
# 	• Winner Avg Gap: 0052.64%
# 	• Winner Avg Reward: 1049.79
# 	• Winner Avg Efficiency: 0047.36%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	052.6%
# 	Winner Avg Efficiency: 	047.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	047.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	046.7% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	046.4% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	046.4% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.07
# 	• Winner Avg Gap: 0055.36%
# 	• Winner Avg Reward: 0982.78
# 	• Winner Avg Efficiency: 0044.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	055.4%
# 	Winner Avg Efficiency: 	044.6%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	044.6% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	044.2% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	043.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2065.04
# 	• Winner Avg Gap: 0072.75%
# 	• Winner Avg Reward: 0566.68
# 	• Winner Avg Efficiency: 0027.25%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	072.7%
# 	Winner Avg Efficiency: 	027.3%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	027.3% Efficiency 	(Won 5/5 experiments)
# 	• CPursuitNeuralUCB: 	025.5% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	025.4% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	023.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2195.49
# 	• Winner Avg Gap: 0064.75%
# 	• Winner Avg Reward: 0781.29
# 	• Winner Avg Efficiency: 0035.25%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	064.8%
# 	Winner Avg Efficiency: 	035.2%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	035.2% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.9% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	034.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	034.2% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 2195.28
# 	• Winner Avg Gap: 0064.73%
# 	• Winner Avg Reward: 0779.65
# 	• Winner Avg Efficiency: 0035.27%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	064.7%
# 	Winner Avg Efficiency: 	035.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	035.3% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	035.0% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.2% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (CPursuitNeuralUCB):
# 	• Stochastic Performance:    	982.779
# 	• Baseline Performance:      	1049.788
# 	• Performance Retention:     	093.6%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.16
# 	• Winner Avg Gap: 0052.64%
# 	• Winner Avg Reward: 1049.79
# 	• Winner Avg Efficiency: 0047.36%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	052.6%
# 	Winner Avg Efficiency: 	047.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	047.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	046.7% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	046.4% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	046.4% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.07
# 	• Winner Avg Gap: 0055.36%
# 	• Winner Avg Reward: 0982.78
# 	• Winner Avg Efficiency: 0044.64%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	055.4%
# 	Winner Avg Efficiency: 	044.6%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	044.6% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	044.2% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	044.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	043.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2065.04
# 	• Winner Avg Gap: 0072.75%
# 	• Winner Avg Reward: 0566.68
# 	• Winner Avg Efficiency: 0027.25%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	072.7%
# 	Winner Avg Efficiency: 	027.3%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	027.3% Efficiency 	(Won 5/5 experiments)
# 	• CPursuitNeuralUCB: 	025.5% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	025.4% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	023.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2195.49
# 	• Winner Avg Gap: 0064.75%
# 	• Winner Avg Reward: 0781.29
# 	• Winner Avg Efficiency: 0035.25%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	064.8%
# 	Winner Avg Efficiency: 	035.2%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	035.2% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.9% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	034.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	034.2% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 2195.28
# 	• Winner Avg Gap: 0064.73%
# 	• Winner Avg Reward: 0779.65
# 	• Winner Avg Efficiency: 0035.27%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	064.7%
# 	Winner Avg Efficiency: 	035.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	035.3% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	035.0% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.2% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# ✅ Evaluation completed!
# [Logging Redirect Stopped]
#
# 🧹 Final cleanup for ThompsonSampling
#
# ======================================================================
# ✅ COMPLETED: ThompsonSampling
# ======================================================================
#
# ThompsonSampling COMPLETED SUCCESSFULLY
#
# ======================================================================
# ALL ALLOCATORS COMPLETE!
# ======================================================================

# %%
# ============================================================
# Cell: Allocator + ExperimentConfiguration for Paper #12
# ============================================================
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.quantum_physics              import *
from daqr.evaluation.allocator_runner       import AllocatorRunner
from daqr.evaluation.multi_run_evaluator    import MultiRunEvaluator
from daqr.config.experiment_config          import ExperimentConfiguration

print("=" * 70)
print("PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS")
print("=" * 70)

# ------------------------------------------------------------
# 1) Allocator Selection
# ------------------------------------------------------------
ALLOCATORS = ["Random"]

# ------------------------------------------------------------
# 2) Run Parameters
# ------------------------------------------------------------
# CORRECTED Paper 12 Evaluation
attack_intensity    = FRAMEWORK_CONFIG['intensity']
current_frames      = 1500      # 3 reconfiguration cycles
frame_step          = 500       # Epoch-aligned checkpoints
current_experiments = 1
last_backup         = False
base_cap            = False
overwrite           = True

RUNS                = [5]               # Acceptable for initial testing
SCALES              = [1.5]             # Single scale
ATTACK_SCENARIOS    = ['stochastic']    # Start simple
print(f"✅ Testing QuARC with {current_frames} timeslots")
print(f"✅ Expected reconfigurations: {current_frames // 500}")
print(f"✅ Statistical runs: {RUNS[0]}")

FRAMEWORK_CONFIG['exp_num']     = current_experiments
FRAMEWORK_CONFIG['base_frames'] = current_frames
FRAMEWORK_CONFIG['frame_step']  = frame_step

# Testbed Configuration
PHYSICS_MODELS = ['paper12']  # Paper 12 (QuARC)
ATTACK_SCENARIOS = ['stochastic']  # Start simple

print("\n" + "=" * 70)
print("PAPER 12 ALLOCATOR EVALUATION")
print("=" * 70)
print(f"Allocators:                 {ALLOCATORS}")
print(f"Physics Models:             {PHYSICS_MODELS}")
print(f"Attack Scenarios:           {ATTACK_SCENARIOS}")
print(f"Scales:                     {SCALES}")
print(f"Runs per Scale:             {RUNS}")
print(f"Total Frames:               {current_frames}")
print("=" * 70)

for allocator_type in ALLOCATORS:
    print(f"\n{'='*70}")
    print(f"RUNNING: {allocator_type} on Paper 12 (QuARC)")
    print('='*70)

    try:
        # Create isolated runner instance
        custom_config = ExperimentConfiguration(
            env_type=FRAMEWORK_CONFIG['main_env'],
            scenarios=test_scenarios,
            use_last_backup=last_backup,
            models=models,
            attack_intensity=attack_intensity,
            scale=1,
            base_capacity=base_cap,
            overwrite=overwrite
        )

        alloc_runner = AllocatorRunner(
            allocator_type=allocator_type,
            physics_models=PHYSICS_MODELS,
            framework_config=FRAMEWORK_CONFIG,
            scales=SCALES,
            runs=RUNS,
            models=models,
            test_scenarios=test_scenarios,
            config=custom_config
        )

        # Run with Paper 12 physics
        alloc_runner.run(get_physics_params_func=get_physics_params)
        print(f"\n{allocator_type} COMPLETED SUCCESSFULLY")

    except Exception as e:
        print(f"\n{allocator_type} FAILED: {e}")
        import traceback
        traceback.print_exc()

print("\n" + "=" * 70)
print("ALL ALLOCATORS COMPLETE!")
print("=" * 70)
# Out:
# ======================================================================
# PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS
# ======================================================================
# ✅ Testing QuARC with 1500 timeslots
# ✅ Expected reconfigurations: 3
# ✅ Statistical runs: 5
#
# ======================================================================
# PAPER 12 ALLOCATOR EVALUATION
# ======================================================================
# Allocators:                 ['Random']
# Physics Models:             ['paper12']
# Attack Scenarios:           ['stochastic']
# Scales:                     [1]
# Runs per Scale:             [5]
# Total Frames:               1500
# ======================================================================
#
# ======================================================================
# RUNNING: Random on Paper 12 (QuARC)
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260130
#       Relative: framework_state/day_20260130
#       Component: framework_state
#       Date: day_20260130
#       📄 Processing 1953 files in framework_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260130: 1953/1953 files processed
#       📊 framework_state/day_20260130: 0/1953 files skipped
#       📊 framework_state/day_20260130: 0/1953 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260130
#       Relative: model_state/day_20260130
#       Component: model_state
#       Date: day_20260130
#       📄 Processing 6242 files in model_state/day_20260130
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260130: 6242/6242 files processed
#       📊 model_state/day_20260130: 0/6242 files skipped
#       📊 model_state/day_20260130: 0/6242 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1953 files
#   • model_state: 6242 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 8195
# ================================================================================
#
# 	→ Filesystem scan found 8195 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# ======================================================================
# 🎯 AllocatorRunner initialized: Random
# ======================================================================
#
# ======================================================================
# 🚀 STARTING ALLOCATOR: Random
# ======================================================================
#
# 📊 Physics Model: paper12
#
# 📋 Allocator Config:
#    Type: Random
#    Testbed: paper12
#    Paths: 4
#    Total Qubits: 100
#    Min per route: 3
#    Seed: 42
#    Epsilon: 1.0, Decay: 1.0
# ✅ Allocator created: (52, 25, 17, 6)
# ✓ Allocator: RandomQubitAllocator (4 paths)
#    Initial allocation: (25, 11, 58, 6)
# Generated paper12 Waxman topology: 100 nodes, 394 edges, avg degree: 7.88
# 📊 Paper12 Physics: Fusion (prob=0.9)
#
# ======================================================================
# RUN 1 | Scale: 1 | Exp: 5
# ======================================================================
# 🔄 Random Dynamic Allocation (Initial): (12, 22, 28, 38)
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 1500 -> 3500 (step: 500)
# quantum_exps-Random(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1T
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Random(paper12)_alloc-all_envs-5_attacks-1500_500-5_runs-S1T_20260130_log.txt
# ⚙ Running evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Experiments per Scenario:   	5
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 1500 frames (CAPACITY:1500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(12, 22, 28, 38)
# 🔧 Allocated qubits for NONE Exp 1: (12, 22, 28, 38)
# 🔄 Random Dynamic Allocation (Initial): (58, 30, 8, 4)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 18435
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0587.37, Efficiency=044.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0619.81, Efficiency=046.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0583.66, Efficiency=044.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0601.00, Efficiency=045.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 1: Env:Baseline (None), Attack:No, Rate:0.0, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 18435
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:053.1%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:1500, SCapacity=1500, Alloc=Random]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 2000 frames (CAPACITY:2000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(58, 30, 8, 4)
# 🔧 Allocated qubits for NONE Exp 2: (58, 30, 8, 4)
# 🔄 Random Dynamic Allocation (Initial): (15, 6, 55, 24)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 20125
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0807.41, Efficiency=045.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0821.51, Efficiency=046.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0840.05, Efficiency=047.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0840.34, Efficiency=047.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 2: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 20125
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:052.3%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2000, SCapacity=2000, Alloc=Random]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 2500 frames (CAPACITY:2500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(15, 6, 55, 24)
# 🔧 Allocated qubits for NONE Exp 3: (15, 6, 55, 24)
# 🔄 Random Dynamic Allocation (Initial): (14, 17, 53, 16)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 21826
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=1061.26, Efficiency=048.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=1051.14, Efficiency=047.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1031.22, Efficiency=046.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=1061.45, Efficiency=048.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 21826
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:051.8%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:2500, SCapacity=2500, Alloc=Random]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 3000 frames (CAPACITY:3000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=3 mode=random → allocation=(14, 17, 53, 16)
# 🔧 Allocated qubits for NONE Exp 4: (14, 17, 53, 16)
# 🔄 Random Dynamic Allocation (Initial): (20, 24, 16, 40)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 17516
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1288.35, Efficiency=048.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1273.26, Efficiency=048.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1219.73, Efficiency=046.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1225.04, Efficiency=046.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 4: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 17516
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:051.3%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3000, SCapacity=3000, Alloc=Random]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 3500 frames (CAPACITY:3500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=4 mode=random → allocation=(20, 24, 16, 40)
# 🔧 Allocated qubits for NONE Exp 5: (20, 24, 16, 40)
# 🔄 Random Dynamic Allocation (Initial): (8, 17, 11, 64)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 15568
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1424.43, Efficiency=046.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.582]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1575.43, Efficiency=051.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.628]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1431.88, Efficiency=046.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.634]
#
# 	🔄 BASELINE (NONE) (NO) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1499.49, Efficiency=048.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.712]
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 15568
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:048.9%) [Env:Baseline (None), Attack:No X Rate:0.0, Frames:3500, SCapacity=3500, Alloc=Random]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 615.1s
# Experiments completed for none
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 1500 frames (CAPACITY:1500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(8, 17, 11, 64)
# 🔧 Allocated qubits for STOCHASTIC Exp 1: (8, 17, 11, 64)
# 🔄 Random Dynamic Allocation (Initial): (23, 11, 16, 50)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 17102
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0572.38, Efficiency=043.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0598.96, Efficiency=045.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0588.93, Efficiency=044.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0568.36, Efficiency=043.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 17102
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:054.7%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:1500, SCapacity=1500, Alloc=Random]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 2000 frames (CAPACITY:2000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(23, 11, 16, 50)
# 🔧 Allocated qubits for STOCHASTIC Exp 2: (23, 11, 16, 50)
# 🔄 Random Dynamic Allocation (Initial): (22, 39, 33, 6)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 12774
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0771.03, Efficiency=043.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0730.85, Efficiency=041.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0747.79, Efficiency=042.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0766.68, Efficiency=043.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 12774
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:056.3%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2000, SCapacity=2000, Alloc=Random]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 2500 frames (CAPACITY:2500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(22, 39, 33, 6)
# 🔧 Allocated qubits for STOCHASTIC Exp 3: (22, 39, 33, 6)
# 🔄 Random Dynamic Allocation (Initial): (56, 4, 23, 17)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 12940
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0945.01, Efficiency=042.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0908.52, Efficiency=041.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=0987.56, Efficiency=044.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0975.97, Efficiency=044.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 12940
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:055.2%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:2500, SCapacity=2500, Alloc=Random]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 3000 frames (CAPACITY:3000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=3 mode=random → allocation=(56, 4, 23, 17)
# 🔧 Allocated qubits for STOCHASTIC Exp 4: (56, 4, 23, 17)
# 🔄 Random Dynamic Allocation (Initial): (65, 9, 17, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 12978
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=1176.36, Efficiency=044.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=1188.36, Efficiency=044.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=1166.71, Efficiency=044.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=1184.02, Efficiency=044.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 12978
# 	-->🏆 EXP4 Winner:EXPNeuralUCB        (Gap:055.1%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3000, SCapacity=3000, Alloc=Random]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 3500 frames (CAPACITY:3500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=4 mode=random → allocation=(65, 9, 17, 9)
# 🔧 Allocated qubits for STOCHASTIC Exp 5: (65, 9, 17, 9)
# 🔄 Random Dynamic Allocation (Initial): (25, 33, 36, 6)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 21261
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1340.94, Efficiency=043.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1456.62, Efficiency=047.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1416.82, Efficiency=045.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1357.98, Efficiency=044.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 21261
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:052.8%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:3500, SCapacity=3500, Alloc=Random]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 616.8s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 1500 frames (CAPACITY:1500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(25, 33, 36, 6)
# 🔧 Allocated qubits for MARKOV Exp 1: (25, 33, 36, 6)
# 🔄 Random Dynamic Allocation (Initial): (11, 5, 37, 47)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 12678
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0301.28, Efficiency=024.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0278.72, Efficiency=022.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0316.25, Efficiency=025.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0328.33, Efficiency=026.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 12678
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:073.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:1500, SCapacity=1500, Alloc=Random]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 2000 frames  <>  SCALED-CAPACITY: 2000 frames (CAPACITY:2000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=1 mode=random → allocation=(11, 5, 37, 47)
# 🔧 Allocated qubits for MARKOV Exp 2: (11, 5, 37, 47)
# 🔄 Random Dynamic Allocation (Initial): (11, 5, 46, 38)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 20894
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=0444.41, Efficiency=026.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=0426.95, Efficiency=025.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=0451.71, Efficiency=027.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=0465.08, Efficiency=028.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=2000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2000, QubitAlloc=Random, SC:2000 (Scale=1 x Cap=2000), Seed: 20894
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:072.0%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2000, SCapacity=2000, Alloc=Random]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 2500 frames  <>  SCALED-CAPACITY: 2500 frames (CAPACITY:2500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(11, 5, 46, 38)
# 🔧 Allocated qubits for MARKOV Exp 3: (11, 5, 46, 38)
# 🔄 Random Dynamic Allocation (Initial): (9, 10, 33, 48)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 18852
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=0543.31, Efficiency=026.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=0454.69, Efficiency=022.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=0523.89, Efficiency=025.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=0558.57, Efficiency=027.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=2500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:2500, QubitAlloc=Random, SC:2500 (Scale=1 x Cap=2500), Seed: 18852
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:072.9%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:2500, SCapacity=2500, Alloc=Random]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 3000 frames  <>  SCALED-CAPACITY: 3000 frames (CAPACITY:3000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=3 mode=random → allocation=(9, 10, 33, 48)
# 🔧 Allocated qubits for MARKOV Exp 4: (9, 10, 33, 48)
# 🔄 Random Dynamic Allocation (Initial): (50, 3, 10, 37)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 20491
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=0669.94, Efficiency=027.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=0583.35, Efficiency=023.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=0655.05, Efficiency=026.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=0712.51, Efficiency=028.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 4: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3000, QubitAlloc=Random, SC:3000 (Scale=1 x Cap=3000), Seed: 20491
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:071.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3000, SCapacity=3000, Alloc=Random]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 3500 frames (CAPACITY:3500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=4 mode=random → allocation=(50, 3, 10, 37)
# 🔧 Allocated qubits for MARKOV Exp 5: (50, 3, 10, 37)
# 🔄 Random Dynamic Allocation (Initial): (47, 8, 27, 18)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 20713
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=0767.80, Efficiency=026.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=0704.20, Efficiency=024.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=0734.11, Efficiency=025.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=0777.45, Efficiency=026.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 5: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 20713
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:073.2%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:3500, SCapacity=3500, Alloc=Random]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 499.5s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 1500 frames  <>  SCALED-CAPACITY: 1500 frames (CAPACITY:1500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=0 mode=random → allocation=(47, 8, 27, 18)
# 🔧 Allocated qubits for ADAPTIVE Exp 1: (47, 8, 27, 18)
# 🔄 Random Dynamic Allocation (Initial): (10, 22, 26, 42)
# ======================================================================================================================================================
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 19674
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=0464.64, Efficiency=035.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=0461.53, Efficiency=035.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=0472.63, Efficiency=035.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ADAPTIVE) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=0456.73, Efficiency=034.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=1500, Threshold=0.712]
#
# ADVERSARIAL (ADAPTIVE) EXP 1: Env:Adversarial, Attack:Adaptive, Rate:0.25, Frames:1500, QubitAlloc=Random, SC:1500 (Scale=1 x Cap=1500), Seed: 19674
# 	-->🏆 EXP1 Winner:CPursuitNeuralUCB   (Gap:064.1%) [Env:Adversarial, Attack:Adaptive X Rate:0.25, Frames:1500, SCapacity=1500, Alloc=Random]
# ...
# 	-->🏆 EXP4 Winner:CPursuitNeuralUCB   (Gap:063.0%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3000, SCapacity=3000, Alloc=Random]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 3500 frames  <>  SCALED-CAPACITY: 3500 frames (CAPACITY:3500 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [RandomAllocator ε=1.000] timestep=4 mode=random → allocation=(33, 38, 12, 17)
# 🔧 Allocated qubits for ONLINEADAPTIVE Exp 5: (33, 38, 12, 17)
# 🔄 Random Dynamic Allocation (Initial): (15, 8, 73, 4)
# ======================================================================================================================================================
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 20079
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 4
# 	   First reward: [0.1944, 0.5334336, 0.7380232703999999, 0.8326343725056001, 0.8726341491523584], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=1098.39, Efficiency=035.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=1129.70, Efficiency=036.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=1094.56, Efficiency=035.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=1096.44, Efficiency=035.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=3500, Threshold=0.712]
#
# ADVERSARIAL (ONLINEADAPTIVE) EXP 5: Env:Adversarial, Attack:OnlineAdaptive, Rate:0.25, Frames:3500, QubitAlloc=Random, SC:3500 (Scale=1 x Cap=3500), Seed: 20079
# 	-->🏆 EXP5 Winner:EXPNeuralUCB        (Gap:063.2%) [Env:Adversarial, Attack:OnlineAdaptive X Rate:0.25, Frames:3500, SCapacity=3500, Alloc=Random]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 534.3s
# Experiments completed for onlineadaptive
# ✓ Scenario 'none' evaluation completed.
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2204.16
# 	• Winner Avg Gap: 0051.93%
# 	• Winner Avg Reward: 1068.23
# 	• Winner Avg Efficiency: 0048.07%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	051.9%
# 	Winner Avg Efficiency: 	048.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	048.1% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.2% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	046.6% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	046.2% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.06
# 	• Winner Avg Gap: 0055.64%
# 	• Winner Avg Reward: 0981.56
# 	• Winner Avg Efficiency: 0044.36%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	055.6%
# 	Winner Avg Efficiency: 	044.4%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	044.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	044.0% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	043.9% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	043.6% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2066.34
# 	• Winner Avg Gap: 0072.53%
# 	• Winner Avg Reward: 0568.39
# 	• Winner Avg Efficiency: 0027.47%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	072.5%
# 	Winner Avg Efficiency: 	027.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	027.5% Efficiency 	(Won 5/5 experiments)
# 	• GNeuralUCB     : 	026.2% Efficiency 	(Won 0/5 experiments)
# 	• CPursuitNeuralUCB: 	026.0% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	023.6% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2195.75
# 	• Winner Avg Gap: 0064.27%
# 	• Winner Avg Reward: 0786.32
# 	• Winner Avg Efficiency: 0035.73%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	064.3%
# 	Winner Avg Efficiency: 	035.7%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	035.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	035.1% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.8% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	034.7% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2195.50
# 	• Winner Avg Gap: 0064.28%
# 	• Winner Avg Reward: 0785.84
# 	• Winner Avg Efficiency: 0035.72%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	064.3%
# 	Winner Avg Efficiency: 	035.7%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	035.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	035.4% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	035.4% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (CPursuitNeuralUCB):
# 	• Stochastic Performance:    	981.559
# 	• Baseline Performance:      	1068.229
# 	• Performance Retention:     	091.9%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2204.16
# 	• Winner Avg Gap: 0051.93%
# 	• Winner Avg Reward: 1068.23
# 	• Winner Avg Efficiency: 0048.07%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	051.9%
# 	Winner Avg Efficiency: 	048.1%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	048.1% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	047.2% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	046.6% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	046.2% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2204.06
# 	• Winner Avg Gap: 0055.64%
# 	• Winner Avg Reward: 0981.56
# 	• Winner Avg Efficiency: 0044.36%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	055.6%
# 	Winner Avg Efficiency: 	044.4%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	044.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	044.0% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	043.9% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	043.6% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 2066.34
# 	• Winner Avg Gap: 0072.53%
# 	• Winner Avg Reward: 0568.39
# 	• Winner Avg Efficiency: 0027.47%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	072.5%
# 	Winner Avg Efficiency: 	027.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	027.5% Efficiency 	(Won 5/5 experiments)
# 	• GNeuralUCB     : 	026.2% Efficiency 	(Won 0/5 experiments)
# 	• CPursuitNeuralUCB: 	026.0% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	023.6% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: EXPNeuralUCB
# 	• Oracle Avg Reward: 2195.75
# 	• Winner Avg Gap: 0064.27%
# 	• Winner Avg Reward: 0786.32
# 	• Winner Avg Efficiency: 0035.73%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	EXPNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	064.3%
# 	Winner Avg Efficiency: 	035.7%
#
# Overall Models Performance:
# 	• EXPNeuralUCB   : 	035.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	035.1% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.8% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	034.7% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 2195.50
# 	• Winner Avg Gap: 0064.28%
# 	• Winner Avg Reward: 0785.84
# 	• Winner Avg Efficiency: 0035.72%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	064.3%
# 	Winner Avg Efficiency: 	035.7%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	035.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	035.4% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	035.4% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	034.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✅ Evaluation completed!
# [Logging Redirect Stopped]
#
# 🧹 Final cleanup for Random
#
# ======================================================================
# ✅ COMPLETED: Random
# ======================================================================
#
# Random COMPLETED SUCCESSFULLY
#
# ======================================================================
# ALL ALLOCATORS COMPLETE!
# ======================================================================
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Paper 12 (QuARC) - Clustered Quantum Routing
#
# ## Quantum Adaptive Routing Using Clusters (QuARC)
#
# **Reference**: Clayton et al., 2024 - "Efficient Routing on Quantum Networks using Adaptive Clustering" (ICNP 2024)
#
# **Repository**: https://github.com/cbclayton/clustered-quantum-routing
#
# ### Key Features
#
# - **Adaptive Clustering**: Dynamic network partitioning into clusters (blobs) based on entanglement generation success
# - **Merge/Split Protocol**: Clusters merge when success rate drops below threshold, split when exceeds threshold
# - **Fusion Management**: Handles n-way quantum state fusion within clusters with noise modeling
# - **Waxman Topology**: Realistic topological model with spatial characteristics
# - **Adaptive Thresholding**: Merge/split thresholds scale dynamically with cluster size
#
# ### Implementation Strategy
#
# Our framework integrates Paper12's QuARC concepts into the neural bandit testbed:
#
# 1. **Cluster Representation**: Map QuARC "blobs" to multi-armed bandit paths
# 2. **Fusion as Actions**: Different cluster sizes = different action arms per path
# 3. **Context Features**: [cluster_size, fusion_prob, avg_entanglement_rate]
# 4. **Reward Function**: Entanglement success rate normalized to [0, 1]
# 5. **Adaptive Allocation**: Neural bandits learn optimal cluster size selection per network state
#
# ### Testbed Parameters
#
# - **Topology**: Waxman random geometric (100-800 nodes)
# - **Edge Success Probability (E_p)**: 0.6 (60% quantum state fidelity)
# - **Fusion Success Probability (q)**: 0.9 (90% fusion gate fidelity)
# - **Average Degree (E_d)**: 6 neighbors per node
# - **Channel Width**: 3 quantum channels per edge
# - **Number of SD Pairs**: 10 source-destination pairs per evaluation
# - **Qubits per Node**: Variable based on cluster configuration
# - **Request Generation**: Random or bimodal distance distribution

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.

# %%
# # ============================================================
# # Cell: Allocator + ExperimentConfiguration for Paper #12
# # ============================================================
# importlib.reload(qubit_allocator)
# importlib.reload(experiment_config)
# importlib.reload(multi_run_evaluator)

# from daqr.core.quantum_physics              import *
# from daqr.evaluation.allocator_runner       import AllocatorRunner
# from daqr.evaluation.multi_run_evaluator    import MultiRunEvaluator
# from daqr.config.experiment_config          import ExperimentConfiguration

# print("=" * 70)
# print("PAPER #12 (QuARC) QUANTUM ROUTING EVALUATION - ALL ALLOCATORS")
# print("=" * 70)

# # ------------------------------------------------------------
# # 1) Allocator Selection
# # ------------------------------------------------------------
# ALLOCATORS = ["Dynamic", "ThompsonSampling", "Random"]

# # ------------------------------------------------------------
# # 2) Run Parameters
# # ------------------------------------------------------------
# attack_intensity    = FRAMEWORK_CONFIG['intensity']
# current_frames      = 50
# frame_step          = 50
# current_experiments = 1
# last_backup         = False
# base_cap            = False
# overwrite           = True

# FRAMEWORK_CONFIG['exp_num']     = current_experiments
# FRAMEWORK_CONFIG['base_frames'] = current_frames
# FRAMEWORK_CONFIG['frame_step']  = frame_step

# # Testbed Configuration
# PHYSICS_MODELS = ['paper12']  # Paper 12 (QuARC)
# ATTACK_SCENARIOS = ['stochastic']  # Start simple
# SCALES = [1]
# RUNS = [5]

# print("\n" + "=" * 70)
# print("PAPER 12 ALLOCATOR EVALUATION")
# print("=" * 70)
# print(f"Allocators:                 {ALLOCATORS}")
# print(f"Physics Models:             {PHYSICS_MODELS}")
# print(f"Attack Scenarios:           {ATTACK_SCENARIOS}")
# print(f"Scales:                     {SCALES}")
# print(f"Runs per Scale:             {RUNS}")
# print(f"Total Frames:               {current_frames}")
# print("=" * 70)

# for allocator_type in ALLOCATORS:
#     print(f"\n{'='*70}")
#     print(f"RUNNING: {allocator_type} on Paper 12 (QuARC)")
#     print('='*70)

#     try:
#         # Create isolated runner instance
#         custom_config = ExperimentConfiguration(
#             env_type=FRAMEWORK_CONFIG['main_env'],
#             scenarios=test_scenarios,
#             use_last_backup=last_backup,
#             models=models,
#             attack_intensity=attack_intensity,
#             scale=1,
#             base_capacity=base_cap,
#             overwrite=overwrite
#         )

#         alloc_runner = AllocatorRunner(
#             allocator_type=allocator_type,
#             physics_models=PHYSICS_MODELS,
#             framework_config=FRAMEWORK_CONFIG,
#             scales=SCALES,
#             runs=RUNS,
#             models=models,
#             test_scenarios=test_scenarios,
#             config=custom_config
#         )

#         # Run with Paper 12 physics
#         alloc_runner.run(get_physics_params_func=get_physics_params)
#         print(f"\n{allocator_type} COMPLETED SUCCESSFULLY")

#     except Exception as e:
#         print(f"\n{allocator_type} FAILED: {e}")
#         import traceback
#         traceback.print_exc()

# print("\n" + "=" * 70)
# print("ALL ALLOCATORS COMPLETE!")
# print("=" * 70)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
