# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 10,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# BUILDING REGISTRY WITH 0 EXPECTED KEYS
# 	→ Filesystem scan found 0 files
# 	→ Drive registry updated
# ===================== REGISTRY BUILD COMPLETE =====================
#
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 10
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================
#   QUANTUM MAB – CLEAN RESET + FRESH IMPORT PIPELINE
# ============================================================
# This block:
#   ✓ Frees all global model objects
#   ✓ Clears CUDA + Python memory
#   ✓ Reloads all DAQR modules cleanly
#   ✓ Ensures any user can re-run cells safely in Colab
#
# This is the correct shared-drive-safe way to avoid
# stale state, GPU memory leaks, and broken reload logic.
# ============================================================

# ============================================================
# STEP 1 — FULL CLEANUP
# ============================================================
import gc
import torch

def deep_cleanup():
    """
    Remove all instantiated model/evaluator objects from global scope
    and fully clear CPU/GPU memory.
    """
    to_clear = [
        "oracle", "gneuralucb", "expneuralucb",
        "cpursuitneuralucb", "icpursuitneuralucb",
        "evaluator", "results"
    ]

    for name in to_clear:
        if name in globals():
            obj = globals().get(name, None)
            # If a cleanup() method exists, call it
            try:
                if hasattr(obj, "cleanup"):
                    obj.cleanup(verbose=False)
            except:
                pass
            # Remove the variable
            globals().pop(name, None)

    # GPU cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Force Python garbage collector
    gc.collect()

    # Reset default dtype to ensure numerical stability
    torch.set_default_dtype(torch.float32)

    print("✓ Deep cleanup complete (memory cleared)")


deep_cleanup()


# ============================================================
# STEP 2 — CLEAN MODULE RELOAD
# ============================================================
import sys
import os
import importlib

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# ------------------------------------------------------------
# Import DAQR modules
# ------------------------------------------------------------
from daqr.config import experiment_config, gd_backup_manager, local_backup_manager
from daqr.core import network_environment, qubit_allocator
from daqr.algorithms import neural_bandits, predictive_bandits, base_bandit
from daqr.evaluation import multi_run_evaluator, visualizer, experiment_runner

# ------------------------------------------------------------
# Reload modules to ensure a clean environment
# ------------------------------------------------------------
importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(qubit_allocator)
importlib.reload(base_bandit)
importlib.reload(neural_bandits)
importlib.reload(predictive_bandits)
importlib.reload(experiment_runner)
importlib.reload(multi_run_evaluator)
importlib.reload(visualizer)

# ------------------------------------------------------------
# Import specific classes after reloads
# ------------------------------------------------------------
from daqr.config.gd_backup_manager import GoogleDriveBackupManager
from daqr.config.experiment_config import ExperimentConfiguration
from daqr.config.local_backup_manager import LocalBackupManager
from daqr.core.network_environment import *
from daqr.core.qubit_allocator import *
from daqr.algorithms.base_bandit import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.experiment_runner import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully (fresh environment ready)")



import subprocess

os.chdir("/content/drive/Shareddrives/ai_quantum_computing/quantum_project")
print("📌 Now in:", os.getcwd())

# Compute the absolute path of cleanup_state_duplicates.py
cleanup_script = os.path.abspath("cleanup_state_duplicates.py")

print(f"🚿 Running cleanup script at:\n{cleanup_script}\n")

# Execute the script exactly as-is
result = subprocess.run(
    ["python3", cleanup_script],
    text=True,
    capture_output=True
)

print("===== CLEANUP STDOUT =====")
print(result.stdout)

print("===== CLEANUP STDERR =====")
print(result.stderr)

print("🚿 Cleanup finished.")
# Out:
# ✓ Deep cleanup complete!
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully!

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
from daqr.core.qubit_allocator import *

# Create allocator with correct parameters
# allocator = ThompsonSamplingAllocator(
#     total_qubits=35,           # Total qubits available (8+10+8+9=35)
#     num_routes=4,              # Number of routes
#     min_qubits_per_route=2     # Minimum qubits per route
# )
# AFTER (UCB - Dynamic):

# allocator = DynamicQubitAllocator(              # ← Change class name
#     total_qubits=35,           
#     num_routes=4,              
#     min_qubits_per_route=2,
#     exploration_bonus=2.0      # ← NEW parameter (optional, default is 2.0)
# )



# Fully random (exploration only)
# allocator = RandomQubitAllocator(epsilon=1.0, seed=42)

# # 50-50 mix of random and baseline
# random_50 = RandomQubitAllocator(epsilon=0.5, seed=42)

# # Mostly baseline with occasional exploration (epsilon-greedy style)
# random_10 = RandomQubitAllocator(epsilon=0.1, seed=42)

# # Decaying randomness (start exploratory, become deterministic)
# decaying = RandomQubitAllocator(
#     epsilon=1.0,           # Start fully random
#     epsilon_decay=0.99,    # Decay 1% per timestep
#     min_epsilon=0.05,      # Eventually stabilize at 5% exploration
#     seed=42
# )

# # Fully deterministic (acts like fixed allocator)
# deterministic = RandomQubitAllocator(epsilon=0.0, seed=42)

# models = ['Oracle', 'GNeuralUCB', 'EXPNeuralUCB']
allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=True,
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=False, overwrite=True) # 4-8k<-cap=8k, 10-12k<-cap=20k, 14-18k<-cap=28k, 20-24k<-cap=40k
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
# BUILDING REGISTRY WITH 0 EXPECTED KEYS
# 	→ Filesystem scan found 0 files
# 	→ Drive registry updated
# ===================== REGISTRY BUILD COMPLETE =====================
#
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
#   • Core (no .pkl): MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10
#   • Prefix: MultiRunEvaluator
#   • Remainder: 8000-Default_Adversarial_Markov-4000_2000_10
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        8000
#   • allocator_id:  Default
#   • env_id:        Adversarial
#   • attack_id:     Markov
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       10
#   • Total runs:    10
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/10 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/10 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_12000-Default_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/10 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_16000-Default_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Default_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_12000-Default_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_16000-Default_Stochastic_No-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Stochastic_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Stochastic_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Stochastic_OnlineAdaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Adversarial_No-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Adversarial_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Adversarial_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Adversarial_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_16000-Default_Adversarial_OnlineAdaptive-8000_3.pkl
#
#   • Model keys: 150
#     - Oracle(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_No-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Random-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Markov-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_Adaptive-4000.pkl
#     - Oracle(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Default_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_No-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Random-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Markov-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_Adaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_No-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Random-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Markov-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_Adaptive-6000.pkl
#     - Oracle(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_12000-Default_Adversarial_OnlineAdaptive-6000.pkl
#     - Oracle(hybrid)_16000-Default_Stochastic_No-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Stochastic_No-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_No-8000.pkl
#     - Oracle(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Random-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Random-8000.pkl
#     - Oracle(hybrid)_16000-Default_Stochastic_Markov-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Markov-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Markov-8000.pkl
#     - Oracle(hybrid)_16000-Default_Stochastic_Adaptive-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Stochastic_Adaptive-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_Adaptive-8000.pkl
#     - Oracle(hybrid)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Stochastic_OnlineAdaptive-8000.pkl
#     - Oracle(hybrid)_16000-Default_Adversarial_No-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Adversarial_No-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_No-8000.pkl
#     - Oracle(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Random-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Random-8000.pkl
#     - Oracle(hybrid)_16000-Default_Adversarial_Markov-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Markov-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Markov-8000.pkl
#     - Oracle(hybrid)_16000-Default_Adversarial_Adaptive-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Adversarial_Adaptive-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_Adaptive-8000.pkl
#     - Oracle(hybrid)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     - GNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     - EXPNeuralUCB(hybrid)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     - CPursuitNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#     - iCPursuitNeuralUCB(neural)_16000-Default_Adversarial_OnlineAdaptive-8000.pkl
#
# --- Run 4/10 -----------------------
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_No-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_No-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_No-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_No-10000.pkl
#     → CPursuitNeuralUCB(neural)_20000-Default_Stochastic_No-10000.pkl
#     → iCPursuitNeuralUCB(neural)_20000-Default_Stochastic_No-10000.pkl
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_Random-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_Random-10000.pkl
#     → CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#     → iCPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_Random-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_Random-10000.pkl
#     → CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#     → iCPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_Markov-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_Markov-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_Markov-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_Markov-10000.pkl
#     → CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Markov-10000.pkl
#     → iCPursuitNeuralUCB(neural)_20000-Default_Stochastic_Markov-10000.pkl
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_Adaptive-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_Adaptive-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_Adaptive-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_Adaptive-10000.pkl
#     → CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Adaptive-10000.pkl
#     → iCPursuitNeuralUCB(neural)_20000-Default_Stochastic_Adaptive-10000.pkl
#   • Frame number: 10000
#   → Runner key: QuantumExperimentRunner_4_20000-Default_Stochastic_OnlineAdaptive-10000_4.pkl
#   • Generating model keys:
#     → Oracle(hybrid)_20000-Default_Stochastic_OnlineAdaptive-10000.pkl
#     → GNeuralUCB(neural)_20000-Default_Stochastic_OnlineAdaptive-10000.pkl
#     → EXPNeuralUCB(hybrid)_20000-Default_Stochastic_OnlineAdaptive-10000.pkl
# ...
#     - GNeuralUCB(neural)_32000-Default_Stochastic_Markov-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Stochastic_Markov-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Stochastic_Markov-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Stochastic_Markov-16000.pkl
#     - Oracle(hybrid)_32000-Default_Stochastic_Adaptive-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Stochastic_Adaptive-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Stochastic_Adaptive-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Stochastic_Adaptive-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Stochastic_Adaptive-16000.pkl
#     - Oracle(hybrid)_32000-Default_Stochastic_OnlineAdaptive-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Stochastic_OnlineAdaptive-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Stochastic_OnlineAdaptive-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Stochastic_OnlineAdaptive-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Stochastic_OnlineAdaptive-16000.pkl
#     - Oracle(hybrid)_32000-Default_Adversarial_No-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Adversarial_No-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Adversarial_No-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Adversarial_No-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Adversarial_No-16000.pkl
#     - Oracle(hybrid)_32000-Default_Adversarial_Random-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Adversarial_Random-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Adversarial_Random-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Adversarial_Random-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Adversarial_Random-16000.pkl
#     - Oracle(hybrid)_32000-Default_Adversarial_Markov-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Adversarial_Markov-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Adversarial_Markov-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Adversarial_Markov-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Adversarial_Markov-16000.pkl
#     - Oracle(hybrid)_32000-Default_Adversarial_Adaptive-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Adversarial_Adaptive-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Adversarial_Adaptive-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Adversarial_Adaptive-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Adversarial_Adaptive-16000.pkl
#     - Oracle(hybrid)_32000-Default_Adversarial_OnlineAdaptive-16000.pkl
#     - GNeuralUCB(neural)_32000-Default_Adversarial_OnlineAdaptive-16000.pkl
#     - EXPNeuralUCB(hybrid)_32000-Default_Adversarial_OnlineAdaptive-16000.pkl
#     - CPursuitNeuralUCB(neural)_32000-Default_Adversarial_OnlineAdaptive-16000.pkl
#     - iCPursuitNeuralUCB(neural)_32000-Default_Adversarial_OnlineAdaptive-16000.pkl
#     - Oracle(hybrid)_36000-Default_Stochastic_No-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Stochastic_No-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Stochastic_No-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Stochastic_No-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Stochastic_No-18000.pkl
#     - Oracle(hybrid)_36000-Default_Stochastic_Random-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Stochastic_Random-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Stochastic_Random-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Stochastic_Random-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Stochastic_Random-18000.pkl
#     - Oracle(hybrid)_36000-Default_Stochastic_Markov-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Stochastic_Markov-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Stochastic_Markov-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Stochastic_Markov-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Stochastic_Markov-18000.pkl
#     - Oracle(hybrid)_36000-Default_Stochastic_Adaptive-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Stochastic_Adaptive-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Stochastic_Adaptive-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Stochastic_Adaptive-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Stochastic_Adaptive-18000.pkl
#     - Oracle(hybrid)_36000-Default_Stochastic_OnlineAdaptive-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Stochastic_OnlineAdaptive-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Stochastic_OnlineAdaptive-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Stochastic_OnlineAdaptive-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Stochastic_OnlineAdaptive-18000.pkl
#     - Oracle(hybrid)_36000-Default_Adversarial_No-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Adversarial_No-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Adversarial_No-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Adversarial_No-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Adversarial_No-18000.pkl
#     - Oracle(hybrid)_36000-Default_Adversarial_Random-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Adversarial_Random-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Adversarial_Random-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Adversarial_Random-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Adversarial_Random-18000.pkl
#     - Oracle(hybrid)_36000-Default_Adversarial_Markov-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Adversarial_Markov-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Adversarial_Markov-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Adversarial_Markov-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Adversarial_Markov-18000.pkl
#     - Oracle(hybrid)_36000-Default_Adversarial_Adaptive-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Adversarial_Adaptive-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Adversarial_Adaptive-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Adversarial_Adaptive-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Adversarial_Adaptive-18000.pkl
#     - Oracle(hybrid)_36000-Default_Adversarial_OnlineAdaptive-18000.pkl
#     - GNeuralUCB(neural)_36000-Default_Adversarial_OnlineAdaptive-18000.pkl
#     - EXPNeuralUCB(hybrid)_36000-Default_Adversarial_OnlineAdaptive-18000.pkl
#     - CPursuitNeuralUCB(neural)_36000-Default_Adversarial_OnlineAdaptive-18000.pkl
#     - iCPursuitNeuralUCB(neural)_36000-Default_Adversarial_OnlineAdaptive-18000.pkl
#     - Oracle(hybrid)_40000-Default_Stochastic_No-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Stochastic_No-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Stochastic_No-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Stochastic_No-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Stochastic_No-20000.pkl
#     - Oracle(hybrid)_40000-Default_Stochastic_Random-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Stochastic_Random-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Stochastic_Random-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Stochastic_Random-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Stochastic_Random-20000.pkl
#     - Oracle(hybrid)_40000-Default_Stochastic_Markov-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Stochastic_Markov-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Stochastic_Markov-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Stochastic_Markov-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Stochastic_Markov-20000.pkl
#     - Oracle(hybrid)_40000-Default_Stochastic_Adaptive-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Stochastic_Adaptive-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Stochastic_Adaptive-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Stochastic_Adaptive-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Stochastic_Adaptive-20000.pkl
#     - Oracle(hybrid)_40000-Default_Stochastic_OnlineAdaptive-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Stochastic_OnlineAdaptive-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Stochastic_OnlineAdaptive-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Stochastic_OnlineAdaptive-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Stochastic_OnlineAdaptive-20000.pkl
#     - Oracle(hybrid)_40000-Default_Adversarial_No-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Adversarial_No-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Adversarial_No-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Adversarial_No-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Adversarial_No-20000.pkl
#     - Oracle(hybrid)_40000-Default_Adversarial_Random-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Adversarial_Random-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Adversarial_Random-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Adversarial_Random-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Adversarial_Random-20000.pkl
#     - Oracle(hybrid)_40000-Default_Adversarial_Markov-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Adversarial_Markov-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Adversarial_Markov-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Adversarial_Markov-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Adversarial_Markov-20000.pkl
#     - Oracle(hybrid)_40000-Default_Adversarial_Adaptive-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Adversarial_Adaptive-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Adversarial_Adaptive-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Adversarial_Adaptive-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Adversarial_Adaptive-20000.pkl
#     - Oracle(hybrid)_40000-Default_Adversarial_OnlineAdaptive-20000.pkl
#     - GNeuralUCB(neural)_40000-Default_Adversarial_OnlineAdaptive-20000.pkl
#     - EXPNeuralUCB(hybrid)_40000-Default_Adversarial_OnlineAdaptive-20000.pkl
#     - CPursuitNeuralUCB(neural)_40000-Default_Adversarial_OnlineAdaptive-20000.pkl
#     - iCPursuitNeuralUCB(neural)_40000-Default_Adversarial_OnlineAdaptive-20000.pkl
#     - Oracle(hybrid)_44000-Default_Stochastic_No-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Stochastic_No-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Stochastic_No-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Stochastic_No-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Stochastic_No-22000.pkl
#     - Oracle(hybrid)_44000-Default_Stochastic_Random-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Stochastic_Random-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Stochastic_Random-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Stochastic_Random-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Stochastic_Random-22000.pkl
#     - Oracle(hybrid)_44000-Default_Stochastic_Markov-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Stochastic_Markov-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Stochastic_Markov-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Stochastic_Markov-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Stochastic_Markov-22000.pkl
#     - Oracle(hybrid)_44000-Default_Stochastic_Adaptive-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Stochastic_Adaptive-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Stochastic_Adaptive-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Stochastic_Adaptive-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Stochastic_Adaptive-22000.pkl
#     - Oracle(hybrid)_44000-Default_Stochastic_OnlineAdaptive-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Stochastic_OnlineAdaptive-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Stochastic_OnlineAdaptive-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Stochastic_OnlineAdaptive-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Stochastic_OnlineAdaptive-22000.pkl
#     - Oracle(hybrid)_44000-Default_Adversarial_No-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Adversarial_No-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Adversarial_No-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Adversarial_No-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Adversarial_No-22000.pkl
#     - Oracle(hybrid)_44000-Default_Adversarial_Random-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Adversarial_Random-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Adversarial_Random-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Adversarial_Random-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Adversarial_Random-22000.pkl
#     - Oracle(hybrid)_44000-Default_Adversarial_Markov-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Adversarial_Markov-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Adversarial_Markov-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Adversarial_Markov-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Adversarial_Markov-22000.pkl
#     - Oracle(hybrid)_44000-Default_Adversarial_Adaptive-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Adversarial_Adaptive-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Adversarial_Adaptive-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Adversarial_Adaptive-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Adversarial_Adaptive-22000.pkl
#     - Oracle(hybrid)_44000-Default_Adversarial_OnlineAdaptive-22000.pkl
#     - GNeuralUCB(neural)_44000-Default_Adversarial_OnlineAdaptive-22000.pkl
#     - EXPNeuralUCB(hybrid)_44000-Default_Adversarial_OnlineAdaptive-22000.pkl
#     - CPursuitNeuralUCB(neural)_44000-Default_Adversarial_OnlineAdaptive-22000.pkl
#     - iCPursuitNeuralUCB(neural)_44000-Default_Adversarial_OnlineAdaptive-22000.pkl
#
# EXPECTED KEY GENERATION COMPLETE
#
# RESTORING FROM DRIVE 1
# RESTORING FROM DRIVE 2
# 	⚠️ Registry exists → aborting restore
# 	⚠️ Not in registry: framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl | Exists? False
# 	☁️ Attempting Drive download: framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
# 	❌ Not found anywhere: framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
# 	 MultiRunEvaluator Path Found = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = False, size = N/A
# 	[WARN] No saved state at /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl or Empty (N/A)
# 	[ERROR] Failed loading pickle from /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl: [Errno 2] No such file or directory: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl'
# 	❌ Corrupted state detected → deleting: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/MultiRunEvaluator_8000-Default_Adversarial_Markov-4000_2000_10.pkl
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 	✅ Cleanup complete.
#
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 22000 (step: 2000)

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenario_performance(scenario=FRAMEWORK_CONFIG['main_env'])
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
# Out:
# ✓ Framework Configuration:
#   • Primary Environment: STOCHASTIC
#   • Evaluation Mode: COMPREHENSIVE
#   • Models to Test: 5
# ======================================================================
#
# ▶ Executing STOCHASTIC-FOCUSED EVALUATION:
#   • STOCHASTIC           Stochastic Random Failures
#   • MARKOV               Markov Adversarial Attack
#   • ADAPTIVE             Adaptive Adversarial Attack
#   • ONLINEADAPTIVE       Online Adaptive Attack
#   • NONE                 Baseline (Optimal Conditions)
# ======================================================================
#
# ⚙ Running Quantum MAB Models Evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Test Scenarios:             	Stochastic Random Failures, Markov Adversarial Attack, Adaptive Adversarial Attack, Online Adaptive Attack, Baseline (Optimal Conditions)
# Experiments per Scenario:   	10
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_8000-Default_Adversarial_5_attacks-4000_2000_10_log_day_20251126.txt
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=0 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 17138
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
# 	 QuantumExperimentRunner_1 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 2007362
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_1 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_1_8000-Default_Stochastic_Random-4000_1.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting GNeuralUCB           in sequence...
# 	EXP 1 GNEURALUCB          : Reward=2496.36, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	EXP 1 EXPNEURALUCB        : Reward=2174.17, Efficiency=078.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 1 CPURSUITNEURALUCB   : Reward=1969.36, Efficiency=071.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2538.56, Efficiency=091.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 1: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 17667
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:008.1%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:4000, SCapacity=8000, Alloc=Default]
# Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 12000 frames (CAPACITY:6000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=1 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 16108
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
# 	 QuantumExperimentRunner_2 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 2804996
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_2 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_2_12000-Default_Stochastic_Random-6000_2.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	EXP 2 GNEURALUCB          : Reward=3833.28, Efficiency=092.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	EXP 2 EXPNEURALUCB        : Reward=3716.44, Efficiency=089.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 2 CPURSUITNEURALUCB   : Reward=3814.32, Efficiency=092.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=3784.16, Efficiency=091.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=12000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:12000 (Scale=2 x Cap=6000), Seed: 14392
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:007.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=12000, Alloc=Default]
# Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 16000 frames (CAPACITY:8000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=2 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 20738
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
# 	 QuantumExperimentRunner_3 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3739195
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_3 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_3_16000-Default_Stochastic_Random-8000_3.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	EXP 3 GNEURALUCB          : Reward=5109.92, Efficiency=092.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	EXP 3 EXPNEURALUCB        : Reward=4335.25, Efficiency=078.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 3 CPURSUITNEURALUCB   : Reward=1055.37, Efficiency=019.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=16000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=5061.20, Efficiency=091.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=16000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:16000 (Scale=2 x Cap=8000), Seed: 17246
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:007.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=16000, Alloc=Default]
# Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 10000 frames  <>  SCALED-CAPACITY: 20000 frames (CAPACITY:10000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=3 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:10000, QubitAlloc=Default, SC:20000 (Scale=2 x Cap=10000), Seed: 17034
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl
# 	 QuantumExperimentRunner_4 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 4643301
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_4 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_4_20000-Default_Stochastic_Random-10000_4.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	EXP 4 GNEURALUCB          : Reward=6283.22, Efficiency=091.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=20000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	EXP 4 EXPNEURALUCB        : Reward=6269.80, Efficiency=090.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=20000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 4 CPURSUITNEURALUCB   : Reward=6336.40, Efficiency=091.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=20000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=6353.71, Efficiency=092.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=20000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:10000, QubitAlloc=Default, SC:20000 (Scale=2 x Cap=10000), Seed: 14843
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:008.0%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:10000, SCapacity=20000, Alloc=Default]
# Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 12000 frames  <>  SCALED-CAPACITY: 24000 frames (CAPACITY:12000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=4 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:12000, QubitAlloc=Default, SC:24000 (Scale=2 x Cap=12000), Seed: 22362
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl
# 	 QuantumExperimentRunner_5 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5571491
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_5 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_5_24000-Default_Stochastic_Random-12000_5.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	EXP 5 GNEURALUCB          : Reward=7639.62, Efficiency=092.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=24000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	EXP 5 EXPNEURALUCB        : Reward=7118.88, Efficiency=085.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=24000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 5 CPURSUITNEURALUCB   : Reward=7591.73, Efficiency=091.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=24000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=7611.87, Efficiency=091.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=24000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:12000, QubitAlloc=Default, SC:24000 (Scale=2 x Cap=12000), Seed: 21698
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:007.8%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:12000, SCapacity=24000, Alloc=Default]
# Experiment 5 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 6: 14000 frames  <>  SCALED-CAPACITY: 28000 frames (CAPACITY:14000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=5 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 6: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:14000, QubitAlloc=Default, SC:28000 (Scale=2 x Cap=14000), Seed: 22085
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl
# 	 QuantumExperimentRunner_6 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 6998323
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_6 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_6_28000-Default_Stochastic_Random-14000_6.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 6: Starting GNeuralUCB           in sequence...
# 	EXP 6 GNEURALUCB          : Reward=7746.83, Efficiency=080.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=28000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 6: Starting EXPNeuralUCB         in sequence...
# 	EXP 6 EXPNEURALUCB        : Reward=7783.34, Efficiency=080.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=28000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 6: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 6 CPURSUITNEURALUCB   : Reward=7800.58, Efficiency=080.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=28000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 6: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 6 ICPURSUITNEURALUCB  : Reward=8432.84, Efficiency=087.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=28000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 6: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:14000, QubitAlloc=Default, SC:28000 (Scale=2 x Cap=14000), Seed: 14357
# 	-->🏆 EXP6 Winner:iCPursuitNeuralUCB  (Gap:012.7%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:14000, SCapacity=28000, Alloc=Default]
# Experiment 6 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 7: 16000 frames  <>  SCALED-CAPACITY: 32000 frames (CAPACITY:16000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=6 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 7: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:16000, QubitAlloc=Default, SC:32000 (Scale=2 x Cap=16000), Seed: 21803
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl
# 	 QuantumExperimentRunner_7 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 7996503
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_7 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_7_32000-Default_Stochastic_Random-16000_7.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 7: Starting GNeuralUCB           in sequence...
# 	EXP 7 GNEURALUCB          : Reward=8939.62, Efficiency=080.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=32000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 7: Starting EXPNeuralUCB         in sequence...
# 	EXP 7 EXPNEURALUCB        : Reward=8976.27, Efficiency=081.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=32000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 7: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 7 CPURSUITNEURALUCB   : Reward=10191.53, Efficiency=092.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=32000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 7: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 7 ICPURSUITNEURALUCB  : Reward=10217.98, Efficiency=092.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=32000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 7: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:16000, QubitAlloc=Default, SC:32000 (Scale=2 x Cap=16000), Seed: 18291
# 	-->🏆 EXP7 Winner:iCPursuitNeuralUCB  (Gap:007.5%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:16000, SCapacity=32000, Alloc=Default]
# Experiment 7 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 8: 18000 frames  <>  SCALED-CAPACITY: 36000 frames (CAPACITY:18000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=7 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 8: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:18000, QubitAlloc=Default, SC:36000 (Scale=2 x Cap=18000), Seed: 15731
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl
# 	 QuantumExperimentRunner_8 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 8994713
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_8 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_8_36000-Default_Stochastic_Random-18000_8.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 8: Starting GNeuralUCB           in sequence...
# 	EXP 8 GNEURALUCB          : Reward=11537.35, Efficiency=092.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=36000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 8: Starting EXPNeuralUCB         in sequence...
# 	EXP 8 EXPNEURALUCB        : Reward=11692.39, Efficiency=094.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=36000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 8: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 8 CPURSUITNEURALUCB   : Reward=11557.38, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=36000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 8: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 8 ICPURSUITNEURALUCB  : Reward=11557.01, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=36000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 8: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:18000, QubitAlloc=Default, SC:36000 (Scale=2 x Cap=18000), Seed: 21917
# 	-->🏆 EXP8 Winner:EXPNeuralUCB        (Gap:005.9%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:18000, SCapacity=36000, Alloc=Default]
# Experiment 8 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 9: 20000 frames  <>  SCALED-CAPACITY: 40000 frames (CAPACITY:20000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=8 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 9: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:20000, QubitAlloc=Default, SC:40000 (Scale=2 x Cap=20000), Seed: 16188
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl
# 	 QuantumExperimentRunner_9 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 9932501
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_9 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_9_40000-Default_Stochastic_Random-20000_9.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 9: Starting GNeuralUCB           in sequence...
# 	EXP 9 GNEURALUCB          : Reward=12840.50, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=40000, Threshold=0.582]
# 	EXPNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 9: Starting EXPNeuralUCB         in sequence...
# 	EXP 9 EXPNEURALUCB        : Reward=12889.44, Efficiency=093.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=40000, Threshold=0.628]
# 	CPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 9: Starting CPursuitNeuralUCB    in sequence...
# 	EXP 9 CPURSUITNEURALUCB   : Reward=12959.56, Efficiency=093.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=40000, Threshold=0.634]
# 	iCPursuitNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 9: Starting iCPursuitNeuralUCB   in sequence...
# 	EXP 9 ICPURSUITNEURALUCB  : Reward=12963.10, Efficiency=093.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=40000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 9: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:20000, QubitAlloc=Default, SC:40000 (Scale=2 x Cap=20000), Seed: 14905
# 	-->🏆 EXP9 Winner:iCPursuitNeuralUCB  (Gap:006.1%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:20000, SCapacity=40000, Alloc=Default]
# Experiment 9 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 10: 22000 frames  <>  SCALED-CAPACITY: 44000 frames (CAPACITY:22000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [FixedAllocator] timestep=9 → allocation=(8, 10, 8, 9)
# 🔄 Dynamic Allocation (Initial): (8, 10, 8, 9)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 10: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:22000, QubitAlloc=Default, SC:44000 (Scale=2 x Cap=22000), Seed: 17802
# ======================================================================================================================================================
# 	⚠️ Not in registry: framework_state/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl
# 	 QuantumExperimentRunner_10 Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3684495
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 QuantumExperimentRunner_10 Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20251126/QuantumExperimentRunner_10_44000-Default_Stochastic_Random-22000_10.pkl
# 	Getting Oracle Rewards ...
# 	Oracle already processed
# 	GNeuralUCB WAS ALREADY PROCESSED
#
# 	🔄 STOCHASTIC (RANDOM) EXP 10: Starting GNeuralUCB           in sequence...
# 	EXP 10 GNEURALUCB          : Reward=14222.00, Efficiency=093.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=44000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 10: Starting EXPNeuralUCB         in sequence...
# 	⚠️ Not in registry: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl | Exists? False
# 	☁️ Attempting Drive download: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	❌ Not found anywhere: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	 Oracle Path Found = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = False, size = N/A
# 	[WARN] No saved state at /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl or Empty (N/A)
# 	[ERROR] Failed loading pickle from /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl: [Errno 2] No such file or directory: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl'
# 	❌ Corrupted state detected → deleting: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 	✅ Cleanup complete.
#
# 	⚠️  Oracle model not found, using manual fallback...
# 	⚠️ Not in registry: model_state/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890451
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	⚠️ Not in registry: model_state/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890452
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	⚠️ Not in registry: model_state/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187358
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	⚠️ Not in registry: model_state/NeuralUCB_3(hybrid)_88000-Default-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl | Exists? True
# 	✓ Found via filesystem: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187338
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl
# 	❌ Runtime error in EXPNeuralUCB: math range error
# 	⚠️ Not in registry: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl | Exists? False
# 	☁️ Attempting Drive download: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	❌ Not found anywhere: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	 Oracle Path Found = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = False, size = N/A
# 	[WARN] No saved state at /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl or Empty (N/A)
# 	[ERROR] Failed loading pickle from /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl: [Errno 2] No such file or directory: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl'
# 	❌ Corrupted state detected → deleting: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 	✅ Cleanup complete.
#
# 	⚠️  Oracle model not found, using manual fallback...
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890451
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890452
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187358
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187338
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl
# 	❌ Runtime error in EXPNeuralUCB: math range error
# 	⚠️ Not in registry: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl | Exists? False
# 	☁️ Attempting Drive download: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	❌ Not found anywhere: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	 Oracle Path Found = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = False, size = N/A
# 	[WARN] No saved state at /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl or Empty (N/A)
# 	[ERROR] Failed loading pickle from /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl: [Errno 2] No such file or directory: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl'
# 	❌ Corrupted state detected → deleting: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 	✅ Cleanup complete.
#
# 	⚠️  Oracle model not found, using manual fallback...
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890451
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890452
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187358
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187338
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl
# 	❌ Runtime error in EXPNeuralUCB: math range error
# 	⚠️ Not in registry: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	Checking FS (local): /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl | Exists? False
# 	☁️ Attempting Drive download: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	❌ Not found anywhere: model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	 Oracle Path Found = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = False, size = N/A
# 	[WARN] No saved state at /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl or Empty (N/A)
# 	[ERROR] Failed loading pickle from /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl: [Errno 2] No such file or directory: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl'
# 	❌ Corrupted state detected → deleting: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Oracle(hybrid)_88000-Default_Stochastic_Random-22000.pkl
# 	📦 LocalBackupManager Registry saved locally
# 	☁️ LocalBackupManager Registry synced to Google Drive
# 	✅ Cleanup complete.
#
# 	⚠️  Oracle model not found, using manual fallback...
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890451
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_0(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 3890452
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_1(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187358
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_2(hybrid)_88000-Default-22000.pkl
# 	 NeuralUCB Path Found = '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl' (type=<class 'str'>)
# 		[TRACE] state_path = PosixPath('/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl') (type=<class 'pathlib.PosixPath'>)
# 		[TRACE] state_path.exists() = True, size = 5187338
# 		[TRACE] loaded_dict type: <class 'dict'>
# 		[TRACE] self == loaded_dict → True (type=<class 'bool'>)
# 	🔄 NeuralUCB Resuming state from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20251126/NeuralUCB_3(hybrid)_88000-Default-22000.pkl

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()

# %%
saved_experiments = viz.save_all_evaluation_results(save_format='both')

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
