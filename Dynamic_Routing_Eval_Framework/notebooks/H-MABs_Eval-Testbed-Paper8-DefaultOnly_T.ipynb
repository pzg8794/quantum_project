# %% [markdown]
# # Paper 8 — Default Allocator Only (T Catch-up)
#
# This notebook runs **only** the **Default** allocator with `base_cap = False` (i.e., **T**, not Tb).
# It exists to safely catch up missing `T` runs after a longer batch finishes.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# ============================================================
# Setup: Quantum MAB Framework (Paper 8 RL/Q-learning Testbed)
# ============================================================

# --- (Optional) Install Dependencies ---
# !pip install -q torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn pmdarima networkx

# --- Core Imports ---
import os, sys, gc, warnings, importlib, subprocess
import itertools
import numpy as np
import matplotlib.pyplot as plt
import torch
import networkx as nx
from pathlib import Path

warnings.filterwarnings('ignore')

# --- Path Setup ---
print(f"Current working directory: {os.getcwd().split('/')[-1]}")
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")
except ImportError:
    print("Running locally (not in Colab)")
    current_dir = os.getcwd()
    if 'GA-Work' in current_dir and 'Dynamic_Routing_Eval_Framework' not in current_dir:
        project_dir = os.path.join(current_dir, 'hybrid_variable_framework', 'Dynamic_Routing_Eval_Framework')
        if os.path.exists(project_dir):
            os.chdir(project_dir)
            print(f"Changed to project directory: {os.getcwd().split('/')[-1]}")

# Add necessary paths for daqr package discovery
sys.path.append(os.path.join(os.getcwd(), 'src'))
sys.path.append(os.getcwd())

print("Framework dependencies installed successfully")
print(f"Python version: {sys.version.split()[0]}")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"NetworkX version: {nx.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")

import daqr
print('✓ daqr import OK')

from daqr.config.experiment_config import ExperimentConfiguration
from daqr.evaluation.allocator_runner import AllocatorRunner

from daqr.core.topology_generator import Paper8RandomConnectedTopologyGenerator
from daqr.core.quantum_physics import Paper8NoiseModel, Paper8FidelityCalculator

# (Optional) reload core modules during dev
from daqr.core import topology_generator, quantum_physics
importlib.reload(topology_generator)
importlib.reload(quantum_physics)
print('✓ core modules loaded')
# Out:
# Current working directory: GA-Work
# Running locally (not in Colab)
# Changed to project directory: Dynamic_Routing_Eval_Framework
# Framework dependencies installed successfully
# Python version: 3.12.11
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# NetworkX version: 3.5
# Matplotlib version: 3.10.6
# ✓ daqr import OK
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ core modules loaded

# %% [markdown]
# ## Paper 8 Run Configuration (Standardized Protocol)

# %%
# --- Paper 8 run configuration (STANDARDIZED protocol) ---
config = ExperimentConfiguration()
models = config.NEURAL_MODELS  # keep consistent with other testbed notebooks

# Paper 8 upstream simulation settings (reference only)
PAPER8_N_ITERATIONS = 1000
PAPER8_EPISODES_PER_AGENT = 15000
PAPER8_MODES = [1, 2, 3]

# Framework standardized run settings
# Base: 4K base frames, 2K step frames, 3/5 runs
BASE_FRAMES = 4000
FRAME_STEP  = 2000
RUNS        = [5]
SCALES      = [1, 1.5, 2]

# Optional stress runs (overnight): uncomment to stress
# RUNS = [8, 10]

ALLOCATORS  = ['Default']

ATTACK_INTENSITY = 0.25

# Run *all* threat regimes (same scenario set used across the framework)
# Scenario display labels (used by evaluator cells)
test_scenarios = {
    'stochastic': 'Stochastic Random Failures',
    'markov': 'Markov Adversarial Attack',
    'adaptive': 'Adaptive Adversarial Attack',
    'onlineadaptive': 'Online Adaptive Attack',
    'none': 'Baseline (Optimal Conditions)',
}

FRAMEWORK_CONFIG = {
    'exp_num': 1,
    'test_mode': True,
    'base_frames': BASE_FRAMES,
    'frame_step': FRAME_STEP,
    'models': models,
    'intensity': ATTACK_INTENSITY,
    'routing_strategy': 'fixed',
    'capacity': 10000,
    'main_env': 'stochastic',
    'env_attrs': {
        'intensity': ATTACK_INTENSITY,
        'base_seed': 10,  # Paper 8 sets numpy/random seed=10
        'reproducible': True,
    },

    # Paper 8 configuration (from upstream [R]Qsim-top-V6-Resource.ipynb)
    'paper8': {
        'testbed': 'paper8',
        'num_paths': 8,
        'total_qubits': 35,
        'min_qubits_per_route': 2,

        # topology parameters
        'num_nodes': 20,
        'connection_prob': 0.001,
        'fidelity_range': (0.65, 0.99),
        'rate_range': (0.75, 1.0),
        'pur_round_range': (0, 3),
        'swap_success_range': (0.23, 0.8),

        # physics params
        'min_fidelity': 0.0,
    },
}

print('BASE_FRAMES:', BASE_FRAMES)
print('FRAME_STEP:', FRAME_STEP)
print('RUNS:', RUNS)
print('SCALES:', SCALES)
print('PHYSICS_MODELS: paper8')
# Out:
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260303
#       Relative: framework_state/day_20260303
#       Component: framework_state
#       Date: day_20260303
#       📄 Processing 3290 files in framework_state/day_20260303
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260303: 3146/3290 files processed
#       📊 framework_state/day_20260303: 0/3290 files skipped
#       📊 framework_state/day_20260303: 144/3290 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260303
#       Relative: model_state/day_20260303
#       Component: model_state
#       Date: day_20260303
#       📄 Processing 11435 files in model_state/day_20260303
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260303: 11435/11435 files processed
#       📊 model_state/day_20260303: 0/11435 files skipped
#       📊 model_state/day_20260303: 0/11435 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260228
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260228
#       Component: framework_state_backups
#       Date: day_20260228
#       📄 Processing 25 files in framework_state_backups/day_20260228
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260228: 25/25 files processed
#       📊 framework_state_backups/day_20260228: 0/25 files skipped
#       📊 framework_state_backups/day_20260228: 0/25 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260204
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260204
#       Component: framework_state_backups
#       Date: day_20260204
#       📄 Processing 8 files in framework_state_backups/day_20260204
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260204: 8/8 files processed
#       📊 framework_state_backups/day_20260204: 0/8 files skipped
#       📊 framework_state_backups/day_20260204: 0/8 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260207
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260207
#       Component: framework_state_backups
#       Date: day_20260207
#       📄 Processing 1 files in framework_state_backups/day_20260207
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260207: 1/1 files processed
#       📊 framework_state_backups/day_20260207: 0/1 files skipped
#       📊 framework_state_backups/day_20260207: 0/1 files conflicted
#       📊 framework_state_backups/day_20260207: 1 replaced, 0 skipped (dedupe policy)
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004612/day_20260228
#       Relative: framework_state_backups/_state_repair_backup_20260301_004612/day_20260228
#       Component: framework_state_backups
#       Date: day_20260228
#       📄 Processing 1 files in framework_state_backups/day_20260228
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260228: 1/1 files processed
#       📊 framework_state_backups/day_20260228: 0/1 files skipped
#       📊 framework_state_backups/day_20260228: 0/1 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_quarantine/_quarantine_20260301_004009/day_20260207
#       Relative: framework_state_quarantine/_quarantine_20260301_004009/day_20260207
#       Component: framework_state_quarantine
#       Date: day_20260207
#       📄 Processing 1 files in framework_state_quarantine/day_20260207
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_quarantine/day_20260207: 1/1 files processed
#       📊 framework_state_quarantine/day_20260207: 0/1 files skipped
#       📊 framework_state_quarantine/day_20260207: 0/1 files conflicted
#
#    📊 Processed 7 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state', 'framework_state_backups', 'framework_state_quarantine']
#   • framework_state: 3146 files
#   • model_state: 11435 files
#   • framework_state_backups: 34 files
#   • framework_state_quarantine: 1 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 14616
# ================================================================================
#
# 	→ Filesystem scan found 14616 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BASE_FRAMES: 4000
# FRAME_STEP: 2000
# RUNS: [5]
# SCALES: [1, 1.5, 2]
# PHYSICS_MODELS: paper8

# %% [markdown]
# ## Paper 8 Helper Functions (paths, contexts, physics adapter)

# %%
# --- Paper 8 helper functions + physics adapter ---
import itertools

def generate_paper8_paths(topology: nx.Graph, num_paths: int, seed: int):
    rng = np.random.default_rng(seed)
    nodes = list(topology.nodes())
    paths = []
    attempts = 0
    max_attempts = 20 * max(1, num_paths)
    while len(paths) < num_paths and attempts < max_attempts:
        attempts += 1
        src, dst = rng.choice(nodes, 2, replace=False)
        try:
            p = nx.shortest_path(topology, int(src), int(dst), weight='distance')
        except nx.NetworkXNoPath:
            continue
        if len(p) < 2:
            continue
        if p not in paths:
            paths.append([int(x) for x in p])
    if len(paths) < num_paths:
        raise RuntimeError(f'Paper8: could not find {num_paths} unique paths (found {len(paths)}).')
    return paths

def _compositions(total: int, parts: int, limit: int = 2500):
    out = []
    def rec(remaining: int, k: int, prefix):
        if len(out) >= limit:
            return
        if k == 1:
            out.append(prefix + [remaining])
            return
        for x in range(remaining + 1):
            if len(out) >= limit:
                return
            rec(remaining - x, k - 1, prefix + [x])
    rec(int(total), int(parts), [])
    return out

def generate_paper8_allocation_contexts(paths, qubit_cap, max_contexts_per_path: int = 2500):
    qubit_cap = list(qubit_cap)
    if len(qubit_cap) != len(paths):
        raise ValueError(f'Paper8: qubit_cap length {len(qubit_cap)} != paths length {len(paths)}')
    contexts = []
    for cap, path in zip(qubit_cap, paths):
        hops = max(1, len(path) - 1)
        comps = _compositions(int(cap), int(hops), limit=int(max_contexts_per_path))
        contexts.append(np.array(comps, dtype=int))
    return contexts

def get_physics_params(physics_model: str, current_frames: int, base_seed: int, qubit_cap):
    if physics_model != 'paper8':
        raise ValueError('This notebook only supports physics_model=paper8')

    p8 = FRAMEWORK_CONFIG['paper8']
    topo = Paper8RandomConnectedTopologyGenerator(
        num_nodes=p8.get('num_nodes', 50),
        connection_prob=p8.get('connection_prob', 0.08),
        seed=base_seed,
        fidelity_range=p8.get('fidelity_range', (0.6, 0.99)),
        rate_range=p8.get('rate_range', (0.7, 1.0)),
        pur_round_range=p8.get('pur_round_range', (0, 5)),
        swap_success_range=p8.get('swap_success_range', (0.7, 0.99)),
    ).generate()

    num_paths = int(p8.get('num_paths', len(qubit_cap)))
    paths = generate_paper8_paths(topo, num_paths=num_paths, seed=base_seed)
    contexts = generate_paper8_allocation_contexts(paths, qubit_cap, max_contexts_per_path=2500)

    noise_model = Paper8NoiseModel(topology=topo, paths=paths)
    fidelity_calc = Paper8FidelityCalculator(min_fidelity=float(p8.get('min_fidelity', 0.0)))

    print(f'📊 Paper8 Topology: {topo.number_of_nodes()} nodes, {topo.number_of_edges()} edges')
    print(f'📊 Paper8 Paths: {len(paths)}')

    return {
        'noise_model': noise_model,
        'fidelity_calculator': fidelity_calc,
        'external_topology': topo,
        'external_contexts': contexts,
        'external_rewards': None,
    }

# %% [markdown]
# ## Run (AllocatorRunner)
#
# Run each allocator in its own cell (same flow as the other testbed notebooks).

# %% [markdown]
# ### Allocator: Default\n

# %%
allocator_type = "Default"
ALLOCATORS = ["Default"]

# ------------------------------------------------------------
# Derive run parameters from FRAMEWORK_CONFIG (config cell)
# ------------------------------------------------------------
attack_intensity    = FRAMEWORK_CONFIG['intensity']
current_frames      = FRAMEWORK_CONFIG['base_frames']
frame_step          = FRAMEWORK_CONFIG['frame_step']
current_experiments = FRAMEWORK_CONFIG['exp_num']
last_backup         = True
base_cap            = False
overwrite           = False

ATTACK_SCENARIOS = ['stochastic']
PHYSICS_MODELS = ['paper8']

print("" + "=" * 70, "🎯 QUANTUM ROUTING ALLOCATOR EVALUATION", "=" * 70)
print("Total Allocators to Test:  ", len(ALLOCATORS))
print("Physics Models:            ", PHYSICS_MODELS)
print("Allocators:                ", ALLOCATORS)
print("Scales:                    ", SCALES)
print("Runs:                      ", RUNS)
print("=" * 70)

for allocator_type in ALLOCATORS:
    print("\n" + "="*70)
    print(f"RUNNING: {allocator_type} on Paper 8 (RL/Q-learning testbed) — standardized run config")
    print("="*70)

    for scale in SCALES:
        print("\n" + "-"*70)
        print(f"Preparing: {allocator_type} at scale {scale}")
        print("-"*70)

        for physics_model in PHYSICS_MODELS:
            print(f"🔧 Generating physics parameters for model: {physics_model}")

            custom_config = ExperimentConfiguration(
                env_type=FRAMEWORK_CONFIG['main_env'],
                scenarios=test_scenarios,
                use_last_backup=last_backup,
                models=models,
                attack_intensity=attack_intensity,
                scale=scale,
                base_capacity=base_cap,
                overwrite=overwrite,
            )

            alloc_runner = AllocatorRunner(
                allocator_type=allocator_type,
                physics_models=[physics_model],
                framework_config=FRAMEWORK_CONFIG,
                scales=[scale],
                runs=RUNS,
                models=models,
                test_scenarios=test_scenarios,
                config=custom_config,
            )

            alloc_runner.run(get_physics_params_func=get_physics_params)

print("ALL ALLOCATORS COMPLETE!")
# Out:
# ====================================================================== 🎯 QUANTUM ROUTING ALLOCATOR EVALUATION ======================================================================
# Total Allocators to Test:   1
# Physics Models:             ['paper8']
# Allocators:                 ['Default']
# Scales:                     [1, 1.5, 2]
# Runs:                       [5]
# ======================================================================
#
# ======================================================================
# RUNNING: Default on Paper 8 (RL/Q-learning testbed) — standardized run config
# ======================================================================
#
# ----------------------------------------------------------------------
# Preparing: Default at scale 1
# ----------------------------------------------------------------------
# 🔧 Generating physics parameters for model: paper8
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260303
#       Relative: framework_state/day_20260303
#       Component: framework_state
#       Date: day_20260303
#       📄 Processing 3290 files in framework_state/day_20260303
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state/day_20260303: 3146/3290 files processed
#       📊 framework_state/day_20260303: 0/3290 files skipped
#       📊 framework_state/day_20260303: 144/3290 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260303
#       Relative: model_state/day_20260303
#       Component: model_state
#       Date: day_20260303
#       📄 Processing 11435 files in model_state/day_20260303
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 model_state/day_20260303: 11435/11435 files processed
#       📊 model_state/day_20260303: 0/11435 files skipped
#       📊 model_state/day_20260303: 0/11435 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260228
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260228
#       Component: framework_state_backups
#       Date: day_20260228
#       📄 Processing 25 files in framework_state_backups/day_20260228
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260228: 25/25 files processed
#       📊 framework_state_backups/day_20260228: 0/25 files skipped
#       📊 framework_state_backups/day_20260228: 0/25 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260204
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260204
#       Component: framework_state_backups
#       Date: day_20260204
#       📄 Processing 8 files in framework_state_backups/day_20260204
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260204: 8/8 files processed
#       📊 framework_state_backups/day_20260204: 0/8 files skipped
#       📊 framework_state_backups/day_20260204: 0/8 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004009/day_20260207
#       Relative: framework_state_backups/_state_repair_backup_20260301_004009/day_20260207
#       Component: framework_state_backups
#       Date: day_20260207
#       📄 Processing 1 files in framework_state_backups/day_20260207
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260207: 1/1 files processed
#       📊 framework_state_backups/day_20260207: 0/1 files skipped
#       📊 framework_state_backups/day_20260207: 0/1 files conflicted
#       📊 framework_state_backups/day_20260207: 1 replaced, 0 skipped (dedupe policy)
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_backups/_state_repair_backup_20260301_004612/day_20260228
#       Relative: framework_state_backups/_state_repair_backup_20260301_004612/day_20260228
#       Component: framework_state_backups
#       Date: day_20260228
#       📄 Processing 1 files in framework_state_backups/day_20260228
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_backups/day_20260228: 1/1 files processed
#       📊 framework_state_backups/day_20260228: 0/1 files skipped
#       📊 framework_state_backups/day_20260228: 0/1 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state_quarantine/_quarantine_20260301_004009/day_20260207
#       Relative: framework_state_quarantine/_quarantine_20260301_004009/day_20260207
#       Component: framework_state_quarantine
#       Date: day_20260207
#       📄 Processing 1 files in framework_state_quarantine/day_20260207
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#       📊 framework_state_quarantine/day_20260207: 1/1 files processed
#       📊 framework_state_quarantine/day_20260207: 0/1 files skipped
#       📊 framework_state_quarantine/day_20260207: 0/1 files conflicted
#
#    📊 Processed 7 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state', 'framework_state_backups', 'framework_state_quarantine']
#   • framework_state: 3146 files
#   • model_state: 11435 files
#   • framework_state_backups: 34 files
#   • framework_state_quarantine: 1 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 14616
# ================================================================================
#
# 	→ Filesystem scan found 14616 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# ======================================================================
# 🎯 AllocatorRunner initialized: Default
# ======================================================================
#
# ======================================================================
# 🚀 STARTING ALLOCATOR: Default
# ======================================================================
# 🧩 State aggregation: enabled (target=day_20260303)
# [state-aggregate] enabled=True dry_run=False target=day_20260303
# [state-aggregate] framework_state: {'roots_missing': 0, 'day_dirs_seen': 1, 'files_considered': 0, 'files_moved': 0, 'files_replaced': 0, 'files_deleted': 0, 'dirs_removed': 0}
# [state-aggregate] model_state:     {'roots_missing': 0, 'day_dirs_seen': 1, 'files_considered': 0, 'files_moved': 0, 'files_replaced': 0, 'files_deleted': 0, 'dirs_removed': 0}
# [state-aggregate] registry_update=True
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
#
# 📊 Physics Model: paper8
#
# 📋 Allocator Config:
#    Type: Default
#    Testbed: paper8
#    Paths: 8
#    Total Qubits: 35
#    Min per route: 2
#    Seed: 42
# ✅ Allocator created: (4, 5, 4, 5, 4, 5, 4, 4)
# ✓ Allocator: QubitAllocator (8 paths)
#    Initial allocation: (4, 5, 4, 5, 4, 5, 4, 4)
# 📊 Paper8 Topology: 20 nodes, 19 edges
# 📊 Paper8 Paths: 8
#
# ======================================================================
# RUN 1 | Scale: 1 | Exp: 5
# ======================================================================
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_paper8.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        4000
#   • allocator_id:  Default
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       5
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/5 -----------------------
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#
#   • Model keys: 50
#
# --- Run 2/5 -----------------------
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#
#   • Model keys: 100
#
# --- Run 3/5 -----------------------
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#
#   • Model keys: 150
#
# --- Run 4/5 -----------------------
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 41
#
#   • Model keys: 200
#
# --- Run 5/5 -----------------------
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 51
#
#   • Model keys: 250
#
# EXPECTED KEY GENERATION COMPLETE
#
# RESTORING FROM DRIVE 1
# RESTORING FROM DRIVE 2
# 	⚠️ Registry exists → aborting restore
# 	✓ MultiRunEvaluator Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260303/MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_paper8.pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260303/MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_paper8.pkl
# 	   File exists: True, size: 210716962
# EQUAL METHOD
# Multi-Run Evaluator Initialized
# Environment Type: None
# Frame Range: 4000 -> 12000 (step: 2000)
# quantum_exps-Default(paper8)_alloc-all_envs-5_attacks-4000_2000-5_runs-S1Tb
# [Logging Redirect Initialized]
# Log File: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/quantum_logs/quantum_exps-Default(paper8)_alloc-all_envs-5_attacks-4000_2000-5_runs-S1Tb_20260303_log.txt
# ⚙ Running evaluation...
# ======================================================================
# SCENARIOS MODEL EVALUATION
# ======================================================================
# Testing algorithm performance against:
# 	• Stochastic:  	Natural quantum decoherence and network failures
# 	• Baseline:    	Optimal conditions for validation
# ======================================================================
# Models to Test:             	Oracle, GNeuralUCB, EXPNeuralUCB, CPursuitNeuralUCB, iCPursuitNeuralUCB
# Experiments per Scenario:   	5
# ======================================================================
#
#
#
# TESTING ENVIRONMENT SCENARIO: STOCHASTIC RANDOM FAILURES
# ==================================================
#
# STARTING EXPERIMENTS: STOCHASTIC
# Category: Stochastic (Natural Random Failures)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2732.53, Efficiency=084.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPNEURALUCB        : Reward=2746.23, Efficiency=085.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 1 CPURSUITNEURALUCB   : Reward=2723.90, Efficiency=084.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2823.96, Efficiency=087.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:012.4%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=4097.48, Efficiency=084.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPNEURALUCB        : Reward=4039.36, Efficiency=083.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 2 CPURSUITNEURALUCB   : Reward=4143.09, Efficiency=085.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=4104.23, Efficiency=084.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:014.3%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5803.07, Efficiency=090.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=5164.45, Efficiency=080.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=5735.26, Efficiency=089.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=5513.22, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:GNeuralUCB          (Gap:010.0%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 4: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 4 GNEURALUCB          : Reward=7235.67, Efficiency=089.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 4 EXPNEURALUCB        : Reward=4118.14, Efficiency=051.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 4 CPURSUITNEURALUCB   : Reward=7036.03, Efficiency=087.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=7266.43, Efficiency=090.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:009.8%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=8355.69, Efficiency=087.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=8480.68, Efficiency=088.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=8429.37, Efficiency=088.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=8811.59, Efficiency=092.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:008.0%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=1396.93, Efficiency=045.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPNEURALUCB        : Reward=0924.52, Efficiency=030.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 1 CPURSUITNEURALUCB   : Reward=1387.78, Efficiency=045.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.634]
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=1473.77, Efficiency=047.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:iCPursuitNeuralUCB  (Gap:052.2%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=2179.69, Efficiency=046.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPNEURALUCB        : Reward=1089.68, Efficiency=023.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 2 CPURSUITNEURALUCB   : Reward=2302.13, Efficiency=049.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.634]
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=2187.90, Efficiency=047.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:050.4%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=2873.76, Efficiency=046.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=2974.09, Efficiency=048.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=2916.50, Efficiency=047.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=2928.68, Efficiency=047.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:EXPNeuralUCB        (Gap:051.9%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 4: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 4 GNEURALUCB          : Reward=3855.24, Efficiency=049.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.582]
# 	EXP 4 EXPNEURALUCB        : Reward=3645.32, Efficiency=047.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 4 CPURSUITNEURALUCB   : Reward=3747.95, Efficiency=048.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.634]
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=3820.97, Efficiency=049.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:050.1%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=4643.22, Efficiency=054.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=4233.38, Efficiency=049.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=4383.72, Efficiency=051.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=4569.03, Efficiency=053.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:045.2%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for markov
#
#
#
# TESTING ENVIRONMENT SCENARIO: ADAPTIVE ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ADAPTIVE
# Category: Adaptive (Reactive Strategic)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2106.82, Efficiency=066.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPNEURALUCB        : Reward=2130.02, Efficiency=066.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 1 CPURSUITNEURALUCB   : Reward=2176.06, Efficiency=068.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2124.59, Efficiency=066.6% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:CPursuitNeuralUCB   (Gap:031.8%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=3247.43, Efficiency=067.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPNEURALUCB        : Reward=3361.70, Efficiency=070.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 2 CPURSUITNEURALUCB   : Reward=3370.96, Efficiency=070.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=3367.03, Efficiency=070.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:029.5%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4288.22, Efficiency=067.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=2938.52, Efficiency=046.1% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=4319.54, Efficiency=067.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=4341.50, Efficiency=068.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:032.0%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 4: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 4 GNEURALUCB          : Reward=5792.03, Efficiency=072.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 4 EXPNEURALUCB        : Reward=5911.66, Efficiency=074.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 4 CPURSUITNEURALUCB   : Reward=5575.52, Efficiency=069.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=5528.71, Efficiency=069.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:EXPNeuralUCB        (Gap:025.9%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=6652.44, Efficiency=072.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=6092.41, Efficiency=066.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=6963.27, Efficiency=076.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=6917.27, Efficiency=075.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:CPursuitNeuralUCB   (Gap:024.0%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for adaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: ONLINE ADAPTIVE ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: ONLINEADAPTIVE
# Category: Online Adaptive (Real-time Strategic)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2165.15, Efficiency=067.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPNEURALUCB        : Reward=2247.54, Efficiency=070.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 1 CPURSUITNEURALUCB   : Reward=2192.43, Efficiency=068.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2117.18, Efficiency=066.4% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:EXPNeuralUCB        (Gap:029.5%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=3252.71, Efficiency=068.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPNEURALUCB        : Reward=2999.99, Efficiency=062.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 2 CPURSUITNEURALUCB   : Reward=3250.05, Efficiency=068.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=3216.35, Efficiency=067.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:GNeuralUCB          (Gap:032.0%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=4357.32, Efficiency=068.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=3815.74, Efficiency=059.8% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=4380.95, Efficiency=068.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=4337.92, Efficiency=068.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:031.3%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 4: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 4 GNEURALUCB          : Reward=5492.36, Efficiency=068.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 4 EXPNEURALUCB        : Reward=5684.04, Efficiency=071.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 4 CPURSUITNEURALUCB   : Reward=5691.52, Efficiency=071.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=5709.19, Efficiency=071.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:028.4%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=6874.17, Efficiency=075.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=5346.60, Efficiency=058.3% [Retries=3, Failed=0, < Threshold=3, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=6682.20, Efficiency=072.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=6886.97, Efficiency=075.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:iCPursuitNeuralUCB  (Gap:024.9%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for onlineadaptive
#
#
#
# TESTING ENVIRONMENT SCENARIO: BASELINE (OPTIMAL CONDITIONS)
# ==================================================
#
# STARTING EXPERIMENTS: NONE
# Category: Baseline (No Attacks)
# ============================================================
# ⏩ SKIPPING EXPERIMENT 1: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 1 GNEURALUCB          : Reward=2921.46, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 1 EXPNEURALUCB        : Reward=2552.85, Efficiency=079.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 1 CPURSUITNEURALUCB   : Reward=2904.51, Efficiency=089.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=2914.29, Efficiency=090.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:009.6%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 2: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 2 GNEURALUCB          : Reward=4437.27, Efficiency=091.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 2 EXPNEURALUCB        : Reward=4020.03, Efficiency=082.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 2 CPURSUITNEURALUCB   : Reward=4612.69, Efficiency=095.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=4446.29, Efficiency=091.7% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP2 Winner:CPursuitNeuralUCB   (Gap:004.9%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=5966.78, Efficiency=092.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=5564.71, Efficiency=086.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=5955.57, Efficiency=092.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=6219.57, Efficiency=096.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:003.8%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 4: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 4 GNEURALUCB          : Reward=7445.83, Efficiency=092.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 4 EXPNEURALUCB        : Reward=6400.26, Efficiency=079.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 4 CPURSUITNEURALUCB   : Reward=7518.65, Efficiency=093.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=7783.03, Efficiency=096.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:003.7%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=9392.11, Efficiency=096.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=8392.75, Efficiency=086.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=9369.33, Efficiency=096.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=8983.09, Efficiency=092.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:003.2%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Default]
#
# Total experiment time: 000.0s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 6428.65
# 	• Winner Avg Gap: 0011.96%
# 	• Winner Avg Reward: 5703.88
# 	• Winner Avg Efficiency: 0088.04%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	012.0%
# 	Winner Avg Efficiency: 	088.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	088.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	087.3% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	086.9% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	077.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 6023.22
# 	• Winner Avg Gap: 0050.87%
# 	• Winner Avg Reward: 2996.07
# 	• Winner Avg Efficiency: 0049.13%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	050.9%
# 	Winner Avg Efficiency: 	049.1%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	049.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	048.7% Efficiency 	(Won 2/5 experiments)
# 	• CPursuitNeuralUCB: 	048.4% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	039.7% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 6299.07
# 	• Winner Avg Gap: 0029.55%
# 	• Winner Avg Reward: 4481.07
# 	• Winner Avg Efficiency: 0070.45%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 3 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	029.5%
# 	Winner Avg Efficiency: 	070.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	070.5% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	070.0% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	069.3% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	064.7% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 6296.94
# 	• Winner Avg Gap: 0030.06%
# 	• Winner Avg Reward: 4439.43
# 	• Winner Avg Efficiency: 0069.94%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	030.1%
# 	Winner Avg Efficiency: 	069.9%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	069.9% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	069.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	069.6% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	064.5% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 6465.96
# 	• Winner Avg Gap: 0006.61%
# 	• Winner Avg Reward: 6069.25
# 	• Winner Avg Efficiency: 0093.39%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	006.6%
# 	Winner Avg Efficiency: 	093.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.4% Efficiency 	(Won 2/5 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	092.6% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	082.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (iCPursuitNeuralUCB):
# 	• Stochastic Performance:    	5703.884
# 	• Baseline Performance:      	6069.253
# 	• Performance Retention:     	094.0%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 6428.65
# ...
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=4154.54, Efficiency=085.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=2701.78, Efficiency=055.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=4133.92, Efficiency=085.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=4332.64, Efficiency=089.6% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 2: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:6000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 20670
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:010.4%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:6000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=2 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for STOCHASTIC Exp 3: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 13109
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 GNEURALUCB          : Reward=5611.12, Efficiency=087.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 EXPNEURALUCB        : Reward=5380.57, Efficiency=083.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 CPURSUITNEURALUCB   : Reward=5502.06, Efficiency=085.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 3: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=5799.46, Efficiency=090.0% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 3: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 13109
# 	-->🏆 EXP3 Winner:iCPursuitNeuralUCB  (Gap:010.0%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:8000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 3 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 4: 10000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=3 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for STOCHASTIC Exp 4: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:10000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 21003
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 GNEURALUCB          : Reward=7003.33, Efficiency=086.9% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 EXPNEURALUCB        : Reward=6802.68, Efficiency=084.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 CPURSUITNEURALUCB   : Reward=7262.55, Efficiency=090.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 4: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=7281.19, Efficiency=090.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 4: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:10000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 21003
# 	-->🏆 EXP4 Winner:iCPursuitNeuralUCB  (Gap:009.6%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:10000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 4 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 12000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=4 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for STOCHASTIC Exp 5: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:12000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15275
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 GNEURALUCB          : Reward=8712.61, Efficiency=091.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 EXPNEURALUCB        : Reward=7926.13, Efficiency=082.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 CPURSUITNEURALUCB   : Reward=8641.63, Efficiency=090.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
#
# 	🔄 STOCHASTIC (RANDOM) EXP 5: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=8402.47, Efficiency=087.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
#
# STOCHASTIC (RANDOM) EXP 5: Env:Stochastic, Attack:Random, Rate:0.0625, Frames:12000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 15275
# 	-->🏆 EXP5 Winner:GNeuralUCB          (Gap:008.9%) [Env:Stochastic, Attack:Random X Rate:0.0625, Frames:12000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 5 completed successfully.
# Total experiment time: 2190.6s
# Experiments completed for stochastic
#
#
#
# TESTING ENVIRONMENT SCENARIO: MARKOV ADVERSARIAL ATTACK
# ==================================================
#
# STARTING EXPERIMENTS: MARKOV
# Category: Structured (Markov Chain Based)
# ============================================================
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 1: 4000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=0 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for MARKOV Exp 1: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 14946
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 GNEURALUCB          : Reward=1489.32, Efficiency=048.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 EXPNEURALUCB        : Reward=1434.10, Efficiency=046.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 CPURSUITNEURALUCB   : Reward=1263.20, Efficiency=040.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 1: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 1 ICPURSUITNEURALUCB  : Reward=1317.07, Efficiency=042.5% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 1: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:4000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 14946
# 	-->🏆 EXP1 Winner:GNeuralUCB          (Gap:052.0%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:4000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 1 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 2: 6000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=1 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for MARKOV Exp 2: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 12973
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 GNEURALUCB          : Reward=2193.60, Efficiency=047.2% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.582]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting EXPNeuralUCB         in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 EXPNEURALUCB        : Reward=2227.40, Efficiency=048.0% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.628]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting CPursuitNeuralUCB    in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 CPURSUITNEURALUCB   : Reward=2317.71, Efficiency=049.9% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.634]
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 2: Starting iCPursuitNeuralUCB   in sequence...
# 	✓ Oracle model loaded from configs: Oracle
# 	EXP 2 ICPURSUITNEURALUCB  : Reward=2448.31, Efficiency=052.7% [Retries=3, Failed=0, < Threshold=3, SCapacity=8000, Threshold=0.712]
#
# ADVERSARIAL (MARKOV) EXP 2: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:6000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 12973
# 	-->🏆 EXP2 Winner:iCPursuitNeuralUCB  (Gap:047.3%) [Env:Adversarial, Attack:Markov X Rate:0.25, Frames:6000, SCapacity=8000, Alloc=Default]
# ✓ Experiment 2 completed successfully.
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 3: 8000 frames  <>  SCALED-CAPACITY: 8000 frames (CAPACITY:4000 X SCALE:2)
# ----------------------------------------------------------------------------------------------------
# [QubitAllocator] timestep=2 → allocation=(4, 5, 4, 5, 4, 5, 4, 4)
# 🔧 Allocated qubits for MARKOV Exp 3: (4, 5, 4, 5, 4, 5, 4, 4)
# 🔄 Default Dynamic Allocation (Initial): (4, 5, 4, 5, 4, 5, 4, 4)
# ======================================================================================================================================================
#
# ADVERSARIAL (MARKOV) EXP 3: Env:Adversarial, Attack:Markov, Rate:0.25, Frames:8000, QubitAlloc=Default, SC:8000 (Scale=2 x Cap=4000), Seed: 16123
# ======================================================================================================================================================
# 	Getting Oracle Rewards ...
# 	📊 Reward structure for Oracle:
# 	   Type: <class 'list'>
# 	   Length: 8
# 	   First reward: [0.05271528003854567, 0.7584734899389046, 0.7584734899389046, 0.6345689841890836, 0.035220108092908126], type: <class 'list'>
# 	   First reward length: 5
#
# 	🔄 ADVERSARIAL (MARKOV) EXP 3: Starting GNeuralUCB           in sequence...
# 	✓ Oracle model loaded from configs: Oracle
