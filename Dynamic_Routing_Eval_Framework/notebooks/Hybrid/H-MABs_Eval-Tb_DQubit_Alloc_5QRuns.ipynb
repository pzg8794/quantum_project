# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 3,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1600 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1503/1600 files processed
#       📊 framework_state/day_20260110: 0/1600 files skipped
#       📊 framework_state/day_20260110: 97/1600 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1503 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6041
# ================================================================================
#
# 	→ Filesystem scan found 6041 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 3
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================
#   QUANTUM MAB – CLEAN RESET + FRESH IMPORT PIPELINE
# ============================================================
# This block:
#   ✓ Frees all global model objects
#   ✓ Clears CUDA + Python memory
#   ✓ Reloads all DAQR modules cleanly
#   ✓ Ensures any user can re-run cells safely in Colab
#
# This is the correct shared-drive-safe way to avoid
# stale state, GPU memory leaks, and broken reload logic.
# ============================================================



import subprocess

# os.chdir("/content/drive/Shareddrives/ai_quantum_computing/quantum_project")
# print("📌 Now in:", os.getcwd())
root = os.path.abspath("../..")
# Compute the absolute path of cleanup_state_duplicates.py
cleanup_script = os.path.abspath(f"{root}/cleanup_state_duplicates.py")

print(f"🚿 Running cleanup script at:\n{cleanup_script}\n")

# Execute the script exactly as-is
result = subprocess.run(
    ["python3", cleanup_script],
    text=True,
    capture_output=True
)

print("===== CLEANUP STDOUT =====")
print(result.stdout)

print("===== CLEANUP STDERR =====")
print(result.stderr)

print("🚿 Cleanup finished.")


# ============================================================
# STEP 1 — FULL CLEANUP
# ============================================================
import gc
import torch

def deep_cleanup():
    """
    Remove all instantiated model/evaluator objects from global scope
    and fully clear CPU/GPU memory.
    """
    to_clear = [
        "oracle", "gneuralucb", "expneuralucb",
        "cpursuitneuralucb", "icpursuitneuralucb",
        "evaluator", "results"
    ]

    for name in to_clear:
        if name in globals():
            obj = globals().get(name, None)
            # If a cleanup() method exists, call it
            try:
                if hasattr(obj, "cleanup"):
                    obj.cleanup(verbose=False)
            except:
                pass
            # Remove the variable
            globals().pop(name, None)

    # GPU cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Force Python garbage collector
    gc.collect()

    # Reset default dtype to ensure numerical stability
    torch.set_default_dtype(torch.float32)

    print("✓ Deep cleanup complete (memory cleared)")


deep_cleanup()


# ============================================================
# STEP 2 — CLEAN MODULE RELOAD
# ============================================================
import sys
import os
import importlib

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# ------------------------------------------------------------
# Import DAQR modules
# ------------------------------------------------------------
from daqr.config import experiment_config, gd_backup_manager, local_backup_manager
from daqr.core import network_environment, qubit_allocator
from daqr.algorithms import neural_bandits, predictive_bandits, base_bandit
from daqr.evaluation import multi_run_evaluator, visualizer, experiment_runner

# ------------------------------------------------------------
# Reload modules to ensure a clean environment
# ------------------------------------------------------------
importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(qubit_allocator)
importlib.reload(base_bandit)
importlib.reload(neural_bandits)
importlib.reload(predictive_bandits)
importlib.reload(experiment_runner)
importlib.reload(multi_run_evaluator)
importlib.reload(visualizer)

# ------------------------------------------------------------
# Import specific classes after reloads
# ------------------------------------------------------------
from daqr.config.gd_backup_manager import GoogleDriveBackupManager
from daqr.config.experiment_config import ExperimentConfiguration
from daqr.config.local_backup_manager import LocalBackupManager
from daqr.core.network_environment import *
from daqr.core.qubit_allocator import *
from daqr.algorithms.base_bandit import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.experiment_runner import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully (fresh environment ready)")
# Out:
# 🚿 Running cleanup script at:
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py
#
# ===== CLEANUP STDOUT =====
# Script dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework
# Project root: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework
#
# State roots:
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# ========== STARTING CLEANUP ==========
#
# [CLEANUP] Removing .0 float artifacts from filenames...
# [✓] Float artifacts fixed: 0
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: removed 0 duplicates
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: removed 0 duplicates
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: moved 0 files, removed 0 directories.
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: moved 0 files, removed 0 directories.
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/local_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 6149 corrected, 0 added
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/drive_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 6149 corrected, 0 added
# [INFO] Registry not found, skipping update: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/backup_registry.json
#
# ========== DONE ==========
#
#
# ===== CLEANUP STDERR =====
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py:1338: SyntaxWarning: invalid escape sequence '\('
#   "scenario_cat": re.split("\(|\)", scenario_cat)[-2],
#
# 🚿 Cleanup finished.
# ✓ Deep cleanup complete (memory cleared)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully (fresh environment ready)

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration

# Create allocator with correct parameters
allocator = ThompsonSamplingAllocator(
    total_qubits=35,           # Total qubits available (8+10+8+9=35)
    num_routes=4,              # Number of routes
    min_qubits_per_route=2     # Minimum qubits per route
)

# AFTER (UCB - Dynamic):
allocator = DynamicQubitAllocator(              # ← Change class name
    total_qubits=35,           
    num_routes=4,              
    min_qubits_per_route=2,
    exploration_bonus=2.0      # ← NEW parameter (optional, default is 2.0)
)

# models = ['Oracle', 'GNeuralUCB', 'EXPNeuralUCB']
# allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 5 # overwrite number of experiments
last_backup = True
overwrite = False
base_cap = True

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=1, base_capacity=base_cap, overwrite=overwrite)
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1600 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1503/1600 files processed
#       📊 framework_state/day_20260110: 0/1600 files skipped
#       📊 framework_state/day_20260110: 97/1600 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1503 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6041
# ================================================================================
#
# 	→ Filesystem scan found 6041 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Dynamic Dynamic Allocation (Initial): (9, 9, 9, 8)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        4000
#   • allocator_id:  Dynamic
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       5
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/5 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_4000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(base)_4000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/5 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_4000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(base)_4000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-6000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-6000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-6000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-6000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-6000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-6000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/5 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_4000-Dynamic_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_4000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_4000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_4000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_4000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_4000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Stochastic_No-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Stochastic_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Stochastic_OnlineAdaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Adversarial_No-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Adversarial_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_4000-Dynamic_Adversarial_OnlineAdaptive-8000_3.pkl
#
#   • Model keys: 150
#     - Oracle(base)_4000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_4000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_4000-Dynamic_Stochastic_No-4000.pkl
# ...
# 	EXP 4 ICPURSUITNEURALUCB  : Reward=7305.43, Efficiency=097.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP4 Winner:GNeuralUCB          (Gap:002.2%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:10000, SCapacity=4000, Alloc=Dynamic]
#
# ----------------------------------------------------------------------------------------------------
# EXPERIMENT 5: 12000 frames  <>  SCALED-CAPACITY: 4000 frames (CAPACITY:4000 X SCALE:1)
# ----------------------------------------------------------------------------------------------------
# [DynamicUCBAllocator] timestep=4 (initial) → allocation=(9, 9, 9, 8)
# 🔧 Allocated qubits for NONE Exp 5: (9, 9, 9, 8)
# 🔄 Dynamic Dynamic Allocation (Initial): (9, 9, 9, 8)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 5: Env:Baseline (None), Attack:No, Rate:0.0, Frames:12000, QubitAlloc=Dynamic, SC:4000 (Scale=1 x Cap=4000), Seed: 20949
# ======================================================================================================================================================
#
# 	🔄 Resume: QuantumExperimentRunner_5
# 	✓ QuantumExperimentRunner_5 Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110/QuantumExperimentRunner_5_4000-Dynamic_Baseline (None)_No-12000_5.pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110/QuantumExperimentRunner_5_4000-Dynamic_Baseline (None)_No-12000_5.pkl
# 	   File exists: True, size: 8325967
# ⏩ SKIPPING EXPERIMENT 5: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 5 GNEURALUCB          : Reward=8811.11, Efficiency=098.3% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.582]
# 	EXP 5 EXPNEURALUCB        : Reward=8079.33, Efficiency=090.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.628]
# 	EXP 5 CPURSUITNEURALUCB   : Reward=8817.31, Efficiency=098.4% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.634]
# 	EXP 5 ICPURSUITNEURALUCB  : Reward=8799.87, Efficiency=098.2% [Retries=0, Failed=0, < Threshold=0, SCapacity=4000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP5 Winner:CPursuitNeuralUCB   (Gap:001.6%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:12000, SCapacity=4000, Alloc=Dynamic]
#
# Total experiment time: 269.8s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5891.94
# 	• Winner Avg Gap: 0007.07%
# 	• Winner Avg Reward: 5500.12
# 	• Winner Avg Efficiency: 0092.93%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	007.1%
# 	Winner Avg Efficiency: 	092.9%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	092.9% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	087.0% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5864.32
# 	• Winner Avg Gap: 0008.46%
# 	• Winner Avg Reward: 5364.10
# 	• Winner Avg Efficiency: 0091.54%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.5%
# 	Winner Avg Efficiency: 	091.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	091.4% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	091.4% Efficiency 	(Won 3/5 experiments)
# 	• EXPNeuralUCB   : 	087.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5886.12
# 	• Winner Avg Gap: 0006.47%
# 	• Winner Avg Reward: 5506.80
# 	• Winner Avg Efficiency: 0093.53%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	006.5%
# 	Winner Avg Efficiency: 	093.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.5% Efficiency 	(Won 5/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	092.5% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	088.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5848.77
# 	• Winner Avg Gap: 0008.01%
# 	• Winner Avg Reward: 5342.34
# 	• Winner Avg Efficiency: 0091.99%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 3 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.0%
# 	Winner Avg Efficiency: 	092.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	092.0% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	092.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	091.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	086.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0001.66%
# 	• Winner Avg Reward: 5864.48
# 	• Winner Avg Efficiency: 0098.34%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.7%
# 	Winner Avg Efficiency: 	098.3%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.3% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	097.8% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	090.1% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (CPursuitNeuralUCB):
# 	• Stochastic Performance:    	5500.122
# 	• Baseline Performance:      	5864.485
# 	• Performance Retention:     	093.8%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5891.94
# 	• Winner Avg Gap: 0007.07%
# 	• Winner Avg Reward: 5500.12
# 	• Winner Avg Efficiency: 0092.93%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	007.1%
# 	Winner Avg Efficiency: 	092.9%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	092.9% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	087.0% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5864.32
# 	• Winner Avg Gap: 0008.46%
# 	• Winner Avg Reward: 5364.10
# 	• Winner Avg Efficiency: 0091.54%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.5%
# 	Winner Avg Efficiency: 	091.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	091.4% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	091.4% Efficiency 	(Won 3/5 experiments)
# 	• EXPNeuralUCB   : 	087.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5886.12
# 	• Winner Avg Gap: 0006.47%
# 	• Winner Avg Reward: 5506.80
# 	• Winner Avg Efficiency: 0093.53%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 5 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	006.5%
# 	Winner Avg Efficiency: 	093.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.5% Efficiency 	(Won 5/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	092.5% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	088.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5848.77
# 	• Winner Avg Gap: 0008.01%
# 	• Winner Avg Reward: 5342.34
# 	• Winner Avg Efficiency: 0091.99%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 3 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.0%
# 	Winner Avg Efficiency: 	092.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	092.0% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	092.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	091.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	086.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0001.66%
# 	• Winner Avg Reward: 5864.48
# 	• Winner Avg Efficiency: 0098.34%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.7%
# 	Winner Avg Efficiency: 	098.3%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.3% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	097.8% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	090.1% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_comparison_20260110_214032.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	007.1%
# 	Winner Avg Efficiency: 	092.9%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	092.9% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	087.0% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_20260110_214032.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.5%
# 	Winner Avg Efficiency: 	091.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	091.4% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	091.4% Efficiency 	(Won 3/5 experiments)
# 	• EXPNeuralUCB   : 	087.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_markov_vs_baseline_20260110_214032.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 5/5 experiments)
# 	Winner Avg Gap: 	006.5%
# 	Winner Avg Efficiency: 	093.5%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.5% Efficiency 	(Won 5/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	092.5% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	088.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_adaptive_vs_baseline_20260110_214032.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	008.0%
# 	Winner Avg Efficiency: 	092.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	092.0% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	092.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	091.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	086.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_onlineadaptive_vs_baseline_20260110_214032.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.7%
# 	Winner Avg Efficiency: 	098.3%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.3% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	097.8% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	090.1% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_none_vs_baseline_20260110_214032.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5891.945
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 5496.632
#   • Oracle Efficiency: 92.9%
#   • Oracle Gap: 7.1%
#   • Classification: EXCELLENT
#
# EXPNeuralUCB:
#   • Stochastic Performance: 5249.843
#   • Oracle Efficiency: 87.0%
#   • Oracle Gap: 13.0%
#   • Classification: GOOD
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 5500.122
#   • Oracle Efficiency: 92.9%
#   • Oracle Gap: 7.1%
#   • Classification: EXCELLENT
#   ★ WINNER ★
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 5489.914
#   • Oracle Efficiency: 92.9%
#   • Oracle Gap: 7.1%
#   • Classification: EXCELLENT
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration


print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=1.5, base_capacity=base_cap, overwrite=overwrite)
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()


# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1605 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): .DS_Store
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1507/1605 files processed
#       📊 framework_state/day_20260110: 0/1605 files skipped
#       📊 framework_state/day_20260110: 98/1605 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1507 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6045
# ================================================================================
#
# 	→ Filesystem scan found 6045 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Dynamic Dynamic Allocation (Initial): (9, 9, 9, 8)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        6000
#   • allocator_id:  Dynamic
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       5
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/5 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(base)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/5 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(base)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-6000.pkl
#     - Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/5 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_6000.0-Dynamic_Stochastic_No-8000_3.pkl
# ...
# 	Winner Avg Gap: 	006.6%
# 	Winner Avg Efficiency: 	093.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.4% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	084.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5905.11
# 	• Winner Avg Gap: 0005.42%
# 	• Winner Avg Reward: 5583.12
# 	• Winner Avg Efficiency: 0094.58%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	005.4%
# 	Winner Avg Efficiency: 	094.6%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	094.6% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	094.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	094.2% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	085.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0001.85%
# 	• Winner Avg Reward: 5869.99
# 	• Winner Avg Efficiency: 0098.15%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.9%
# 	Winner Avg Efficiency: 	098.1%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	097.6% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (CPursuitNeuralUCB):
# 	• Stochastic Performance:    	5505.081
# 	• Baseline Performance:      	5869.990
# 	• Performance Retention:     	093.8%
# 	GOOD:               	Acceptable performance under stochastic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5889.94
# 	• Winner Avg Gap: 0006.66%
# 	• Winner Avg Reward: 5505.08
# 	• Winner Avg Efficiency: 0093.34%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 3 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	006.7%
# 	Winner Avg Efficiency: 	093.3%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	093.0% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	091.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	087.2% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5865.28
# 	• Winner Avg Gap: 0008.29%
# 	• Winner Avg Reward: 5380.84
# 	• Winner Avg Efficiency: 0091.71%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	091.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	087.1% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	085.5% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5889.49
# 	• Winner Avg Gap: 0006.56%
# 	• Winner Avg Reward: 5520.60
# 	• Winner Avg Efficiency: 0093.44%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	006.6%
# 	Winner Avg Efficiency: 	093.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.4% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	084.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5905.11
# 	• Winner Avg Gap: 0005.42%
# 	• Winner Avg Reward: 5583.12
# 	• Winner Avg Efficiency: 0094.58%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	005.4%
# 	Winner Avg Efficiency: 	094.6%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	094.6% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	094.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	094.2% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	085.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0001.85%
# 	• Winner Avg Reward: 5869.99
# 	• Winner Avg Efficiency: 0098.15%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 2 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.9%
# 	Winner Avg Efficiency: 	098.1%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	097.6% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_comparison_20260110_223008.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	006.7%
# 	Winner Avg Efficiency: 	093.3%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	093.0% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	091.0% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	087.2% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_20260110_223008.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.7% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	091.5% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	087.1% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	085.5% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_markov_vs_baseline_20260110_223008.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	006.6%
# 	Winner Avg Efficiency: 	093.4%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.4% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	093.2% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	092.9% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	084.7% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_adaptive_vs_baseline_20260110_223008.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	005.4%
# 	Winner Avg Efficiency: 	094.6%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	094.6% Efficiency 	(Won 3/5 experiments)
# 	• CPursuitNeuralUCB: 	094.3% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	094.2% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	085.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_onlineadaptive_vs_baseline_20260110_223008.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	001.9%
# 	Winner Avg Efficiency: 	098.1%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• iCPursuitNeuralUCB: 	098.1% Efficiency 	(Won 2/5 experiments)
# 	• GNeuralUCB     : 	097.6% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.8% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_none_vs_baseline_20260110_223008.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5889.944
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 5173.714
#   • Oracle Efficiency: 87.2%
#   • Oracle Gap: 12.8%
#   • Classification: GOOD
#
# EXPNeuralUCB:
#   • Stochastic Performance: 5318.813
#   • Oracle Efficiency: 91.0%
#   • Oracle Gap: 9.0%
#   • Classification: EXCELLENT
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 5505.081
#   • Oracle Efficiency: 93.3%
#   • Oracle Gap: 6.7%
#   • Classification: EXCELLENT
#   ★ WINNER ★
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 5487.947
#   • Oracle Efficiency: 93.0%
#   • Oracle Gap: 7.0%
#   • Classification: EXCELLENT
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration


print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=base_cap, overwrite=overwrite) 
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()


# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1600 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1503/1600 files processed
#       📊 framework_state/day_20260110: 0/1600 files skipped
#       📊 framework_state/day_20260110: 97/1600 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1503 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6041
# ================================================================================
#
# 	→ Filesystem scan found 6041 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Dynamic Dynamic Allocation (Initial): (9, 9, 9, 8)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        8000
#   • allocator_id:  Dynamic
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       5
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/5 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(base)_8000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/5 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(base)_8000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-6000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-6000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-6000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-6000.pkl
#     - Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-6000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-6000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-6000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-6000.pkl
#     - Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/5 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Dynamic_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Dynamic_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Dynamic_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Dynamic_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Stochastic_No-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Stochastic_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Stochastic_OnlineAdaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Adversarial_No-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Adversarial_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Dynamic_Adversarial_OnlineAdaptive-8000_3.pkl
#
#   • Model keys: 150
#     - Oracle(base)_8000-Dynamic_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Dynamic_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Dynamic_Stochastic_No-4000.pkl
# ...
# Recommended Model: 	GNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	006.7%
# 	Winner Avg Efficiency: 	093.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	093.3% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	083.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	079.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5892.66
# 	• Winner Avg Gap: 0008.33%
# 	• Winner Avg Reward: 5435.79
# 	• Winner Avg Efficiency: 0091.67%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.7% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	090.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	089.1% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0006.84%
# 	• Winner Avg Reward: 5557.25
# 	• Winner Avg Efficiency: 0093.16%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	006.8%
# 	Winner Avg Efficiency: 	093.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	093.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	091.8% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (CPursuitNeuralUCB):
# 	• Stochastic Performance:    	5487.830
# 	• Baseline Performance:      	5557.248
# 	• Performance Retention:     	098.8%
# 	EXCELLENT:          	Minimal performance loss under realistic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	5
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 5
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 5890.36
# 	• Winner Avg Gap: 0006.95%
# 	• Winner Avg Reward: 5487.83
# 	• Winner Avg Efficiency: 0093.05%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 2 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 0 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	007.0%
# 	Winner Avg Efficiency: 	093.0%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	093.0% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	092.8% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	091.9% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	082.5% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 5862.64
# 	• Winner Avg Gap: 0013.38%
# 	• Winner Avg Reward: 5080.77
# 	• Winner Avg Efficiency: 0086.62%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	013.4%
# 	Winner Avg Efficiency: 	086.6%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	086.6% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	086.1% Efficiency 	(Won 0/5 experiments)
# 	• iCPursuitNeuralUCB: 	083.1% Efficiency 	(Won 2/5 experiments)
# 	• CPursuitNeuralUCB: 	081.9% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: GNeuralUCB
# 	• Oracle Avg Reward: 5892.39
# 	• Winner Avg Gap: 0006.71%
# 	• Winner Avg Reward: 5517.42
# 	• Winner Avg Efficiency: 0093.29%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 3 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	006.7%
# 	Winner Avg Efficiency: 	093.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	093.3% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	083.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	079.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5892.66
# 	• Winner Avg Gap: 0008.33%
# 	• Winner Avg Reward: 5435.79
# 	• Winner Avg Efficiency: 0091.67%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 3 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.7% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	090.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	089.1% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 5
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5974.07
# 	• Winner Avg Gap: 0006.84%
# 	• Winner Avg Reward: 5557.25
# 	• Winner Avg Efficiency: 0093.16%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 4 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	006.8%
# 	Winner Avg Efficiency: 	093.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	093.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	091.8% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_comparison_20260110_211907.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 1/5 experiments)
# 	Winner Avg Gap: 	007.0%
# 	Winner Avg Efficiency: 	093.0%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	093.0% Efficiency 	(Won 1/5 experiments)
# 	• iCPursuitNeuralUCB: 	092.8% Efficiency 	(Won 0/5 experiments)
# 	• GNeuralUCB     : 	091.9% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	082.5% Efficiency 	(Won 2/5 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_stochastic_vs_baseline_20260110_211907.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 2/5 experiments)
# 	Winner Avg Gap: 	013.4%
# 	Winner Avg Efficiency: 	086.6%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	086.6% Efficiency 	(Won 2/5 experiments)
# 	• EXPNeuralUCB   : 	086.1% Efficiency 	(Won 0/5 experiments)
# 	• iCPursuitNeuralUCB: 	083.1% Efficiency 	(Won 2/5 experiments)
# 	• CPursuitNeuralUCB: 	081.9% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_markov_vs_baseline_20260110_211907.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	GNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	006.7%
# 	Winner Avg Efficiency: 	093.3%
#
# Overall Models Performance:
# 	• GNeuralUCB     : 	093.3% Efficiency 	(Won 3/5 experiments)
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	083.3% Efficiency 	(Won 1/5 experiments)
# 	• EXPNeuralUCB   : 	079.8% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_adaptive_vs_baseline_20260110_211907.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 3/5 experiments)
# 	Winner Avg Gap: 	008.3%
# 	Winner Avg Efficiency: 	091.7%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	091.7% Efficiency 	(Won 3/5 experiments)
# 	• GNeuralUCB     : 	090.7% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	089.1% Efficiency 	(Won 1/5 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/5 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_onlineadaptive_vs_baseline_20260110_211907.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 4/5 experiments)
# 	Winner Avg Gap: 	006.8%
# 	Winner Avg Efficiency: 	093.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.2% Efficiency 	(Won 4/5 experiments)
# 	• CPursuitNeuralUCB: 	093.1% Efficiency 	(Won 1/5 experiments)
# 	• GNeuralUCB     : 	091.8% Efficiency 	(Won 0/5 experiments)
# 	• EXPNeuralUCB   : 	090.4% Efficiency 	(Won 0/5 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Dynamic_none_vs_baseline_20260110_211907.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5890.356
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 5446.690
#   • Oracle Efficiency: 91.9%
#   • Oracle Gap: 8.1%
#   • Classification: EXCELLENT
#
# EXPNeuralUCB:
#   • Stochastic Performance: 4781.366
#   • Oracle Efficiency: 82.5%
#   • Oracle Gap: 17.5%
#   • Classification: GOOD
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 5487.830
#   • Oracle Efficiency: 93.0%
#   • Oracle Gap: 7.0%
#   • Classification: EXCELLENT
#   ★ WINNER ★
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 5475.938
#   • Oracle Efficiency: 92.8%
#   • Oracle Gap: 7.2%
#   • Classification: EXCELLENT
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
