# %% [markdown]
# # Neural Bandit Algorithm Evaluation Framework
#
# ## Graduate Research Project
# **AI & Quantum Computing Laboratory**
# **Rochester Institute of Technology**
#
# ---
#
# ## Research Framework Overview
#
# This comprehensive evaluation framework provides rigorous analysis of neural bandit algorithms with clear categorical distinction between different operational environments:
#
# - **Baseline Environment**: Optimal performance benchmark (Oracle)
# - **Stochastic Environment**: Natural random failures and network noise
# - **Adversarial Environment**: Strategic intelligent attacks and malicious targeting
#
# ## Primary Research Questions
#
# 1. **Algorithm Robustness**: How do neural bandit algorithms perform across different threat models?
# 2. **Comparative Analysis**: Which algorithms demonstrate superior performance in specific scenarios?
# 3. **Quantified Performance**: What are the exact degradation metrics under adversarial conditions?
# 4. **Theoretical Validation**: Do experimental results align with established regret bounds?
#
# ## Key Research Contributions
#
# - **Systematic Environment Categorization**: Clear baseline/stochastic/adversarial taxonomy
# - **Multi-Algorithm Comparative Testing**: Comprehensive evaluation across 6+ algorithms
# - **Quantified Robustness Metrics**: Precise performance degradation measurements
# - **Publication-Ready Analysis**: Academic-quality visualizations and statistical validation
#
# ## Evaluation Methodology
#
# The framework implements standardized testing protocols across three distinct categories:
# - **Baseline**: Oracle performance establishing theoretical upper bounds
# - **Stochastic**: Random environmental perturbations modeling realistic conditions
# - **Adversarial**: Strategic attack scenarios simulating malicious interference
#
# Each algorithm undergoes identical testing conditions enabling direct performance comparison and robustness quantification across all operational environments.

# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# @title Quantum MAB Models Evaluation Framework - Environment Setup
import os, sys
import warnings
warnings.filterwarnings('ignore')

# Get current directory
cur_dir = os.getcwd()
print(f"Current working directory: {cur_dir.split('/')[-1]}")

try:
    import google.colab                 # Check if running in Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Change to framework directory (updated path)
    project_dir = '/content/drive/MyDrive/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework'
    os.chdir(project_dir)
    print("Running in Google Colab")

    # Add source directory to path
    project_code_dir = os.path.join(project_dir, 'src')
    sys.path.append(project_code_dir)

except ImportError:
    print("Running locally (not in Colab)")
    # For local development, assume current directory structure
    pass

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Verify Python version and framework initialization
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Quantum MAB Models Evaluation Framework - Environment Ready")
# Out:
# Current working directory: notebooks
# Running locally (not in Colab)
# Now working from: notebooks
# Python version: 3.12.11
# Quantum MAB Models Evaluation Framework - Environment Ready

# %%
# @title Framework Dependencies Installation

# Install core scientific computing libraries for MAB evaluation
# !pip install torch torchvision numpy matplotlib seaborn pandas tqdm scipy scikit-learn -q

# Verify installations
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pandas as pd

print("Framework dependencies installed successfully")
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print("Quantum MAB Models Evaluation Framework - Ready for model testing")
# Out:
# Framework dependencies installed successfully
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Matplotlib version: 3.10.6
# Quantum MAB Models Evaluation Framework - Ready for model testing

# %% [markdown]
# ## Threat Model Classification Framework
#
# ### Systematic Environment Taxonomy
#
# This research framework establishes precise categorical distinctions for quantum network evaluation environments, addressing previous ambiguity in threat model classification:
#
# ### Environmental Categories
#
# | Environment | Implementation | Threat Characteristic | Research Application |
# |-------------|----------------|----------------------|---------------------|
# | **Baseline** | `none` | Deterministic optimal performance | Theoretical upper bound |
# | **Stochastic** | `stochastic`/`random` | Natural random failures | Realistic network conditions |
# | **Adversarial** | `markov` | Oblivious strategic attacks | Pattern-based targeting |
# | **Adversarial** | `adaptive` | Responsive strategic attacks | Feedback-driven targeting |
# | **Adversarial** | `onlineadaptive` | Real-time strategic attacks | Dynamic threat adaptation |
#
# ### Research Contribution
#
# This framework addresses a critical gap in existing literature where random network failures were often conflated with intentional adversarial attacks. The systematic categorization enables:
#
# - **Precise Robustness Quantification**: Exact performance degradation measurements across threat categories
# - **Comparative Algorithm Analysis**: Direct performance comparison under identical threat conditions
# - **Theoretical Validation**: Empirical verification of regret bounds across different adversarial models
# - **Reproducible Research Standards**: Standardized evaluation protocols for quantum network algorithms
#
# ### Methodological Significance
#
# Previous research often lacked clear distinction between stochastic and adversarial environments, limiting the ability to assess true algorithm robustness under intentional attacks versus natural network degradation. This framework provides the necessary precision for rigorous academic evaluation of quantum routing algorithms.

# %%
# @title Quantum MAB Models Evaluation Framework - Core Components Import

import importlib
import sys
import os
import numpy as np
import torch

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))

# Install pmdarima for time series analysis (used in some models)
try:
    import pmdarima as pm
except ImportError:
    # !pip install pmdarima -q
    import pmdarima as pm

print(f"Now working from: {os.getcwd().split('/')[-1]}")

# Import and reload framework components
try:
    # Core environment and algorithms
    from daqr.core import network_environment
    importlib.reload(network_environment)
    
    from daqr.algorithms import base_bandit
    importlib.reload(base_bandit)
    
    from daqr.algorithms import neural_bandits
    importlib.reload(neural_bandits)
    
    from daqr.algorithms import predictive_bandits
    importlib.reload(predictive_bandits)
    
    # Framework evaluation and testing
    from daqr.evaluation import experiment_runner
    importlib.reload(experiment_runner)
    
    from daqr.evaluation import multi_run_evaluator
    importlib.reload(multi_run_evaluator)
    
    from daqr.evaluation import visualizer
    importlib.reload(visualizer)
    
    from experiments import stochastic_evaluation
    importlib.reload(stochastic_evaluation)
    
    # Configuration
    from daqr.config import experiment_config
    importlib.reload(experiment_config)

    print("✅ Quantum MAB Models Evaluation Framework - All components imported successfully")
    
    # Try to verify framework configuration
    try:
        from daqr.config.experiment_config import ExperimentConfiguration
        print(f"📊 Framework configuration loaded: ExperimentConfiguration")
        
    except ImportError:
        print("⚠️  ExperimentConfiguration not available yet")

except ImportError as e:
    print(f"❌ Import error encountered: {e}")
    print("🔧 Manual module creation may be required")

# Display current module status
print("\n" + "="*60)
print("MODULE STATUS SUMMARY:")
print("="*60)

modules_to_check = [
    ('daqr.core', 'network_environment'),
    ('daqr.algorithms', 'base_bandit'),
    ('daqr.algorithms', 'neural_bandits'),
    ('daqr.algorithms', 'predictive_bandits'),
    ('daqr.evaluation', 'experiment_runner'),
    ('daqr.evaluation', 'multi_run_evaluator'),
    ('daqr.evaluation', 'visualizer'),
    ('experiments', 'stochastic_evaluation'),
    ('daqr.config', 'experiment_config')
]

for package, module_name in modules_to_check:
    try:
        mod = __import__(f"{package}.{module_name}", fromlist=[module_name])
        print(f"✅ {package}.{module_name:<30} - Loaded")
    except ImportError:
        print(f"❌ {package}.{module_name:<30} - Not available")

print("="*60)

# Check for new qubit allocator module
try:
    from daqr.core import qubit_allocator
    importlib.reload(qubit_allocator)
    print("\n🆕 Dynamic Qubit Allocation module loaded!")
    from daqr.core.qubit_allocator import DynamicQubitAllocator, ThompsonSamplingAllocator
    print("   Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator")
except ImportError:
    print("\n⚠️  qubit_allocator module not found (expected if not yet created)")
# Out:
# Now working from: notebooks
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✅ Quantum MAB Models Evaluation Framework - All components imported successfully
# 📊 Framework configuration loaded: ExperimentConfiguration
#
# ============================================================
# MODULE STATUS SUMMARY:
# ============================================================
# ✅ daqr.core.network_environment            - Loaded
# ✅ daqr.algorithms.base_bandit                    - Loaded
# ✅ daqr.algorithms.neural_bandits                 - Loaded
# ✅ daqr.algorithms.predictive_bandits             - Loaded
# ✅ daqr.evaluation.experiment_runner              - Loaded
# ✅ daqr.evaluation.multi_run_evaluator            - Loaded
# ✅ daqr.evaluation.visualizer                     - Loaded
# ✅ experiments.stochastic_evaluation          - Loaded
# ✅ daqr.config.experiment_config              - Loaded
# ============================================================
#
# 🆕 Dynamic Qubit Allocation module loaded!
#    Available allocators: DynamicQubitAllocator, ThompsonSamplingAllocator

# %% [markdown]
# ## Theoretical Foundation and Algorithm Architecture
#
# ### Algorithm Composition
#
# The **EXPNeuralUCB** algorithm integrates two complementary theoretical frameworks:
#
# - **EXP3 Component**: Exponential-weight group selection mechanism for adversarial robustness
# - **NeuralUCB Component**: Neural network-based arm selection with rigorous uncertainty quantification
#
# ### Theoretical Performance Guarantees
#
# The algorithm maintains provable regret bounds under adversarial conditions:
#
# \[
# \mathbb{E}[\text{Regret}(T)] = O\left(\sqrt{KT\log T} + \sqrt{ST\log T}\right)
# \]
#
# where:
# - \(K\): Number of available arms (quantum routing paths)
# - \(S\): Number of strategic groups (allocation strategies)
# - \(T\): Time horizon (evaluation period)
#
# ### Research Hypotheses
#
# This evaluation framework tests three primary hypotheses regarding algorithm performance and robustness:
#
# **H1: Adversarial Superiority**
# EXPNeuralUCB demonstrates measurably superior performance in adversarial environments compared to baseline neural bandit algorithms lacking adversarial robustness mechanisms.
#
# **H2: Bounded Performance Degradation**
# Performance degradation under adversarial attacks remains within acceptable bounds (< 15% relative to stochastic performance), validating the algorithm's practical applicability.
#
# **H3: Consistent Ranking Stability**
# Algorithm performance rankings remain stable across varying adversarial attack intensities, indicating reliable robustness characteristics.
#
# ### Experimental Validation Framework
#
# The theoretical predictions are empirically validated through systematic evaluation across the defined environmental categories, providing quantitative evidence for the algorithm's adversarial robustness properties while maintaining performance guarantees under standard stochastic conditions.

# %%
import sys
import os

# Add parent directory to path so notebook can find daqr
sys.path.insert(0, os.path.abspath('..'))
from daqr.config import experiment_config

importlib.reload(experiment_config)
from daqr.config.experiment_config import ExperimentConfiguration

# Initialize configuration
config = ExperimentConfiguration()

# Define models for comprehensive evaluation (expandable)
# Access model lists from config
models = config.NEURAL_MODELS  # or CONTEXTUAL_MODELS, INFORMED_CONTEXTUAL_MODELS


# Framework-specific experimental configuration
FRAMEWORK_CONFIG = {
    # Testing Configuration (lightweight for development)
    'test_mode': True,  # Set to False for final comprehensive evaluation
    'base_frames': 4000,    # Quick testing (increase to 4000+ for final runs)
    'exp_num': 3,  # Fast iteration (increase to 10+ for statistical significance)
    'frame_step': 2000,
    'models': models,
    
    # Production Configuration (for final evaluation)
    'prod_frames': 4000,     # Full evaluation frames
    'prod_experiments': 10,  # Statistical significance
    'frame_steps': [],  # Multi-horizon testing
    
    # Primary evaluation focus
    'main_env': 'stochastic',
    'eval_mod': 'comprehensive',
    'main_model': 'CEXPNeuralUCB',
    
    # Routing strategy configuration (NEW)
    'routing_strategy': 'fixed',  # 'fixed' or 'dynamic'
    'enable_routing_comparison': False,  # Enable for routing paper
    
    # Algorithm parameters (EXPNeuralUCB paper-compliant)
    'alg_attrs': {
        'lambda_reg': 1.0,      # Regularization parameter
        'gamma': 0.1,           # EXP3 exploration rate  
        'network_width': 128,   # Neural network width
        'network_depth': 2,     # Neural network depth
        'gradient_steps': 8,    # Gradient descent steps
        'learning_rate': 1e-4   # Learning rate
    },

    # Environment parameters
    'env_attrs': {
        'intensity': 0.25,  # Natural failure rate for stochastic
        'base_seed': 12345,
        'reproducible': True
    },

    # Test scenarios for different evaluation modes
    'scenarios': {
        'exp_focus': ['stochastic'],  # Primary focus
        'stochastic_vs_baseline': ['none', 'stochastic'], # Comparison
        'comprehensive': ['none', 'stochastic', 'markov', 'adaptive'], # Full evaluation
        'adversarial': ['markov', 'adaptive', 'onlineadaptive']  # Future use
    }
}

# Calculate frame steps
for exp_id in range(0, FRAMEWORK_CONFIG['exp_num']):
    FRAMEWORK_CONFIG['frame_steps'].append(
        FRAMEWORK_CONFIG['base_frames'] + (FRAMEWORK_CONFIG['frame_step'] * exp_id)
    )
FRAMEWORK_CONFIG['capacity'] = 10000 # quantum paper default capacity

# Dynamic configuration based on testing mode
attack_intensity= FRAMEWORK_CONFIG['env_attrs']['intensity']
frame_step = FRAMEWORK_CONFIG['frame_step']
current_frames = (FRAMEWORK_CONFIG['base_frames'] if FRAMEWORK_CONFIG['test_mode'] 
                  else FRAMEWORK_CONFIG['prod_frames'])
current_experiments = (FRAMEWORK_CONFIG['exp_num'] if FRAMEWORK_CONFIG['test_mode'] 
                       else FRAMEWORK_CONFIG['prod_experiments'])

# Display current configuration
print("=" * 70)
print("DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION")
print("=" * 70)
print(f"Models to evaluate: {len(models)} total")
print(f"Primary environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"Routing strategy: {FRAMEWORK_CONFIG['routing_strategy'].upper()}")

print(f"\nCURRENT SETTINGS ({'TESTING' if FRAMEWORK_CONFIG['test_mode'] else 'PRODUCTION'} MODE):")
print(f"  • Frames per run: {current_frames}")
print(f"  • Experiments per model: {current_experiments}")
print(f"  • Expected runtime: {'~2-3 minutes' if FRAMEWORK_CONFIG['test_mode'] else '~30-45 minutes'}")

print(f"\nALGORITHM PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['alg_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nENVIRONMENT PARAMETERS:")
for key, value in FRAMEWORK_CONFIG['env_attrs'].items():
    print(f"  • {key}: {value}")

print(f"\nAVAILABLE TEST SCENARIOS:")
for scenario_name, environments in FRAMEWORK_CONFIG['scenarios'].items():
    print(f"  • {scenario_name}: {environments}")

print("\n" + "=" * 70)
print("DEVELOPMENT STRATEGY:")
if FRAMEWORK_CONFIG['test_mode']:
    print("✓ TESTING MODE - Fast iteration for development and debugging")
    print("  Switch test_mode to False for final comprehensive evaluation")
else:
    print("✓ PRODUCTION MODE - Full statistical evaluation")

if FRAMEWORK_CONFIG['enable_routing_comparison']:
    print("\n✓ ROUTING COMPARISON ENABLED")
    print("  Framework will compare Fixed vs Dynamic routing strategies")
    
print("=" * 70)
print("\n✓ Configuration loaded successfully - Ready for model evaluation")
# Out:
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1598 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1501/1598 files processed
#       📊 framework_state/day_20260110: 0/1598 files skipped
#       📊 framework_state/day_20260110: 97/1598 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1501 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6039
# ================================================================================
#
# 	→ Filesystem scan found 6039 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# ======================================================================
# DYNAMIC ROUTING EVALUATION FRAMEWORK - CONFIGURATION
# ======================================================================
# Models to evaluate: 5 total
# Primary environment: STOCHASTIC
# Routing strategy: FIXED
#
# CURRENT SETTINGS (TESTING MODE):
#   • Frames per run: 4000
#   • Experiments per model: 3
#   • Expected runtime: ~2-3 minutes
#
# ALGORITHM PARAMETERS:
#   • lambda_reg: 1.0
#   • gamma: 0.1
#   • network_width: 128
#   • network_depth: 2
#   • gradient_steps: 8
#   • learning_rate: 0.0001
#
# ENVIRONMENT PARAMETERS:
#   • intensity: 0.25
#   • base_seed: 12345
#   • reproducible: True
#
# AVAILABLE TEST SCENARIOS:
#   • exp_focus: ['stochastic']
#   • stochastic_vs_baseline: ['none', 'stochastic']
#   • comprehensive: ['none', 'stochastic', 'markov', 'adaptive']
#   • adversarial: ['markov', 'adaptive', 'onlineadaptive']
#
# ======================================================================
# DEVELOPMENT STRATEGY:
# ✓ TESTING MODE - Fast iteration for development and debugging
#   Switch test_mode to False for final comprehensive evaluation
# ======================================================================
#
# ✓ Configuration loaded successfully - Ready for model evaluation

# %% [markdown]
# ## Comparative Analysis Framework: Stochastic versus Adversarial Environments
#
# ### Research Focus
#
# This evaluation constitutes the primary empirical contribution of the research: systematic quantification of algorithm performance across fundamentally different operational conditions that distinguish between natural system failures and intentional strategic attacks.
#
# ### Environmental Characterization
#
# **Stochastic Environment**
# - **Operational Model**: Natural random failures representing realistic network degradation patterns
# - **Attack Distribution**: Probabilistic failures following uniform random distribution
# - **Research Significance**: Establishes baseline performance metrics under standard operational conditions
#
# **Adversarial Environment**
# - **Operational Model**: Strategic intelligent attacks systematically targeting algorithmic decision-making processes
# - **Attack Distribution**: Adaptive targeting mechanisms that dynamically respond to observed algorithm behavior
# - **Research Significance**: Evaluates robustness under worst-case strategic threat scenarios
#
# ### Experimental Predictions
#
# Based on the theoretical analysis and algorithm architecture, the following empirical outcomes are anticipated:
#
# **Performance Superiority Hypothesis**
# EXPNeuralUCB will demonstrate measurably superior performance retention in adversarial environments relative to baseline neural bandit algorithms lacking specialized adversarial robustness mechanisms.
#
# **Bounded Degradation Hypothesis**
# Performance degradation under adversarial conditions will remain within acceptable operational limits, specifically maintaining performance within 85% of stochastic environment baselines.
#
# **Stability Hypothesis**
# Algorithm performance rankings will exhibit stability across varying adversarial attack intensities, indicating consistent robustness characteristics rather than scenario-dependent performance fluctuations.
#
# ### Research Methodology
#
# The comparative analysis employs identical experimental conditions across both environments, enabling precise quantification of performance degradation attributable to adversarial targeting while controlling for environmental variables and maintaining statistical rigor in the evaluation process.

# %%
# ============================================================
#   QUANTUM MAB – CLEAN RESET + FRESH IMPORT PIPELINE
# ============================================================
# This block:
#   ✓ Frees all global model objects
#   ✓ Clears CUDA + Python memory
#   ✓ Reloads all DAQR modules cleanly
#   ✓ Ensures any user can re-run cells safely in Colab
#
# This is the correct shared-drive-safe way to avoid
# stale state, GPU memory leaks, and broken reload logic.
# ============================================================



import subprocess

# os.chdir("/content/drive/Shareddrives/ai_quantum_computing/quantum_project")
# print("📌 Now in:", os.getcwd())
root = os.path.abspath("../..")
# Compute the absolute path of cleanup_state_duplicates.py
cleanup_script = os.path.abspath(f"{root}/cleanup_state_duplicates.py")

print(f"🚿 Running cleanup script at:\n{cleanup_script}\n")

# Execute the script exactly as-is
result = subprocess.run(
    ["python3", cleanup_script],
    text=True,
    capture_output=True
)

print("===== CLEANUP STDOUT =====")
print(result.stdout)

print("===== CLEANUP STDERR =====")
print(result.stderr)

print("🚿 Cleanup finished.")


# ============================================================
# STEP 1 — FULL CLEANUP
# ============================================================
import gc
import torch

def deep_cleanup():
    """
    Remove all instantiated model/evaluator objects from global scope
    and fully clear CPU/GPU memory.
    """
    to_clear = [
        "oracle", "gneuralucb", "expneuralucb",
        "cpursuitneuralucb", "icpursuitneuralucb",
        "evaluator", "results"
    ]

    for name in to_clear:
        if name in globals():
            obj = globals().get(name, None)
            # If a cleanup() method exists, call it
            try:
                if hasattr(obj, "cleanup"):
                    obj.cleanup(verbose=False)
            except:
                pass
            # Remove the variable
            globals().pop(name, None)

    # GPU cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Force Python garbage collector
    gc.collect()

    # Reset default dtype to ensure numerical stability
    torch.set_default_dtype(torch.float32)

    print("✓ Deep cleanup complete (memory cleared)")


deep_cleanup()


# ============================================================
# STEP 2 — CLEAN MODULE RELOAD
# ============================================================
import sys
import os
import importlib

# Ensure daqr package is discoverable
PARENT_DIR = os.path.abspath("..")
if PARENT_DIR not in sys.path:
    sys.path.insert(0, PARENT_DIR)

# ------------------------------------------------------------
# Import DAQR modules
# ------------------------------------------------------------
from daqr.config import experiment_config, gd_backup_manager, local_backup_manager
from daqr.core import network_environment, qubit_allocator
from daqr.algorithms import neural_bandits, predictive_bandits, base_bandit
from daqr.evaluation import multi_run_evaluator, visualizer, experiment_runner

# ------------------------------------------------------------
# Reload modules to ensure a clean environment
# ------------------------------------------------------------
importlib.reload(experiment_config)
importlib.reload(network_environment)
importlib.reload(qubit_allocator)
importlib.reload(base_bandit)
importlib.reload(neural_bandits)
importlib.reload(predictive_bandits)
importlib.reload(experiment_runner)
importlib.reload(multi_run_evaluator)
importlib.reload(visualizer)

# ------------------------------------------------------------
# Import specific classes after reloads
# ------------------------------------------------------------
from daqr.config.gd_backup_manager import GoogleDriveBackupManager
from daqr.config.experiment_config import ExperimentConfiguration
from daqr.config.local_backup_manager import LocalBackupManager
from daqr.core.network_environment import *
from daqr.core.qubit_allocator import *
from daqr.algorithms.base_bandit import *
from daqr.algorithms.neural_bandits import *
from daqr.algorithms.predictive_bandits import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.evaluation.experiment_runner import *
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("✓ All modules reloaded successfully (fresh environment ready)")
# Out:
# 🚿 Running cleanup script at:
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py
#
# ===== CLEANUP STDOUT =====
# Script dir: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework
# Project root: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework
#
# State roots:
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
#   ✅ /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#   ❌ /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# ========== STARTING CLEANUP ==========
#
# [CLEANUP] Removing .0 float artifacts from filenames...
# [✓] Float artifacts fixed: 0
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: removed 0 duplicates
#
# --- Cleaning: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ---
# [CLEAN] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [✓] /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: removed 0 duplicates
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
#
# --- Cleaning: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state ---
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state: moved 0 files, removed 0 directories.
#
#
# ========== CONSOLIDATION: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state ==========
# Target date directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
# [✓] Consolidation finished for /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state: moved 0 files, removed 0 directories.
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/framework_state
# [SKIP] Missing path → /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/model_state
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/local_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 6147 corrected, 0 added
#
# [UPDATE] Updating registry: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/drive_backup_registry.json
# [DEBUG] State roots passed in:
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state  (exists=True)
#         - /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state  (exists=True)
#
# [DEBUG] COMPONENT: framework_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/Icon
#
# [DEBUG] COMPONENT: model_state
#         root = /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/.DS_Store
# [SKIP]     Not a directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/Icon
# [✓] Registry updated: 6147 corrected, 0 added
# [INFO] Registry not found, skipping update: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake/backup_registry.json
#
# ========== DONE ==========
#
#
# ===== CLEANUP STDERR =====
# /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/cleanup_state_duplicates.py:1338: SyntaxWarning: invalid escape sequence '\('
#   "scenario_cat": re.split("\(|\)", scenario_cat)[-2],
#
# 🚿 Cleanup finished.
# ✓ Deep cleanup complete (memory cleared)
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# PyTorch version: 2.8.0
# NumPy version: 1.26.4
# Using device: cpu
# ✓ All modules reloaded successfully (fresh environment ready)

# %%
# Define evaluation scenarios based on framework focus
if FRAMEWORK_CONFIG['main_env'] == 'stochastic':
    # Primary stochastic evaluation with optional comparison
    test_scenarios = {
        'stochastic': 'Stochastic Random Failures',
        'markov': 'Markov Adversarial Attack',
        'adaptive': 'Adaptive Adversarial Attack',
        'onlineadaptive': 'Online Adaptive Attack',
        'none': 'Baseline (Optimal Conditions)'  # For comparison
    }
    evaluation_type = "STOCHASTIC-FOCUSED"
else:
    # Fallback to stochastic vs adversarial for comparison
    test_scenarios = {
        'stochastic': 'Stochastic (Natural Network Failures)', 
        'adaptive': 'Adversarial (Strategic Attacks)'
    }
    evaluation_type = "COMPARATIVE"

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration

# Create allocator with correct parameters
allocator = ThompsonSamplingAllocator(
    num_routes=4,              # Number of routes
    total_qubits=35,           # Total qubits available (8+10+8+9=35)
    min_qubits_per_route=2     # Minimum qubits per route
)

allocator = DynamicQubitAllocator(              # ← Change class name
    num_routes=4,        
    total_qubits=35,                 
    exploration_bonus=2.0,      # ← NEW parameter (optional, default is 2.0)
    min_qubits_per_route=2
)

# Fully random (exploration only)
allocator = RandomQubitAllocator(epsilon=1.0, seed=42)

# models = ['Oracle', 'GNeuralUCB', 'EXPNeuralUCB']
# allocator = None

print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

current_experiments = 3 # overwrite number of experiments
last_backup = True
overwrite = False
base_cap = True

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=base_cap, overwrite=overwrite) 
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1598 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1501/1598 files processed
#       📊 framework_state/day_20260110: 0/1598 files skipped
#       📊 framework_state/day_20260110: 97/1598 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1501 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6039
# ================================================================================
#
# 	→ Filesystem scan found 6039 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Random Dynamic Allocation (Initial): (9, 4, 20, 2)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_8000-Random_All_All-4000_2000_3_S2Tb.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        8000
#   • allocator_id:  Random
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       3
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/3 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_8000-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_8000-Random_All_All-4000_2000_3_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(base)_8000-Random_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/3 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_8000-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_8000-Random_All_All-4000_2000_3_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(base)_8000-Random_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-6000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-6000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-6000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-6000.pkl
#     - Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(base)_8000-Random_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-6000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-6000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-6000.pkl
#     - Oracle(base)_8000-Random_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-6000.pkl
#     - Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/3 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_8000-Random_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_8000-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_8000-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_8000-Random_All_All-4000_2000_3_S2Tb.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_8000-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_8000-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_8000-Random_Stochastic_No-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Stochastic_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Stochastic_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Stochastic_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Stochastic_OnlineAdaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Adversarial_No-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Adversarial_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Adversarial_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Adversarial_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_8000-Random_Adversarial_OnlineAdaptive-8000_3.pkl
#
#   • Model keys: 150
#     - Oracle(base)_8000-Random_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_No-4000.pkl
#     - Oracle(base)_8000-Random_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_8000-Random_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_8000-Random_Stochastic_Random-4000.pkl
# ...
# [RandomAllocator ε=1.000] timestep=2 mode=random → allocation=(4, 5, 11, 15)
# 🔧 Allocated qubits for NONE Exp 3: (4, 5, 11, 15)
# 🔄 Random Dynamic Allocation (Initial): (17, 2, 4, 12)
# ======================================================================================================================================================
#
# BASELINE (NONE) (NO) EXP 3: Env:Baseline (None), Attack:No, Rate:0.0, Frames:8000, QubitAlloc=Random, SC:8000 (Scale=2 x Cap=4000), Seed: 20840
# ======================================================================================================================================================
#
# 	🔄 Resume: QuantumExperimentRunner_3
#
# 	⚡ Random QuantumExperimentRunner detected → scanning registry for substitute
# 	  🔍 Found 5 matching candidates
# 	    - (11_5_4_15): 3,751,575 bytes
# 	    - (10_12_7_6): 3,727,201 bytes
# 	    - (6_7_12_10): 3,751,575 bytes
# 	    - (3_3_3_26): 3,751,574 bytes
# 	    - (6_17_4_8): 5,743,257 bytes
# 	  ✅ Selected LARGEST: (6_17_4_8) (5,743,257 bytes)
#
# 	⚡ Random QuantumExperimentRunner detected → scanning registry for substitute
# 	  🔍 Found 5 matching candidates
# 	    - (11_5_4_15): 3,751,575 bytes
# 	    - (10_12_7_6): 3,727,201 bytes
# 	    - (6_7_12_10): 3,751,575 bytes
# 	    - (3_3_3_26): 3,751,574 bytes
# 	    - (6_17_4_8): 5,743,257 bytes
# 	  ✅ Selected LARGEST: (6_17_4_8) (5,743,257 bytes)
# 	✓ QuantumExperimentRunner_3 Path validated: '/Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110/QuantumExperimentRunner_3_8000-Random_Baseline (None)_No-8000_3_(6_17_4_8).pkl'
# 	   Loading from: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110/QuantumExperimentRunner_3_8000-Random_Baseline (None)_No-8000_3_(6_17_4_8).pkl
# 	   File exists: True, size: 5743257
# ⏩ SKIPPING EXPERIMENT 3: ALREADY COMPLETED AND STORED
#
# 	📊 EXPERIMENT RESULTS SUMMARY
# 	========================================================================================================================
# 	EXP 3 GNEURALUCB          : Reward=7557.03, Efficiency=098.8% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.582]
# 	EXP 3 EXPNEURALUCB        : Reward=7071.93, Efficiency=092.5% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.628]
# 	EXP 3 CPURSUITNEURALUCB   : Reward=7580.54, Efficiency=099.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.634]
# 	EXP 3 ICPURSUITNEURALUCB  : Reward=7577.27, Efficiency=099.1% [Retries=0, Failed=0, < Threshold=0, SCapacity=8000, Threshold=0.712]
# 	========================================================================================================================
# 	-->🏆 EXP3 Winner:CPursuitNeuralUCB   (Gap:000.9%) [Env:Baseline (None), Attack:No X Rate:0.25, Frames:8000, SCapacity=8000, Alloc=Random]
#
# Total experiment time: 192.6s
# Experiments completed for none
# ✓ Scenario 'stochastic' evaluation completed.
# ✓ Scenario 'markov' evaluation completed.
# ✓ Scenario 'adaptive' evaluation completed.
# ✓ Scenario 'onlineadaptive' evaluation completed.
# ✓ Scenario 'none' evaluation completed.
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5121.64
# 	• Winner Avg Gap: 0013.97%
# 	• Winner Avg Reward: 4627.69
# 	• Winner Avg Efficiency: 0086.03%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.0%
# 	Winner Avg Efficiency: 	086.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	086.0% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	083.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4916.21
# 	• Winner Avg Gap: 0035.83%
# 	• Winner Avg Reward: 2992.51
# 	• Winner Avg Efficiency: 0064.17%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	035.8%
# 	Winner Avg Efficiency: 	064.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	064.2% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	039.3% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 4857.13
# 	• Winner Avg Gap: 0025.45%
# 	• Winner Avg Reward: 3877.40
# 	• Winner Avg Efficiency: 0074.55%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 0/3 experiments)
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4575.12
# 	• Winner Avg Gap: 0024.11%
# 	• Winner Avg Reward: 3534.45
# 	• Winner Avg Efficiency: 0075.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5119.47
# 	• Winner Avg Gap: 0006.19%
# 	• Winner Avg Reward: 4856.37
# 	• Winner Avg Efficiency: 0093.81%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (iCPursuitNeuralUCB):
# 	• Stochastic Performance:    	4627.694
# 	• Baseline Performance:      	4856.365
# 	• Performance Retention:     	095.3%
# 	EXCELLENT:          	Minimal performance loss under realistic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5121.64
# 	• Winner Avg Gap: 0013.97%
# 	• Winner Avg Reward: 4627.69
# 	• Winner Avg Efficiency: 0086.03%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.0%
# 	Winner Avg Efficiency: 	086.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	086.0% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	083.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4916.21
# 	• Winner Avg Gap: 0035.83%
# 	• Winner Avg Reward: 2992.51
# 	• Winner Avg Efficiency: 0064.17%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	035.8%
# 	Winner Avg Efficiency: 	064.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	064.2% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	039.3% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 4857.13
# 	• Winner Avg Gap: 0025.45%
# 	• Winner Avg Reward: 3877.40
# 	• Winner Avg Efficiency: 0074.55%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 0/3 experiments)
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4575.12
# 	• Winner Avg Gap: 0024.11%
# 	• Winner Avg Reward: 3534.45
# 	• Winner Avg Efficiency: 0075.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5119.47
# 	• Winner Avg Gap: 0006.19%
# 	• Winner Avg Reward: 4856.37
# 	• Winner Avg Efficiency: 0093.81%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]

# %%
# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()

# %%
# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_comparison_20260110_063614.png
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.0%
# 	Winner Avg Efficiency: 	086.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	086.0% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	083.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_20260110_063614.png
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	035.8%
# 	Winner Avg Efficiency: 	064.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	064.2% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	039.3% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_markov_vs_baseline_20260110_063614.png
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 0/3 experiments)
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_adaptive_vs_baseline_20260110_063614.png
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_onlineadaptive_vs_baseline_20260110_063614.png
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_none_vs_baseline_20260110_063614.png
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5121.642
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3013.408
#   • Oracle Efficiency: 59.4%
#   • Oracle Gap: 40.6%
#   • Classification: NEEDS IMPROVEMENT
#
# EXPNeuralUCB:
#   • Stochastic Performance: 4488.945
#   • Oracle Efficiency: 83.0%
#   • Oracle Gap: 17.0%
#   • Classification: GOOD
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 4610.757
#   • Oracle Efficiency: 85.6%
#   • Oracle Gap: 14.4%
#   • Classification: GOOD
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 4627.694
#   • Oracle Efficiency: 86.0%
#   • Oracle Gap: 14.0%
#   • Classification: GOOD
#   ★ WINNER ★
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration


print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=1.5, base_capacity=base_cap, overwrite=overwrite)
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()


# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS
# ======================================================================
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ===================== BUILD LOCAL REGISTRY =====================
#
# ================================================================================
# 🔍 SCANNING LOCAL FILES
# ================================================================================
# Parameters: load_to_drive=False, force=False
#
# 📂 Checking DRIVE mode: /content/drive/Shareddrives/ai_quantum_computing/quantum_data_lake
#    ⚠️  Path does not exist, skipping
#
# 📂 Checking LOCAL mode: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#    ✅ Path exists, starting walk...
#    🚶 Walking directory tree: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/framework_state/day_20260110
#       Relative: framework_state/day_20260110
#       Component: framework_state
#       Date: day_20260110
#       📄 Processing 1598 files in framework_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Baseline (None)_No-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Default_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_200-Default_All_All-100_100_1_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_OnlineAdaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-ThompsonSampling_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_1_4000-Dynamic_Stochastic_Random-4000_1pkl
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_8_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Stochastic_Random-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Markov-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_3_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_8_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_3_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_10_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_8_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_8_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_5_S1Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Dynamic_All_All-4000_2000_5_S2Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Random_All_All-4000_2000_3_(18_9_6_2)_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_100-Dynamic_All_All-50_50_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): QuantumExperimentRunner_2_6000-Default_Adversarial_Adaptive-6000_2.pkl 2
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-ThompsonSampling_All_All-4000_2000_8_S1Tb.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_5_S1_5T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_3_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-ThompsonSampling_All_All-4000_2000_10_S2T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Dynamic_All_All-4000_2000_10_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1Tb_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_5_S1_5T_iCMABs2.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_4000-Default_All_All-4000_2000_3_S1T.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Default_All_All-4000_2000_3_S1_5T_EXP3.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_8000-Default_All_All-4000_2000_5_S2Tb_iCMABs.csv
#          ⊘ Skip (invalid ext): MultiRunEvaluator_6000-Dynamic_All_All-4000_2000_3_S1_5T.csv
#       📊 framework_state/day_20260110: 1501/1598 files processed
#       📊 framework_state/day_20260110: 0/1598 files skipped
#       📊 framework_state/day_20260110: 97/1598 files conflicted
#
#    📁 Directory: /Users/pitergarcia/DataScience/Semester4/GA-Work/hybrid_variable_framework/Dynamic_Routing_Eval_Framework/daqr/config/model_state/day_20260110
#       Relative: model_state/day_20260110
#       Component: model_state
#       Date: day_20260110
#       📄 Processing 4549 files in model_state/day_20260110
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_24000-Default_Stochastic_Random-12000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_8000-Random_Adversarial_OnlineAdaptive-8000)_(15_14_4_2).pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_2(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_1(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_56000-Dynamic-14000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_0(neural)_24000-Dynamic-6000.pkl 2
#          ⊘ Skip (invalid ext): CPursuitNeuralUCB(neural)_20000-Default_Stochastic_Random-10000.pkl 2
#          ⊘ Skip (invalid ext): NeuralUCB_3(neural)_24000-Dynamic-6000.pkl 2
#       📊 model_state/day_20260110: 4538/4549 files processed
#       📊 model_state/day_20260110: 0/4549 files skipped
#       📊 model_state/day_20260110: 11/4549 files conflicted
#
#    📊 Processed 2 directories
#
# ================================================================================
# 📦 BUILDING FINAL REGISTRY
# ================================================================================
# Components found: ['framework_state', 'model_state']
#   • framework_state: 1501 files
#   • model_state: 4538 files
#
# ✅ SCAN COMPLETE
# Modes scanned: 1
# Total files in registry: 6039
# ================================================================================
#
# 	→ Filesystem scan found 6039 files
#
# ===================== GET DRIVE REGISTRY =====================
# ===================== REGISTRY BUILD COMPLETE =====================
#
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# BUILDING REGISTRY WITH 0 EXPECTED COMPONENTS KEYS
#
# ===================== GET LOCAL REGISTRY =====================
# → Skipping local cache (force=True or file missing)
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# 	📦 LocalBackupManager Registry Saved Locally in LOCAL
# 🔄 Random Dynamic Allocation (Initial): (7, 3, 19, 6)
#
# 	🔄 Resume: MultiRunEvaluator
#
# =====================================================
# 🔍 GENERATING EXPECTED KEYS FROM EVALUATOR
# =====================================================
#   • Evaluator filename: MultiRunEvaluator_6000-Random_All_All-4000_2000_3_S1_5Tb.pkl
#
# 🧩 PARSED COMPONENTS
#   • cap_id:        6000
#   • allocator_id:  Random
#   • env_id:        All
#   • attack_id:     All
#   • base_frames:   4000
#   • frame_step:    2000
#   • runs_id:       3
#
# =====================================================
# 🧪 GENERATING KEYS FOR EACH RUN
# =====================================================
#
# --- Run 1/3 -----------------------
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_No-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Markov-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_No-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_No-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_Random-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_Markov-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Markov-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_Adaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#   • Frame number: 4000
#   → Runner key: QuantumExperimentRunner_1_6000.0-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 11
#     - MultiRunEvaluator_6000-Random_All_All-4000_2000_3_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#
#   • Model keys: 50
#     - Oracle(base)_6000.0-Random_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#
# --- Run 2/3 -----------------------
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_No-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Markov-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_No-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_No-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_Random-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_Markov-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Markov-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_Adaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#   • Frame number: 6000
#   → Runner key: QuantumExperimentRunner_2_6000.0-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 21
#     - MultiRunEvaluator_6000-Random_All_All-4000_2000_3_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#
#   • Model keys: 100
#     - Oracle(base)_6000.0-Random_Stochastic_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_No-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Random-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-4000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_No-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-6000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Random-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-6000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Markov-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-6000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-6000.pkl
#     - Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-6000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_No-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-6000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Random-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-6000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Markov-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-6000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-6000.pkl
#     - Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#     - iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-6000.pkl
#
# --- Run 3/3 -----------------------
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_No-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Markov-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Stochastic_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Stochastic_OnlineAdaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_No-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_No-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_No-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_No-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_No-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_Random-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Random-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Random-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Random-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_Markov-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Markov-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Markov-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Markov-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_Adaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_Adaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_Adaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_Adaptive-8000.pkl
#   • Frame number: 8000
#   → Runner key: QuantumExperimentRunner_3_6000.0-Random_Adversarial_OnlineAdaptive-8000_3.pkl
#   • Generating model keys:
#     → Oracle(base)_6000.0-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → GNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → EXPNeuralUCB(hybrid)_6000.0-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → CPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-8000.pkl
#     → iCPursuitNeuralUCB(neural)_6000.0-Random_Adversarial_OnlineAdaptive-8000.pkl
#
# =====================================================
# 📦 FINAL EXPECTED KEYS
# =====================================================
#   • Runner keys: 31
#     - MultiRunEvaluator_6000-Random_All_All-4000_2000_3_S1_5Tb.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Stochastic_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_No-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Random-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Markov-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_Adaptive-4000_1.pkl
#     - QuantumExperimentRunner_1_6000.0-Random_Adversarial_OnlineAdaptive-4000_1.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Stochastic_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_No-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Random-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Markov-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_Adaptive-6000_2.pkl
#     - QuantumExperimentRunner_2_6000.0-Random_Adversarial_OnlineAdaptive-6000_2.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Stochastic_No-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Stochastic_Random-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Stochastic_Markov-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Stochastic_Adaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Stochastic_OnlineAdaptive-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Adversarial_No-8000_3.pkl
#     - QuantumExperimentRunner_3_6000.0-Random_Adversarial_Random-8000_3.pkl
# ...
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4575.12
# 	• Winner Avg Gap: 0024.11%
# 	• Winner Avg Reward: 3534.45
# 	• Winner Avg Efficiency: 0075.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5119.47
# 	• Winner Avg Gap: 0006.19%
# 	• Winner Avg Reward: 4856.37
# 	• Winner Avg Efficiency: 0093.81%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# KEY INSIGHTS:
# Best Performing Model Analysis (iCPursuitNeuralUCB):
# 	• Stochastic Performance:    	4627.694
# 	• Baseline Performance:      	4856.365
# 	• Performance Retention:     	095.3%
# 	EXCELLENT:          	Minimal performance loss under realistic conditions
# Statistical Analysis:
# 	• Total models evaluated:     	5
# 	• Experiments per environment:	3
# 	• Quantum network simulation: 	Comprehensive stochastic modeling
# ======================================================================
#
# ======================================================================
# COMPREHENSIVE SCENARIO PERFORMANCE ANALYSIS
# ======================================================================
# SCENARIO: STOCHASTIC
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5121.64
# 	• Winner Avg Gap: 0013.97%
# 	• Winner Avg Reward: 4627.69
# 	• Winner Avg Efficiency: 0086.03%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.0%
# 	Winner Avg Efficiency: 	086.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	086.0% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	083.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: MARKOV
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4916.21
# 	• Winner Avg Gap: 0035.83%
# 	• Winner Avg Reward: 2992.51
# 	• Winner Avg Efficiency: 0064.17%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 1 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	035.8%
# 	Winner Avg Efficiency: 	064.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	064.2% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	039.3% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# SCENARIO: ADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: CPursuitNeuralUCB
# 	• Oracle Avg Reward: 4857.13
# 	• Winner Avg Gap: 0025.45%
# 	• Winner Avg Reward: 3877.40
# 	• Winner Avg Efficiency: 0074.55%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 2 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 0 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 0/3 experiments)
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# SCENARIO: ONLINEADAPTIVE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 4575.12
# 	• Winner Avg Gap: 0024.11%
# 	• Winner Avg Reward: 3534.45
# 	• Winner Avg Efficiency: 0075.89%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 0 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 2 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# SCENARIO: NONE
# 	• Total Experiments: 3
# 	• Overall Winner: iCPursuitNeuralUCB
# 	• Oracle Avg Reward: 5119.47
# 	• Winner Avg Gap: 0006.19%
# 	• Winner Avg Reward: 4856.37
# 	• Winner Avg Efficiency: 0093.81%
# 	• Win Counts:
# 		- Oracle: 0 wins
# 		- GNeuralUCB: 0 wins
# 		- EXPNeuralUCB: 1 wins
# 		- CPursuitNeuralUCB: 1 wins
# 		- iCPursuitNeuralUCB: 1 wins
# ----------------------------------------------------------------------
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
#
# ✓ Quantum MAB Models Evaluation Framework - STOCHASTIC-FOCUSED evaluation completed!
#
# ==================== FETCH FROM DRIVE START ====================
# → Looking for 'backup_registry.json' in Drive folder: 0APT9hcMpvuHYUk9PVA
# → No registry file found in Drive
# ==================== FETCH FROM DRIVE END =====================
#
# [Logging Redirect Stopped]
# ======================================================================
# ROBUSTNESS ANALYSIS
# ======================================================================
# Comparison Results Summary:
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_comparison_20260110_070822.png
#
# 📊 Generating plots for scenario: STOCHASTIC
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: STOCHASTIC
# ======================================================================
# SCENARIO: 	STOCHASTIC RANDOM FAILURES
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	014.0%
# 	Winner Avg Efficiency: 	086.0%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	086.0% Efficiency 	(Won 2/3 experiments)
# 	• CPursuitNeuralUCB: 	085.6% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	083.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	059.4% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'stochastic' evaluation completed.
# Creating  stochastic vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_stochastic_vs_baseline_20260110_070822.png
#
# 📊 Generating plots for scenario: MARKOV
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: MARKOV
# ======================================================================
# SCENARIO: 	MARKOV ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	035.8%
# 	Winner Avg Efficiency: 	064.2%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	064.2% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	056.4% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	039.3% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	034.2% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'markov' evaluation completed.
# Creating  markov vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_markov_vs_baseline_20260110_070822.png
#
# 📊 Generating plots for scenario: ADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ADAPTIVE
# ======================================================================
# SCENARIO: 	ADAPTIVE ADVERSARIAL ATTACK
# ----------------------------------------
# Recommended Model: 	CPursuitNeuralUCB (Won 0/3 experiments)
# 	Winner Avg Gap: 	025.5%
# 	Winner Avg Efficiency: 	074.5%
#
# Overall Models Performance:
# 	• CPursuitNeuralUCB: 	074.5% Efficiency 	(Won 0/3 experiments)
# 	• iCPursuitNeuralUCB: 	073.7% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	066.0% Efficiency 	(Won 0/3 experiments)
# 	• GNeuralUCB     : 	062.8% Efficiency 	(Won 2/3 experiments)
# ======================================================================
# ✓ Scenario 'adaptive' evaluation completed.
# Creating  adaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_adaptive_vs_baseline_20260110_070822.png
#
# 📊 Generating plots for scenario: ONLINEADAPTIVE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: ONLINEADAPTIVE
# ======================================================================
# SCENARIO: 	ONLINE ADAPTIVE ATTACK
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 2/3 experiments)
# 	Winner Avg Gap: 	024.1%
# 	Winner Avg Efficiency: 	075.9%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	075.9% Efficiency 	(Won 2/3 experiments)
# 	• GNeuralUCB     : 	073.5% Efficiency 	(Won 0/3 experiments)
# 	• EXPNeuralUCB   : 	067.4% Efficiency 	(Won 0/3 experiments)
# 	• CPursuitNeuralUCB: 	062.5% Efficiency 	(Won 1/3 experiments)
# ======================================================================
# ✓ Scenario 'onlineadaptive' evaluation completed.
# Creating  onlineadaptive vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_onlineadaptive_vs_baseline_20260110_070822.png
#
# 📊 Generating plots for scenario: NONE
#
# ======================================================================
# DETAILED SCENARIO PERFORMANCE: NONE
# ======================================================================
# SCENARIO: 	BASELINE (OPTIMAL CONDITIONS)
# ----------------------------------------
# Recommended Model: 	iCPursuitNeuralUCB (Won 1/3 experiments)
# 	Winner Avg Gap: 	006.2%
# 	Winner Avg Efficiency: 	093.8%
#
# Overall Models Performance:
# 	• iCPursuitNeuralUCB: 	093.8% Efficiency 	(Won 1/3 experiments)
# 	• CPursuitNeuralUCB: 	093.3% Efficiency 	(Won 1/3 experiments)
# 	• EXPNeuralUCB   : 	091.3% Efficiency 	(Won 1/3 experiments)
# 	• GNeuralUCB     : 	073.0% Efficiency 	(Won 0/3 experiments)
# ======================================================================
# ✓ Scenario 'none' evaluation completed.
# Creating  none vs basline comparison visualization...
# ✓ Comparison plot saved as: Random_none_vs_baseline_20260110_070822.png
#
#  All scenario plots generated!
#
# ✓ Stochastic Analysis Generated:
#   → quantum_mab_models_stochastic_evaluation.png
#
# ======================================================================
# STOCHASTIC PERFORMANCE METRICS
# ======================================================================
#
# Oracle:
#   • Stochastic Performance: 5121.642
#   • Oracle Efficiency: 0.0%
#   • Oracle Gap: 0.0%
#   • Classification: NEEDS IMPROVEMENT
#
# GNeuralUCB:
#   • Stochastic Performance: 3013.408
#   • Oracle Efficiency: 59.4%
#   • Oracle Gap: 40.6%
#   • Classification: NEEDS IMPROVEMENT
#
# EXPNeuralUCB:
#   • Stochastic Performance: 4488.945
#   • Oracle Efficiency: 83.0%
#   • Oracle Gap: 17.0%
#   • Classification: GOOD
#
# CPursuitNeuralUCB:
#   • Stochastic Performance: 4610.757
#   • Oracle Efficiency: 85.6%
#   • Oracle Gap: 14.4%
#   • Classification: GOOD
#
# iCPursuitNeuralUCB:
#   • Stochastic Performance: 4627.694
#   • Oracle Efficiency: 86.0%
#   • Oracle Gap: 14.0%
#   • Classification: GOOD
#   ★ WINNER ★
#
# ======================================================================
# STOCHASTIC ENVIRONMENT INSIGHTS
# ======================================================================
#   • Natural quantum decoherence and network failures
#   • Performance metrics validate theoretical predictions
#   • Baseline for future adversarial robustness studies

# %%
importlib.reload(qubit_allocator)
importlib.reload(experiment_config)
importlib.reload(multi_run_evaluator)

from daqr.core.qubit_allocator import *
from daqr.evaluation.multi_run_evaluator import *
from daqr.config.experiment_config import ExperimentConfiguration


print("=" * 70)
print("QUANTUM MAB MODELS EVALUATION FRAMEWORK - STOCHASTIC FOCUS")
print("=" * 70)

# Create config with allocator
custom_config = ExperimentConfiguration(
    runs=current_experiments, allocator=allocator, 
    env_type=FRAMEWORK_CONFIG['main_env'], scenarios=test_scenarios, use_last_backup=last_backup,
    models=models, attack_intensity=attack_intensity, scale=2, base_capacity=base_cap, overwrite=overwrite)
evaluator = MultiRunEvaluator(configs=custom_config, base_frames=current_frames, frame_step=frame_step)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# -----------------------------
# START LOGGING (UNIQUE NAME)
# -----------------------------
evaluator.configs.set_log_name(base_frames=current_frames, frame_step=frame_step)
evaluator.configs.backup_mgr.init_logging_redirect(evaluator)

# @title Quantum MAB Models Stochastic Evaluation - Primary Framework Execution
print("\n✓ Framework Configuration:")
print(f"  • Primary Environment: {FRAMEWORK_CONFIG['main_env'].upper()}")
print(f"  • Evaluation Mode: {FRAMEWORK_CONFIG['eval_mod'].upper()}")
print(f"  • Models to Test: {len(models)}")
print("=" * 70)

print(f"\n▶ Executing {evaluation_type.upper()} EVALUATION:")
for scenario, description in test_scenarios.items():
    print(f"  • {scenario.upper():<20} {description}")
print("=" * 70)

# Execute framework evaluation
try:
    print("\n⚙ Running Quantum MAB Models Evaluation...")
    comparison_results = evaluator.test_stochastic_environment(cal_winner=True, parellel=False)
    evaluator.calculate_scenarios_performance()
    last_exp_comparison_results = evaluator.get_evaluation_results(FRAMEWORK_CONFIG['main_env'])
    print(f"\n✓ Quantum MAB Models Evaluation Framework - {evaluation_type.upper()} evaluation completed!")
    
except Exception as e:
    print(f"\n❌ Evaluation error: {e}")
    print("⚠ This may indicate missing framework components or configuration issues")
    import traceback
    traceback.print_exc()
    
finally:
    # ------------------------------------
    # ALWAYS STOP LOGGING CLEANLY
    # ------------------------------------
    evaluator.configs.backup_mgr.load_new_entries()
    evaluator.configs.backup_mgr.stop_logging_redirect()


# @title Robustness Analysis and Quantification
import importlib
# from daqr.evaluation import visualizer

importlib.reload(visualizer)
from daqr.evaluation.visualizer import QuantumEvaluatorVisualizer

print("=" * 70)
print("ROBUSTNESS ANALYSIS")
print("=" * 70)

try:
    # Pretty print comparison results
    import pprint
    print("Comparison Results Summary:")
    # pprint.pprint(comparison_results)

    # Full comparison plot (all scenarios together)
    viz = QuantumEvaluatorVisualizer(comparison_results, allocator=allocator, config=custom_config)
    viz.plot_stochastic_vs_adversarial_comparison()

    # Get list of all scenarios
    scenario_list = list(test_scenarios.keys())

    # Plot each scenario individually
    for scenario in scenario_list:
        if scenario.lower() == 'stochastic': pass
        print(f"\n📊 Generating plots for scenario: {scenario.upper()}")
        evaluator.calculate_scenario_performance(scenario=scenario)

        # Get ALL results for this scenario (all experiments)
        all_scenario_results = evaluator.get_evaluation_results(scenario=scenario)
        
        # Just pass the scenario name - method auto-detects and plots it
        viz.plot_scenarios_comparison(scenario=scenario)
        
        # # Also plot just the last experiment
        # if len(all_scenario_results[scenario].keys()) > 1:
        #     last_scenario_results = evaluator.get_evaluation_results(scenario=scenario,exp_id=-1)
        #     if last_scenario_results: viz.plot_scenarios_comparison(last_scenario_results)

    print("\n All scenario plots generated!")

    
    print("\n✓ Stochastic Analysis Generated:")
    print("  → quantum_mab_models_stochastic_evaluation.png")
    
    # Use viz.get_viz_data() to access pre-computed averaged results
    stoch_data = viz.get_viz_data(f'stochastic_data')
    
    if stoch_data and 'averaged' in stoch_data:
        stoch_results = stoch_data['averaged']
        
        print("\n" + "=" * 70)
        print("STOCHASTIC PERFORMANCE METRICS")
        print("=" * 70)
        
        oracle_reward = stoch_results.get('oracle_reward', 1)
        winner = stoch_results.get('winner', 'N/A')
        
        for alg in models:
            if alg in stoch_results['results']:
                model_data = stoch_results['results'][alg]
                
                # Use PRE-COMPUTED metrics
                stoch_reward = model_data.get('final_reward', 0)
                efficiency = model_data.get('efficiency', 0)
                gap = model_data.get('gap', float('inf'))
                
                print(f"\n{alg}:")
                print(f"  • Stochastic Performance: {stoch_reward:.3f}")
                print(f"  • Oracle Efficiency: {efficiency:.1f}%")
                print(f"  • Oracle Gap: {gap:.1f}%")
                
                if efficiency > 90:     classification = "EXCELLENT"
                elif efficiency > 80:   classification = "GOOD"
                elif efficiency > 70:   classification = "MODERATE"
                else:                   classification = "NEEDS IMPROVEMENT"
                
                print(f"  • Classification: {classification}")
                
                if alg == winner:
                    print(f"  ★ WINNER ★")
        
        print("\n" + "=" * 70)
        print("STOCHASTIC ENVIRONMENT INSIGHTS")
        print("=" * 70)
        print("  • Natural quantum decoherence and network failures")
        print("  • Performance metrics validate theoretical predictions")
        print("  • Baseline for future adversarial robustness studies")
    else:
        print("⚠ No stochastic averaged results available")

except Exception as e:
    print(f"❌ Error in robustness analysis: {e}")
    import traceback
    traceback.print_exc()

# %% [markdown]
# ## Multi-Environment Performance Analysis
#
# ### Complete Evaluation Matrix
#
# This research extends beyond the primary stochastic-adversarial comparison to provide comprehensive algorithm assessment across the complete spectrum of operational environments, establishing a thorough empirical foundation for robustness evaluation.
#
# ### Environmental Test Framework
#
# | Environment | Classification | Threat Characteristics | Analytical Purpose |
# |-------------|---------------|----------------------|-------------------|
# | `none` | Baseline | Deterministic optimal conditions | Theoretical performance ceiling |
# | `stochastic` | Probabilistic | Uniform random failures | Standard operational baseline |
# | `markov` | Adversarial | Memory-dependent strategic attacks | Oblivious adversarial model |
# | `adaptive` | Adversarial | Feedback-driven strategic attacks | Responsive adversarial model |
# | `onlineadaptive` | Adversarial | Real-time adaptive strategic attacks | Sophisticated adversarial model |
#
# ### Research Contributions
#
# **Comprehensive Threat Model Coverage**
# The evaluation framework addresses the complete spectrum of operational conditions, from optimal deterministic environments through increasingly sophisticated adversarial scenarios, providing unprecedented coverage of realistic deployment conditions.
#
# **Graduated Adversarial Complexity Analysis**
# The systematic progression from oblivious to sophisticated adversarial models enables precise quantification of algorithm performance degradation as threat sophistication increases, revealing critical robustness thresholds.
#
# **Cross-Environment Validation Protocol**
# Consistent algorithm ranking across multiple environments validates robustness claims and identifies algorithms with stable performance characteristics independent of operational conditions.
#
# **Empirical Robustness Quantification**
# The multi-environment approach enables precise measurement of performance degradation rates, establishing quantitative robustness metrics that support theoretical predictions and practical deployment decisions.
#
# ### Methodological Significance
#
# This comprehensive evaluation protocol addresses limitations in existing literature where algorithm assessment often focuses on narrow operational scenarios, providing the empirical foundation necessary for robust algorithm deployment in practical quantum network environments.
